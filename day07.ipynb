# %% [markdown]
# # 6.Data Collection with API

# %% [markdown]
# ## 6.1 Youtube
#
# site: https://console.developers.google.com/ <br>
# reference: https://developers.google.com/youtube/v3/docs?hl=ko <br>
#
# ```python
# from googleapiclient.discovery import build
# from googleapiclient.errors import HttpError
# from oauth2client.tools import argparser
#
# import pandas as pd
#
#
# DEVELOPER_KEY=''
# YOUTUBE_API_SERVICE_NAME='youtube'
# YOUTUBE_API_VERSION='v3'
#
# youtube = build(
#   YOUTUBE_API_SERVICE_NAME,
#   YOUTUBE_API_VERSION,
#   developerKey=DEVELOPER_KEY
#   )
# ```

# %% [markdown]
# ### Videos
#
# 채널 내 비디오 조회 기본 코드 (*snippet은 고정)
# ```python
# response = (
#   youtube
#   .playlistItems()
#   .list(
#     playlistId=*channel_id*,
#     part='snippet',
#     maxResults=50
#     )
#   .execute()
#   )
# ```
#
#
# 1번의 query에 전체 데이터를 다 받을 수 없음 <br>
# 따라서 pageToken을 이용하여 다음 페이지의 정보를 받아야 함 <br>
# ```python
# if 'nextPageToken' in response:
#   response = (
#     youtube
#     .playlistItems()
#     .list(
#       playlistId=*channel_id*,
#       pageToken=response.get('nextPageToken'),
#       part='snippet',
#       maxResults=50
#       )
#     .execute()
#     )
# ```

# %%
# !pip install google-api-python-client
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.58.0-py2.py3-none-any.whl (9.0 MB)
# Collecting google-auth-httplib2>=0.1.0
#   Downloading google_auth_httplib2-0.1.0-py2.py3-none-any.whl (9.3 kB)
# Collecting uritemplate<5,>=3.0.1
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5
#   Downloading google_api_core-2.8.2-py3-none-any.whl (114 kB)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in c:\programdata\anaconda3\lib\site-packages (from google-api-python-client) (1.33.0)
# Collecting httplib2<1dev,>=0.15.0
#   Downloading httplib2-0.20.4-py3-none-any.whl (96 kB)
# Requirement already satisfied: protobuf<5.0.0dev,>=3.15.0 in c:\programdata\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.19.1)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\programdata\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.27.1)
# Collecting googleapis-common-protos<2.0dev,>=1.56.2
#   Downloading googleapis_common_protos-1.56.4-py2.py3-none-any.whl (211 kB)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (4.7.2)
# Requirement already satisfied: six>=1.9.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (1.16.0)
# Requirement already satisfied: setuptools>=40.3.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (61.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\programdata\anaconda3\lib\site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (3.0.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.26.9)
# Installing collected packages: httplib2, googleapis-common-protos, uritemplate, google-auth-httplib2, google-api-core, google-api-python-client
# Successfully installed google-api-core-2.8.2 google-api-python-client-2.58.0 google-auth-httplib2-0.1.0 googleapis-common-protos-1.56.4 httplib2-0.20.4 uritemplate-4.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-core 1.7.1 requires google-api-core<2.0.0dev,>=1.21.0, but you have google-api-core 2.8.2 which is incompatible.

# %%
# !pip install oauth2client
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting oauth2client
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in c:\programdata\anaconda3\lib\site-packages (from oauth2client) (0.2.8)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\programdata\anaconda3\lib\site-packages (from oauth2client) (0.4.8)
# Requirement already satisfied: rsa>=3.1.4 in c:\programdata\anaconda3\lib\site-packages (from oauth2client) (4.7.2)
# Requirement already satisfied: httplib2>=0.9.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from oauth2client) (0.20.4)
# Requirement already satisfied: six>=1.6.1 in c:\programdata\anaconda3\lib\site-packages (from oauth2client) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\programdata\anaconda3\lib\site-packages (from httplib2>=0.9.1->oauth2client) (3.0.4)
# Installing collected packages: oauth2client
# Successfully installed oauth2client-4.1.3

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from oauth2client.tools import argparser

import pandas as pd


DEVELOPER_KEY='AIzaSyCMuqkVfelho1yjM1cWAmVHyPKPzC54qQg'
YOUTUBE_API_SERVICE_NAME='youtube'
YOUTUBE_API_VERSION='v3'

youtube = build(
  YOUTUBE_API_SERVICE_NAME,
  YOUTUBE_API_VERSION,
  developerKey=DEVELOPER_KEY
  )

# %%
#id 를 넣었으나 작동하지 않음 comments를 활용하여 영상 id 확인필요
response = (
  youtube
  .search()
  .list(
    channelId='UC1B6SalAoiJD7eHfMUA9QrA', 
    part='snippet',
    maxResults=50
    )
  .execute()
  )

# %%
for i, item in enumerate(response.items()):
    if i == 5:
        videos_info = item
        break

# %%
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'YUQu4XyinQYfrrxx2CrnBUwgO8g',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'KR',
#  'pageInfo': {'totalResults': 90, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'IZ_IVF1tbuaGkffSLJDcLPNbzvk',
#    'id': {'kind': 'youtube#video', 'videoId': 'lc0AXbBHJYc'},
#    'snippet': {'publishedAt': '2022-08-05T09:00:34Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '작전타임',
#     'description': '스케치코미디 #숏박스 #ufc.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lc0AXbBHJYc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/lc0AXbBHJYc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/lc0AXbBHJYc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-05T09:00:34Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '4uK6sz__ABrJB5uUZ1Y434_mUWY',
#    'id': {'kind': 'youtube#video', 'videoId': '1z4NjPc4_i0'},
#    'snippet': {'publishedAt': '2022-04-16T09:00:00Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '벚꽃놀이',
#     'description': '스케치코미디 #숏박스 #벚꽃놀이.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1z4NjPc4_i0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/1z4NjPc4_i0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/1z4NjPc4_i0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-04-16T09:00:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'jEkBoY-S-Y15J7po-yMlnJkGOwc',
#    'id': {'kind': 'youtube#video', 'videoId': '7VUTjhc-s6o'},
#    'snippet': {'publishedAt': '2022-07-04T09:00:03Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '고깃집',
#     'description': '스케치코미디 #숏박스 #장기연애 장소제공 : 서울 마포구 독막로 67-14 빽돈 홍대점.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7VUTjhc-s6o/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7VUTjhc-s6o/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7VUTjhc-s6o/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-04T09:00:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 's2QiwlcuXOAotGGYVBZ9FuJXsYE',
#    'id': {'kind': 'youtube#video', 'videoId': 'KTA9IE8jPP4'},
#    'snippet': {'publishedAt': '2022-01-20T03:15:00Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '대실',
#     'description': '스케치코미디 #숏박스 #장수커플 음원출처 브금대통령 : https://www.youtube.com/user/GwooA.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/KTA9IE8jPP4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/KTA9IE8jPP4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/KTA9IE8jPP4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-01-20T03:15:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'eQlHggiFi8WPUB-tLFbjk5AeodA',
#    'id': {'kind': 'youtube#video', 'videoId': 'u1npU_pnDdE'},
#    'snippet': {'publishedAt': '2021-12-18T04:00:10Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '경차사러 갔다가 람보르기니 산 썰',
#     'description': '스케치코미디 #숏박스 #허위딜러 음원출처 브금대통령 : https://www.youtube.com/user/GwooA.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/u1npU_pnDdE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/u1npU_pnDdE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/u1npU_pnDdE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-12-18T04:00:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'yK8GTpiJmq9JCBet1UtK0A11rgg',
#    'id': {'kind': 'youtube#video', 'videoId': 'AeVP4dzq174'},
#    'snippet': {'publishedAt': '2022-06-01T09:00:04Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '병문안',
#     'description': '스케치코미디 #숏박스 #병문안.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AeVP4dzq174/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/AeVP4dzq174/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/AeVP4dzq174/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-06-01T09:00:04Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'LP24v29mdda9grzbMzY7H0xIjhk',
#    'id': {'kind': 'youtube#video', 'videoId': 'mnGNoGj19Jg'},
#    'snippet': {'publishedAt': '2022-05-13T09:00:22Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '특종',
#     'description': '스케치코미디 #숏박스 #기자.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mnGNoGj19Jg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mnGNoGj19Jg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/mnGNoGj19Jg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-05-13T09:00:22Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'JODd7eHGPGRyiH-_a5N94-z23fM',
#    'id': {'kind': 'youtube#video', 'videoId': 'rWzNdMhnYIs'},
#    'snippet': {'publishedAt': '2022-04-08T09:00:22Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '방송사고',
#     'description': '스케치코미디 #숏박스 #뉴스 음원출처 브금대통령 : https://www.youtube.com/user/GwooA.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/rWzNdMhnYIs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/rWzNdMhnYIs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/rWzNdMhnYIs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-04-08T09:00:22Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'uop0oW-8I2FWjTYVYMZv876ZJ8U',
#    'id': {'kind': 'youtube#video', 'videoId': 'bS08FFG20eQ'},
#    'snippet': {'publishedAt': '2022-03-06T09:00:17Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '여행계획',
#     'description': '스케치코미디 #숏박스 #장기연애 음원출처 브금대통령 : https://www.youtube.com/user/GwooA 장소제공 : 경기 파주시 교하로 427 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/bS08FFG20eQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/bS08FFG20eQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/bS08FFG20eQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-06T09:00:17Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '8jkstRTD9bkD5UXDLGzwP-LtZqo',
#    'id': {'kind': 'youtube#video', 'videoId': 'v48_kOMPe08'},
#    'snippet': {'publishedAt': '2022-03-29T09:00:21Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '자가격리',
#     'description': '스케치코미디 #숏박스 #찐남매 음원출처 브금대통령 : https://www.youtube.com/user/GwooA.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/v48_kOMPe08/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/v48_kOMPe08/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/v48_kOMPe08/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-29T09:00:21Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Vg3GjytmHrrks4QOHMcH1jyXCso',
#    'id': {'kind': 'youtube#video', 'videoId': 'aXTkswSxmQs'},
#    'snippet': {'publishedAt': '2022-07-15T09:00:04Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '메뉴 어떤 걸로 하시겠어요?',
#     'description': '스케치코미디 #숏박스 #써브웨이.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/aXTkswSxmQs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/aXTkswSxmQs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/aXTkswSxmQs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-15T09:00:04Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '4ets7gkENG6IcnkhbwXJDSGCS7s',
#    'id': {'kind': 'youtube#video', 'videoId': 'lkagwPQrWeE'},
#    'snippet': {'publishedAt': '2022-01-27T09:00:32Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '마감 30분 전',
#     'description': '스케치코미디 #숏박스 #미용실 장소제공 : 인천 부평구 부평대로 153 233호 수피아나 음원출처 브금대통령 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lkagwPQrWeE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/lkagwPQrWeE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/lkagwPQrWeE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-01-27T09:00:32Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'WnEmKRehY3Pm801KB0-LY4Mg5DM',
#    'id': {'kind': 'youtube#video', 'videoId': '7MhUaA9wbJA'},
#    'snippet': {'publishedAt': '2022-05-26T09:00:03Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '병문안',
#     'description': '스케치코미디 #숏박스 #병원.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7MhUaA9wbJA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7MhUaA9wbJA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7MhUaA9wbJA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-05-26T09:00:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'sAcnOfm8-FnXtuWITjXv1iKK0fE',
#    'id': {'kind': 'youtube#video', 'videoId': 'wVr57pnUj_I'},
#    'snippet': {'publishedAt': '2022-04-28T09:00:22Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '...',
#     'description': '스케치코미디 #숏박스 #찐형제.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wVr57pnUj_I/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/wVr57pnUj_I/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/wVr57pnUj_I/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-04-28T09:00:22Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'BkhwGv6BYi36FmJpLPEPx_ZeiI4',
#    'id': {'kind': 'youtube#video', 'videoId': '4fNMMelN4tM'},
#    'snippet': {'publishedAt': '2022-02-10T09:00:02Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '예쁜카페',
#     'description': '스케치코미디 #숏박스 #예쁜카페 장소제공 : 마포구 상암동 2-127번지 듀이커피 음원출처 브금대통령 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4fNMMelN4tM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/4fNMMelN4tM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/4fNMMelN4tM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-02-10T09:00:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'r6Z39xMxWu84Jd_YtiRWBI9ZhlU',
#    'id': {'kind': 'youtube#video', 'videoId': 'Uidupj_sAO8'},
#    'snippet': {'publishedAt': '2022-04-21T09:00:10Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '홈트레이닝',
#     'description': '스케치코미디 #숏박스 #LG퓨리케어에어로타워.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Uidupj_sAO8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Uidupj_sAO8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Uidupj_sAO8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-04-21T09:00:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '3yLN_in5Pjvcm5huYjdFoDNRHBA',
#    'id': {'kind': 'youtube#video', 'videoId': 'O4gFFS4Maek'},
#    'snippet': {'publishedAt': '2022-07-29T09:00:11Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '은행',
#     'description': '스케치코미디 #숏박스 #은행.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/O4gFFS4Maek/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/O4gFFS4Maek/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/O4gFFS4Maek/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-29T09:00:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Nebk__jNmvileASHjPT8pbbKoAU',
#    'id': {'kind': 'youtube#video', 'videoId': 'UCeB51k4ZDc'},
#    'snippet': {'publishedAt': '2022-07-01T09:00:16Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '짜장면 내기',
#     'description': '스케치코미디 #숏박스 #당구장.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UCeB51k4ZDc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/UCeB51k4ZDc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/UCeB51k4ZDc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-01T09:00:16Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'FNeBijhZblBb2BrknAd9EQkt4Fw',
#    'id': {'kind': 'youtube#video', 'videoId': 'lPl8-Fo4nr8'},
#    'snippet': {'publishedAt': '2022-06-24T09:00:37Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '필요한 거 있으시면 말씀해주세요',
#     'description': '스케치코미디 #숏박스 #신발.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lPl8-Fo4nr8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/lPl8-Fo4nr8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/lPl8-Fo4nr8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-06-24T09:00:37Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'GX4AELVPxJ-RboyZE0KPsri5KFc',
#    'id': {'kind': 'youtube#video', 'videoId': 'GCpOvMasiXw'},
#    'snippet': {'publishedAt': '2022-06-10T09:00:14Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '상담',
#     'description': '스케치코미디 #숏박스 #성형외과 장소제공 : 서울 강남구 테헤란로107(역삼동822-2 메디타워8, 10층) 프리미어성형외과의원.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GCpOvMasiXw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/GCpOvMasiXw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/GCpOvMasiXw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-06-10T09:00:14Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'aA7MjDbnKxWUIUbSwhLekJmkepc',
#    'id': {'kind': 'youtube#video', 'videoId': 'Dyx_uy9h5UQ'},
#    'snippet': {'publishedAt': '2021-11-25T11:15:01Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '손흥민 어떡하냐',
#     'description': '스케치코미디 #숏박스 #손흥민 음원출처 브금대통령 : https://www.youtube.com/user/GwooA.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Dyx_uy9h5UQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Dyx_uy9h5UQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Dyx_uy9h5UQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-25T11:15:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'PwuNjVjUORaPacES5QJyV4FEias',
#    'id': {'kind': 'youtube#video', 'videoId': 'fU6lxdxTdU4'},
#    'snippet': {'publishedAt': '2022-03-18T09:00:21Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '아프면 손 드세요',
#     'description': '스케치코미디 #숏박스 #치과 장소제공 : 서울 서초구 서초대로 77길 54 (서초동 1303-37 서초더블유타워 12층) 티유치과의원 영상에 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fU6lxdxTdU4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fU6lxdxTdU4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fU6lxdxTdU4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-18T09:00:21Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'xwF5c-9I5RLqQk4mcgNs6FBaQts',
#    'id': {'kind': 'youtube#video', 'videoId': 'FJ8Z6lOVEfk'},
#    'snippet': {'publishedAt': '2022-02-25T09:00:38Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '꺼져',
#     'description': '스케치코미디 #숏박스 #찐남매 믿기어렵고 믿고싶지도 않겠지만 진세가 동생입니다 음원출처 브금대통령 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FJ8Z6lOVEfk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/FJ8Z6lOVEfk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/FJ8Z6lOVEfk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-02-25T09:00:38Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'P4DwV3nNp_xn8RfgRWUopuye7fk',
#    'id': {'kind': 'youtube#video', 'videoId': '2IArGihNhOs'},
#    'snippet': {'publishedAt': '2021-12-12T03:48:43Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '1등 되면 얼마줄 거야?',
#     'description': '스케치코미디 #숏박스 #로또 음원출처 브금대통령 : https://www.youtube.com/user/GwooA.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/2IArGihNhOs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/2IArGihNhOs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/2IArGihNhOs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-12-12T03:48:43Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'k0EjkSd3muGmfKGwOhZNAf4DMkk',
#    'id': {'kind': 'youtube#video', 'videoId': 'efnc2S012Co'},
#    'snippet': {'publishedAt': '2021-12-05T04:45:01Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '모든 건 너한테 달렸어',
#     'description': '스케치코미디 #숏박스 #도둑 음원출처 브금대통령 : https://www.youtube.com/user/GwooA.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/efnc2S012Co/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/efnc2S012Co/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/efnc2S012Co/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-12-05T04:45:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'rfTSq2CzSQHIYTVTHkokNc228D8',
#    'id': {'kind': 'youtube#video', 'videoId': 'BlC3DgsM3l0'},
#    'snippet': {'publishedAt': '2022-01-02T06:16:24Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '내일 지구 멸망하면 뭐 할 거야?',
#     'description': '스케치코미디 #숏박스 #지구멸망 음원출처 브금대통령 : https://www.youtube.com/user/GwooA.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BlC3DgsM3l0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BlC3DgsM3l0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BlC3DgsM3l0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-01-02T06:16:24Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'WIbccM74O2EbGtZnJizwRou8eXo',
#    'id': {'kind': 'youtube#video', 'videoId': 'joSo7mS5FOs'},
#    'snippet': {'publishedAt': '2022-08-12T09:00:33Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '제일 싼 집',
#     'description': '스케치코미디 #숏박스 #휴대폰.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/joSo7mS5FOs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/joSo7mS5FOs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/joSo7mS5FOs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-12T09:00:33Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'CX4POFsNnuYy7lEkrtuWQqeM5m4',
#    'id': {'kind': 'youtube#video', 'videoId': '0QqFajIlfDk'},
#    'snippet': {'publishedAt': '2021-11-17T09:30:01Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '얼마 할 거야?',
#     'description': '스케치코미디 #숏박스 #결혼식.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0QqFajIlfDk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/0QqFajIlfDk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/0QqFajIlfDk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-17T09:30:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '2R8cQLiu-1hJOrlc_oQWZouw-V4',
#    'id': {'kind': 'youtube#video', 'videoId': '4Fs59tq2Cd8'},
#    'snippet': {'publishedAt': '2021-12-23T11:15:00Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '군인 인 거 티나?',
#     'description': '스케치코미디 #숏박스 #신병 음원출처 브금대통령 : https://www.youtube.com/user/GwooA.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4Fs59tq2Cd8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/4Fs59tq2Cd8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/4Fs59tq2Cd8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-12-23T11:15:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'hPEoLOujY3RfAuo2KGtqW_QndPw',
#    'id': {'kind': 'youtube#video', 'videoId': 'f74KBqRMNOg'},
#    'snippet': {'publishedAt': '2022-02-20T09:00:16Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '287번 101번',
#     'description': '스케치코미디 #숏박스 #오징어게임 작업에 참여해주신 곽자형 배우님 감사합니다! 음원출처 브금대통령 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/f74KBqRMNOg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/f74KBqRMNOg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/f74KBqRMNOg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-02-20T09:00:16Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'FHmkS4RVRrTRzxi5-cLwtMHLH7Q',
#    'id': {'kind': 'youtube#video', 'videoId': 'DbUa2pMQ_Gg'},
#    'snippet': {'publishedAt': '2021-12-09T09:30:04Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '아이언맨 VS 헐크',
#     'description': '스케치코미디 #숏박스 #어벤져스 음원출처 브금대통령 : https://www.youtube.com/user/GwooA.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DbUa2pMQ_Gg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/DbUa2pMQ_Gg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/DbUa2pMQ_Gg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-12-09T09:30:04Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '7KH5mwX9cH6ej0uwGZdYS_OeKVM',
#    'id': {'kind': 'youtube#video', 'videoId': 'PTyWnhAEzq4'},
#    'snippet': {'publishedAt': '2022-03-03T09:00:11Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '대리니ㅁ 할말ㅇㅣ씁ㄴ다',
#     'description': '스케치코미디 #숏박스 #카스영영 음원출처 브금대통령 : https://www.youtube.com/user/GwooA 카스의 짜릿함과 청량감이 그대로 논 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PTyWnhAEzq4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/PTyWnhAEzq4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/PTyWnhAEzq4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-03T09:00:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ZK2SrPwvtSXwLndtVSbecp5TnPg',
#    'id': {'kind': 'youtube#video', 'videoId': 'X9kVzk7rlRw'},
#    'snippet': {'publishedAt': '2022-04-05T09:00:29Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '살려주세요',
#     'description': '스케치코미디 #숏박스 #나의해방일지 답답한 일상에 해방이 필요할 때 JTBC 토일드라마 [나의 해방일지] 이민기x김지원x손석구x ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/X9kVzk7rlRw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/X9kVzk7rlRw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/X9kVzk7rlRw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-04-05T09:00:29Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '2TevZ1znxPzbwWyIQend4aj0hls',
#    'id': {'kind': 'youtube#video', 'videoId': 'Mvptj7RwvmI'},
#    'snippet': {'publishedAt': '2021-10-30T05:00:08Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '말하지 말라고 (오겜 스포주의)',
#     'description': '스케치코미디 #숏박스 #오징어게임 BG출처(브금대통령) : https://www.youtube.com/user/GwooA.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Mvptj7RwvmI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Mvptj7RwvmI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Mvptj7RwvmI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-10-30T05:00:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'DRtTaMRqt10KZGPbbxz9nVtlFXA',
#    'id': {'kind': 'youtube#video', 'videoId': 'WjRm0Kl9hXU'},
#    'snippet': {'publishedAt': '2021-12-02T03:38:13Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '바퀴벌레 퇴치',
#     'description': '스케치코미디 #숏박스 #바퀴벌레 음원출처 브금대통령 : https://www.youtube.com/user/GwooA.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/WjRm0Kl9hXU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/WjRm0Kl9hXU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/WjRm0Kl9hXU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-12-02T03:38:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'y9gDd78xQBU8AU5wdZKVTWGkK7Q',
#    'id': {'kind': 'youtube#video', 'videoId': 'mYB4iCeo2Q8'},
#    'snippet': {'publishedAt': '2021-11-13T03:42:43Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '누구지?',
#     'description': '스케치코미디 #숏박스 #동창 (브금 출처)브금대통령 : https://youtube.com/user/GwooA.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mYB4iCeo2Q8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mYB4iCeo2Q8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/mYB4iCeo2Q8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-13T03:42:43Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ZF7whE6uL_s7ClHdlQZuowgbIdM',
#    'id': {'kind': 'youtube#video', 'videoId': 'mUa3MSTXWQM'},
#    'snippet': {'publishedAt': '2022-06-16T09:00:18Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '여자들',
#     'description': '스케치코미디 #숏박스 #별빛청하 장소제공: 서울 마포구 잔다리로 8-6 1943 홍대점.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mUa3MSTXWQM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mUa3MSTXWQM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/mUa3MSTXWQM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-06-16T09:00:18Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'fZAoV5Tv26LPM7IPeCt0hZPiGVU',
#    'id': {'kind': 'youtube#video', 'videoId': 'tA58K0PfuOA'},
#    'snippet': {'publishedAt': '2021-12-27T03:26:04Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '오빠 나 이러려고 만나?',
#     'description': '스케치코미디 #숏박스 #쉬운여자 음원출처 브금대통령 : https://www.youtube.com/user/GwooA.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/tA58K0PfuOA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/tA58K0PfuOA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/tA58K0PfuOA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-12-27T03:26:04Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'vdAh_PLiJOAZ4eM2MrnDcsVT7gg',
#    'id': {'kind': 'youtube#video', 'videoId': 'qSjF8esYrpc'},
#    'snippet': {'publishedAt': '2021-11-07T05:45:00Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '너라면 어떻게 할거야?',
#     'description': '스케치코미디 #숏박스 #밸런스게임 (브금 출처)브금대통령 : https://youtube.com/user/GwooA.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/qSjF8esYrpc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/qSjF8esYrpc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/qSjF8esYrpc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-07T05:45:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ETb9qNUC4CUFKt5S_LFbslXldLI',
#    'id': {'kind': 'youtube#video', 'videoId': '0-b8AZcws0k'},
#    'snippet': {'publishedAt': '2022-02-16T09:00:00Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '컷',
#     'description': '스케치코미디 #숏박스 #테라브레스 *테라브레스 구매링크* 꽃향기때문에 입주변에 벌이 꼬일 수 있어요 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0-b8AZcws0k/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/0-b8AZcws0k/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/0-b8AZcws0k/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-02-16T09:00:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'TrzDSTrzc2Ei_Ik9_yOOv1fVgnM',
#    'id': {'kind': 'youtube#video', 'videoId': 'YYRKUaC1sXY'},
#    'snippet': {'publishedAt': '2021-11-28T05:45:00Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '뭘 쳐다봐',
#     'description': '스케치코미디 #숏박스 #속마음 음원출처 브금대통령 : https://www.youtube.com/user/GwooA.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/YYRKUaC1sXY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/YYRKUaC1sXY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/YYRKUaC1sXY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-28T05:45:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '_xtYCjoB0YJHiXruLqOyPvQYlKA',
#    'id': {'kind': 'youtube#video', 'videoId': 'D1HuJ7k_Vwo'},
#    'snippet': {'publishedAt': '2022-05-22T09:00:05Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '유튜브 3일 차',
#     'description': '스케치코미디 #숏박스#먹방.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/D1HuJ7k_Vwo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/D1HuJ7k_Vwo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/D1HuJ7k_Vwo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-05-22T09:00:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'eg6rhL_FU1--m9VTFzUfy4Ah10I',
#    'id': {'kind': 'youtube#video', 'videoId': 'B70t6vaftp4'},
#    'snippet': {'publishedAt': '2022-02-03T09:00:07Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '니가 갔다와',
#     'description': '스케치코미디 #숏박스 #헌팅 장소제공 : 서울 금천구 벚꽃로 298 가산디지털단지점 통파이브 음원출처 브금대통령 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/B70t6vaftp4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/B70t6vaftp4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/B70t6vaftp4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-02-03T09:00:07Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'DIKAHSfq61hzOP101dUK4vBeWDA',
#    'id': {'kind': 'youtube#video', 'videoId': '0YITe3q-SCc'},
#    'snippet': {'publishedAt': '2021-11-11T06:00:01Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '신인배우',
#     'description': '스케치코미디 #숏박스 #신인배우 (브금 출처)브금대통령 : https://youtube.com/user/GwooA.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0YITe3q-SCc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/0YITe3q-SCc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/0YITe3q-SCc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-11T06:00:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '3QQ6G5D6ReVS8Jlb9In5K-A1w4k',
#    'id': {'kind': 'youtube#video', 'videoId': 'YC7DLjEp9po'},
#    'snippet': {'publishedAt': '2022-08-19T09:00:16Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '유튜브 30일 차',
#     'description': '스케치코미디 #숏박스 #언박싱.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/YC7DLjEp9po/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/YC7DLjEp9po/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/YC7DLjEp9po/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-19T09:00:16Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '-IwHqU5esfGDGiJJDus_hJctWfs',
#    'id': {'kind': 'youtube#video', 'videoId': 'SKns0Vho5H0'},
#    'snippet': {'publishedAt': '2021-11-20T04:45:02Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '어디까지 얘기했지?',
#     'description': '스케치코미디 #숏박스 #꼬리에꼬리를무는답답함 음원출처 브금대통령 : https://www.youtube.com/user/GwooA.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/SKns0Vho5H0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/SKns0Vho5H0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/SKns0Vho5H0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-20T04:45:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'VjVzv5di-m4AvPwB1AVTiE_nSwg',
#    'id': {'kind': 'youtube#video', 'videoId': 'p4a-wsIbVRM'},
#    'snippet': {'publishedAt': '2022-07-20T09:00:34Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '구독자 이벤트 뭐 하지?',
#     'description': '스케치코미디 #숏박스 #200만.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/p4a-wsIbVRM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/p4a-wsIbVRM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/p4a-wsIbVRM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-20T09:00:34Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'nZJwtBRwfgWe1yDJKkoa2r2NU5Y',
#    'id': {'kind': 'youtube#video', 'videoId': 'QDSBgE5YoOE'},
#    'snippet': {'publishedAt': '2022-03-13T09:00:11Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '구독자 이벤트 뭐 하지?',
#     'description': '스케치코미디 #숏박스 #구독자이벤트 안녕하세요 숏박스입니다 :)   숏박스를 사랑해주시는 여러분들 덕분에 구독자 100만을 달성 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QDSBgE5YoOE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/QDSBgE5YoOE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/QDSBgE5YoOE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-13T09:00:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'VME1d9jug8wzkHNJRgUAw11MCVE',
#    'id': {'kind': 'youtube#video', 'videoId': 'hkskzD3Bs4M'},
#    'snippet': {'publishedAt': '2021-11-04T06:00:23Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '휴지 있으세요?',
#     'description': '스케치코미디 #숏박스 #화장실 BG출처(브금대통령) : https://www.youtube.com/user/GwooA.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hkskzD3Bs4M/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hkskzD3Bs4M/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/hkskzD3Bs4M/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-04T06:00:23Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '8jbX8rpy4ugPYJA08AOgB9_XKuU',
#    'id': {'kind': 'youtube#video', 'videoId': 'wST9cYLYO7o'},
#    'snippet': {'publishedAt': '2022-03-24T09:00:26Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '합석',
#     'description': '스케치코미디 #숏박스 #비레디 [더보기] - 비레디 자석 쿠션: https://brand.naver.com/beready/products/5535727355 - 비레디 생기 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wST9cYLYO7o/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/wST9cYLYO7o/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/wST9cYLYO7o/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-24T09:00:26Z'}}]}

# %% [markdown]
# ### 영상 한개에 대한 제목정보

# %%
# videos_info[1][0].get('snippet').get('title')
videos_info[1][0].get('id').get('videoId')
# Out:
# 'lc0AXbBHJYc'

# %% [markdown]
# ### 영상 50개에 대한 제목정보

# %%
title = [videos_info[1][i].get('snippet').get('title') for i in range(len(videos_info[1]))] #제목
date = [videos_info[1][i].get('snippet').get('publishedAt') for i in range(len(videos_info[1]))] #날짜
video_id = [videos_info[1][i].get('id').get('videoId') for i in range(len(videos_info[1]))] #영상id

# %%
pd.DataFrame(zip(date,title,video_id), 
             columns = ['date','titles','video_id'])
# Out:
#                     date              titles     video_id
# 0   2022-08-05T09:00:34Z                작전타임  lc0AXbBHJYc
# 1   2022-04-16T09:00:00Z                벚꽃놀이  1z4NjPc4_i0
# 2   2022-07-04T09:00:03Z            고깃집  7VUTjhc-s6o
# 3   2022-01-20T03:15:00Z                  대실  KTA9IE8jPP4
# 4   2021-12-18T04:00:10Z  경차사러 갔다가 람보르기니 산 썰  u1npU_pnDdE
# 5   2022-06-01T09:00:04Z           병문안  AeVP4dzq174
# 6   2022-05-13T09:00:22Z                  특종  mnGNoGj19Jg
# 7   2022-04-08T09:00:22Z                방송사고  rWzNdMhnYIs
# 8   2022-03-06T09:00:17Z                여행계획  bS08FFG20eQ
# 9   2022-03-29T09:00:21Z                자가격리  v48_kOMPe08
# 10  2022-07-15T09:00:04Z     메뉴 어떤 걸로 하시겠어요?  aXTkswSxmQs
# 11  2022-01-27T09:00:32Z            마감 30분 전  lkagwPQrWeE
# 12  2022-05-26T09:00:03Z                 병문안  7MhUaA9wbJA
# 13  2022-04-28T09:00:22Z                 ...  wVr57pnUj_I
# 14  2022-02-10T09:00:02Z                예쁜카페  4fNMMelN4tM
# 15  2022-04-21T09:00:10Z               홈트레이닝  Uidupj_sAO8
# 16  2022-07-29T09:00:11Z              은행  O4gFFS4Maek
# 17  2022-07-01T09:00:16Z              짜장면 내기  UCeB51k4ZDc
# 18  2022-06-24T09:00:37Z   필요한 거 있으시면 말씀해주세요  lPl8-Fo4nr8
# 19  2022-06-10T09:00:14Z                  상담  GCpOvMasiXw
# 20  2021-11-25T11:15:01Z            손흥민 어떡하냐  Dyx_uy9h5UQ
# 21  2022-03-18T09:00:21Z           아프면 손 드세요  fU6lxdxTdU4
# 22  2022-02-25T09:00:38Z                  꺼져  FJ8Z6lOVEfk
# 23  2021-12-12T03:48:43Z       1등 되면 얼마줄 거야?  2IArGihNhOs
# 24  2021-12-05T04:45:01Z        모든 건 너한테 달렸어  efnc2S012Co
# 25  2022-01-02T06:16:24Z  내일 지구 멸망하면 뭐 할 거야?  BlC3DgsM3l0
# 26  2022-08-12T09:00:33Z              제일 싼 집  joSo7mS5FOs
# 27  2021-11-17T09:30:01Z            얼마 할 거야?  0QqFajIlfDk
# 28  2021-12-23T11:15:00Z          군인 인 거 티나?  4Fs59tq2Cd8
# 29  2022-02-20T09:00:16Z           287번 101번  f74KBqRMNOg
# 30  2021-12-09T09:30:04Z          아이언맨 VS 헐크  DbUa2pMQ_Gg
# 31  2022-03-03T09:00:11Z        대리니ㅁ 할말ㅇㅣ씁ㄴ다  PTyWnhAEzq4
# 32  2022-04-05T09:00:29Z               살려주세요  X9kVzk7rlRw
# 33  2021-10-30T05:00:08Z   말하지 말라고 (오겜 스포주의)  Mvptj7RwvmI
# 34  2021-12-02T03:38:13Z             바퀴벌레 퇴치  WjRm0Kl9hXU
# 35  2021-11-13T03:42:43Z                누구지?  mYB4iCeo2Q8
# 36  2022-06-16T09:00:18Z                 여자들  mUa3MSTXWQM
# 37  2021-12-27T03:26:04Z       오빠 나 이러려고 만나?  tA58K0PfuOA
# 38  2021-11-07T05:45:00Z        너라면 어떻게 할거야?  qSjF8esYrpc
# 39  2022-02-16T09:00:00Z                   컷  0-b8AZcws0k
# 40  2021-11-28T05:45:00Z               뭘 쳐다봐  YYRKUaC1sXY
# 41  2022-05-22T09:00:05Z            유튜브 3일 차  D1HuJ7k_Vwo
# 42  2022-02-03T09:00:07Z              니가 갔다와  B70t6vaftp4
# 43  2021-11-11T06:00:01Z                신인배우  0YITe3q-SCc
# 44  2022-08-19T09:00:16Z           유튜브 30일 차  YC7DLjEp9po
# 45  2021-11-20T04:45:02Z          어디까지 얘기했지?  SKns0Vho5H0
# 46  2022-07-20T09:00:34Z       구독자 이벤트 뭐 하지?  p4a-wsIbVRM
# 47  2022-03-13T09:00:11Z       구독자 이벤트 뭐 하지?  QDSBgE5YoOE
# 48  2021-11-04T06:00:23Z            휴지 있으세요?  hkskzD3Bs4M
# 49  2022-03-24T09:00:26Z                  합석  wST9cYLYO7o

# %% [markdown]
# ### 첫페이지 댓글수집

# %%
response = (
    youtube
    .commentThreads()
    .list(
      part='snippet,replies', 
      videoId='uRFEhFIsyXY', 
      maxResults=100
      )
    .execute()
    )

#nextPageToken = 페이지의 max 댓글

tot_resp = len(response.get('items'))
# tot_resp1 = response.get('pageInfo').get('totalResults')



# [response.get('items')[i].get('snippet').get('topLevelComment').get('snippet').get('textOriginal') for i in range(len(response.get('items')))]#
# Out:
# 97

# %%
def get_comments_from_youtube_api_result(response):
    return [response.get('items')[i].get('snippet').get('topLevelComment').get('snippet').get('textOriginal') for i in range(len(response.get('items')))]

# %% [markdown]
# ### 전체 잿글수집

# %%
all_comments = []

response = (
    youtube
    .commentThreads()
    .list(
      part='snippet,replies', 
      videoId='uRFEhFIsyXY', 
      maxResults=100
      )
    .execute()
    )

while response.get('nextPageToken'):
  response = (
    youtube
    .commentThreads()
    .list(
      part='snippet,replies', 
      videoId='uRFEhFIsyXY', 
      maxResults=100,
      pageToken = response.get('nextPageToken')
    )
    .execute()
  )
  all_comments.extend(get_comments_from_youtube_api_result(response))

# %%
all_comments
# Out:
# ['ㅋㅋㅋ 엄지님 티셔츠 셀린 디온 미쳤네요\n오빠만세 ㅋㅋㅋ',
#  '개그콘서트를 김미화님 나오실 때부터 폐지되는 날까지 10년이 넘는 기간 동안 거의 매주 챙겨 봤어요. 본방을 보지 못하는 날이면 재방송을 꼭 시청했었지요 육아로 힘든 시기를 보내고 있는 동안 개콘을 통해 울고 웃었습니다. \n그 갓난쟁이 우리 애기가 지금 대학생이고요\n숏박스 \n화이팅입니다!!!',
#  '역시 찐남매 시리즈 흥얼에서 괜히 내가 다 뿌듯 어쩜 저런 드립을치지 ㅠㅠ 최고야',
#  '티샤츠 셀린디온 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '첨보는데 존나재밋네',
#  '실비김치는 못참지 ㅋㅋ',
#  '실비김치 광고 자연스럽게 녹인건줄 ㅋㅋㅋㅋㅋ',
#  "These videos are always so touching and makes me really grateful I don't have a sister",
#  '재밌다 헤헤헤헿',
#  '동생이 잘 놀아주네ㅋㅋㅋㅋ',
#  '실비 김치 드시고\n시원하게 쾌변 하세요',
#  '그와중에 엄지렐라 dionㅋㅋㅋㅋ',
#  '남매인데 과거생각나네요 ㅋㅋ 웃겨웃겨',
#  'ㅋㅋㅋㅋㅋ 회사에 이한몸 불..아니고 구글에 불질러버리겟다고햇대ㅋㅋ ㅋ',
#  '아시바존나욱기다',
#  '세상에서 제일 가는 포테이토칩ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '남매라 역시 둘이 닮음',
#  '라이 라이 또라이 부러쓰 부러쓰',
#  '2:56 원훈씨 닮음 표정이',
#  '버릴 대사가 없다ㅎㅎ\n누가 감독이야?? 대단합니다~!!',
#  '티샤츠 셀린디온ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '아 또각또각 ㅋㄱㅋㄱㅋㄱㅋㄱㅋㄱㅋ머냐고 ㅋㄱㅋㄱㅋㄱㅋㄱㅋㄱㅋㄱㅋㄱㅋㄱㅋㅋㅋㅌㄱㅌㅋㅌㅋㅋㅌ 골때린다 개웃김',
#  '불을 질러버렼ㅋㅋㅋㅋ 🔥',
#  'ㅇ요새 저 파란옷 패션 유행임? 우리집 돼지도 저렇게 입고다니던대',
#  '아니 오늘따라 턱오빠 왤케 잘생겼어요...????\n그리고 궁금한게 있는데 왜 항상 입 주위에 침이 흥건해요?🤤🤤',
#  '켘ㅋ케케케케ㅔㅋ케케케켘케케케케케케케케켘ㅋㅋㅋㅋㅋㅋ케케케케켘 나도 퇴사하는뎈ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ케케케켘케',
#  '내 첫회사 빙그레가 거기 왜 있어?',
#  '숏박스가 진짜 대단하긴 하구나 7시간만에 117만 조회수가 나와버리네',
#  '역시 명품여왕 엄지렐라답게 티셔츠도 ‘셀린 디온’ ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '진짜 꺼지라는데 안꺼지고 계속 말거는거 현실고증 ㅋㅋㅋㅋㅋㅋ',
#  "현실남매 콘텐츠는 '이번에는 뭐가 겹칠까?' 라고 기대하면서 보는데요, 진세 배우님이 제 동생 같아서 킹받아요. 징그럽고 안쓰럽고 애처롭달까? 어릴 때, 그 순수한 얼굴에 골격이 생겨서 아저씨 같은데, 공격 못 받아치는 성격에 한편으로 약해지는 마음이 드는거요. 엄지 배우님의 연기에 공감될수록 더 그런 생각이 들어요 ㅋㅋㅋㅋ 다른 사람은 안 되지만 나만 괴롭힐 수 있는 소중한 동생(?)이죠..! 깨알 디테일도 놓치지 않는 프로다운 우리 배우님들 오늘도 영상 감사해요!",
#  '이몸 불싸르는 것보다 남에 건물에 불싸르는 것을 \n좋아하는 그는 대체 !!',
#  '2:12 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ set this one body on fire 개웃기넼ㅋㅋㅋㅋㅋㅋㅋ 외국인이 들으면 눈이 휘동그래지겠다',
#  '안녕하십니까-> 나가세요 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '2:55 이 부분 원훈님 느낌난다',
#  '아 개웃기네ㅋㅋㅋㅋㅋㅋㅋㅋㅋ 아직 안봄',
#  '내동생이 이거보면 개킹받는데요 나랑 똑같아서 쿡쿡 큭큭 크히히히',
#  '셀린\n디온  ㅋㅋㅋㅋㅋㅋㅋ 개웃기네 ㅋㅋㅋㅋㅋ',
#  '요번건 김대희가 보인다..',
#  '누나가 없지만 리얼하다는건 알겠다',
#  '사진이랑달라요 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '리아할 때 롯데리아 나만 생각했누',
#  '진세 입 옆에 침 하얀거 묻은거까지 디테일좋다;',
#  '이거 보고 실비김치 25박스 시켰습니다.\n명절선물용으로 실비김치가 최고죠 👍',
#  '근데 진짜 궁금해서 그러는데 남동생은 항상 누나한테 저렇게 화가 나있어요?',
#  '귀엽다...',
#  '이번 편은 진세한테서 원훈이가 보이네',
#  '???: 제가 곧 그 건물을 불지르려고 합니다!',
#  '역시 남매라 그런지 두분 붕어빵처럼 닮았네요',
#  '후^^ 내 동생이랑 나보는 줄 알았네…;',
#  '쌍둥인줄 알았네ㅋㅋ',
#  '사랑합니다 쇼박스',
#  '뿌링클에 넘어가는거 개웃기넼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'dion ㅋㅋㅋㅋㅋㅋ',
#  '선댓글 후감상',
#  '와웅 찐남매 떳당 야홋!!!',
#  '진세입니다할 때 존나 웃었네 ㅋㅋㅋㅋㅋㅋㅋ',
#  '엄지님 친언니였으면...',
#  '티셔츠 셀린 디온 인게 개웃김',
#  '2:59 세상에서 제일 행복한 진세 드립 웃참하다가 슬금슬금 미소 올라오니까 존심 때메 입 가리는거 웃는거 찐임ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '아침에 나가있어야 할 사람이 안나가있을때 공감되네 ㅋㅋㅋㅋㅋ 실제로 지각한 이력이 있으니 깨워보는 거임 ㅋㅋㅋㅋ',
#  '진세 진짜 착해 😭저런 남동생이 어디써 ㅠㅠ',
#  '디테일속에 또 디테일을 살리다니 ㄷㄷ',
#  '0:56 My name is Rona Mae',
#  'ㅋㅋㅋ 아우 저희 친누나가 저 괴롭힐때(?)랑 똑같아서 개웃었네요 중간에 도움되는것 같아서 웃는거 까지 똑같 ㅋㅋㅋㅋ',
#  '구글에 불지른데ㅋㅋㄱㄱ',
#  '우리집은 니가 없어야 잘 돌아가ㅋㅋㅋ',
#  '진짜 집은 너 없으면 더 잘 돌아감 ㄹㅇ',
#  '신세 조진 진세야~ 구겨진 얼굴 좀 펴고~',
#  '감이 왜 이렇게 떨어지셨어요 초심돌아오세요',
#  '첨으로 중간에 껐습니다',
#  '갖고싶다 셀린디온',
#  '남동생특) 싫다면서 다 해줌 ㅎㅎ',
#  '진세님 같은 동생 갖고싶어요',
#  '와 진짜 2년 일하고 오늘 막 퇴사했는데 이런 콘텐츠를,,, 안누를수가 없었어요..',
#  '못난이아줌마 막 치명적인척 자연스럽게 연기하는척 오글오글',
#  'ㅋㅋㅌㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ진짜 봐도봐도 우낌ㅋㅌㅌㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋ부장님 쩝쩝ㅋㅋㅋ아윳곀ㅋㅋㅋㅋ',
#  '엌? 오늘 퇴사했는데....ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ\n이게 올라오네?',
#  '나가세요 ㅅㅂ ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '리아라길래 코리아 생각했다..  나만 그러냐',
#  'ㅋㅋㅋㅋㅋㅋㅋ 구글 본사에 불지른데ㅋㅋㅋㅋㅋ',
#  '3:20 턱 졸라 길다 진짜로',
#  '근데 뿌링클 어떻게 참냐고ㅋㅋㅋㅋ',
#  '그래도.. 아무리 싸워도… 누나가 있을때가 그립습니다… 숏박스 남매편 볼때마다 웃지만 웁니다.  누나가 너무 보고 싶습니다',
#  '말라리아랰ㅋㅋㅋㅋㅋㅋㅋ',
#  '진짜 캐웃긴다ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅠㅠ 너무 웃김.... 이 남매 어디서 살고 있을 것 같음',
#  '늘ㅋㅋㅋㅋㅋㅋㅋ증말 재밌어요ㅋㅋㅋㅋㅋ진짜 친오빠랑 저랬을듯ㅋㅋㅋㅋ20대중반에 떨어져살아서 그르치 울오빠 나한테 드래곤볼찾기 시킨X ㅋㅋㅋㅋㅋ',
#  '이 남동생은 가만보면 ㅈㄴ착해 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '아 진짜웃기네',
#  '나도 오늘 퇴사햇는데 ㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋ찐남매 같아용 연기 너무 잘하셔용',
#  '아 밥맛 이아줌씨 또 나왔네',
#  '아 꼴같잖이 이아줌마 또 기어나왔네',
#  '아 짜증나 이아줌마 또 기어나왔네',
#  '2:17 4fire 포인트 ㅋㅋ',
#  '엄지 살쪘다',
#  '와우 대박이에요!~%^*',
#  '3:00 저기서 웃는게 ㄹㅇ임 개웃긴데 반응해주기는 싫을 때 딱 저럼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '오래~~~~~~~~~~~사고 안치고 꾸준히 옆에 있어라!!!!',
#  '슬 재미없다 또 히트없나요????',
#  '남자분 육룡이 나르샤 나왔지 않나요?',
#  '0:26 솔직히 진세님 존잘에 분위기 있다. 눈빛 오지고 약간 지구에 온 사이어인 느낌도 있고 차도남 느낌도 있음.',
#  '간만에 재밌다ㅋㅋㅋㅋㅋㅋㅋㅋ역시 찐남매시리즈가 진리',
#  '광고도 적당히 해주세요 광고 채널인지 개인채널인지..',
#  '흥얼ㅋㅋㅋㅋ',
#  '마지막쯤에 웃긴데 안 웃긴 척 하는 거 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ이거보고 안웃으면 지구인아니다',
#  '와씨,, 밥먹을때  쩝쩝거리는거 아빠뻘이고 어른인거 다치우고 ㅈㄴ 거슬리고 짜증남',
#  '300만 가자!',
#  '이야 개 재밌다(아직 안봄)\n근데 왜 지윤이 엔딩 끝날때 또 먹는얘기 나올것같이 생겼지',
#  '단한번도 안웃음..  다음편 기대할게요 화이팅',
#  '저정도면 누나가 선녀임 왜 싫어하는겨',
#  '찐남매, 장기연애는 진짜 숏박스 시그니처ㅋㅋㅋㅋㅋㅋㅋㅋㅋ진짜 계속 해주세요 제발',
#  '남자친구는 결혼하신다고 들었는데 이후에는 어떤 만남을 추구하시나요',
#  '흥얼🌸',
#  '숏박스의 근본 장기연애 찐남매 편은 항상웃기네요 ㅋㅋㅋㅋ\n컨텐츠 만드시면서 때로는 좋지않은 반응들이 있을 수 있는데 그거에 속상해 하거나 기죽지 마시고\n피드백 잘 수용해서 지금처럼 좋은 영상 부탁드려요🙏숏박스 화이팅🤍',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 아 너무 좋다 이거 누나한테 정말 당한적 많아... 이런 것 말고도 많은 상황극...\n특히 맞는것들 욕먹는 것들',
#  '노잼 되어가는 숏 박스',
#  '원훈이오빠 내놔',
#  '지렐이 셀린디온 티 개귀여워 ㅋㅋㅋㅋㅋㅋ',
#  '두분 찐남매에요?\n하관이 비슷하네요...',
#  '이거즤',
#  "다음 에피소드로 '백조렐라' 만들어주세용ㅋㅋㅋ",
#  '셀린(디온)ㅋㅋㅋㅋㅋㅋㅋ',
#  '리아라고 해서 코리아 인줄 알았는데 말라리아랰ㅋㅋㅋ 씹ㅋㅋㅋㅋㅋㅋㅌ',
#  '재미없다. 요번편',
#  '진세님 틴트 뺏어 쓰셨나요?',
#  '이와중에 엄지 티셔츠 셀린 ‘디온’',
#  '진세님은 툴툴거리면서 못이기는척 누나 부탁들어주는 설정 개똑같음 ㅋㅋㅋ\n\n면접에서 회사 건물에 방화 예고하는 사람되는 거 너무 웃겨요 ㅋㅋㅋㅋㅋ',
#  '당연히 코리아인줄알았는데 말라리앜ㅋㅋㅋㅋㅋㅋㅋ',
#  '13살 어린 제 남동생이 보고 공감할까 걱정이네요~!\n우린땐(마음속으로 욕했을텐데)싼 맛난거 사주고 용돈주면서 약올라하는거 귀여웠는데...\n이제 서른넘어서 안 귀여워요^^',
#  '하..동생이 없는데  동생이 있는거 같은 ㅎㅎㅎ👍👍👍👍👍',
#  '사이좋은 남매도 많아요~',
#  '엄지님 티셔츠보고 와 숏박스 이제 명품 협찬도 받나?! 했는데 셀린디온이었네..',
#  '구글번역기 개웃기다ㅋㅋㅋ 구글에 불질렀대ㅋㅋㅋ',
#  '정말 엄지공주 능력 빼고는 이수빈하고 너무 똑같네요. 이수빈 보고있냐 방좀 치워',
#  'ㅋ 실비김치가 배송이 늦죠',
#  '빙그레 까는거 아니면 광고 둘 중에 하나다',
#  '0:37 안경잽이들의 애환. 시력 나빠지는 게 안경다리로 눈 몇 번 찔러서인듯.\n1:33 남동생 축구팀 유니폼 바지 뺏어입는 거 누나ㄴ들 특징. 드라이핏 개꿀.',
#  '진세 어깨 섹시해.',
#  'ㅋㅋ 이직 화이팅!',
#  '뭐야 5시간이나 지났는데 조회수 85만밖에 안됨??? 인기가 너무식었네요 분발하시길 바랍니다',
#  '연차내고 집에있는거 당연한거 아닌가요....??',
#  '면접볼 때 잡초로 변신해서 뽑아달란 멘트는 어디든 있구나 아놔 ㅋㅋㅋㅋㅋ',
#  '누가 면접왕이형 좀 불러와보셈;;;',
#  '재미없어요..',
#  '기대를 저버리지않는 숏박스 ! 역시 아직 보진 않았습니다',
#  '마지막에 누나 합격한 줄 알고 좋아하는 디테일 ㅋㅋㅋㅋㅋ 역시 가족밖에 없음',
#  '남매랑 광고하는게 제일 재미없음 솔직히,, 걍 장기 연애나 다른거 보고싶어 ㅠ',
#  '숏박스 요새 쫌....',
#  '제일가는 포테이토 칩 ㄹㅈㄷ ㅋㅋㅋㅋㅋㅋㅋ',
#  '근데 지윤님 눈 주위 보니까 진짜 자다 방금 일어나신거 같음ㅋㅋㄱ어제 라면 한 세봉 하셨나 왜케 부었지ㅋㅋㅋㅋ',
#  '안봐도 재미있어서 안볼 예정',
#  'ㅋㅋ 겁나 웃곀ㅋㅋ',
#  '제 누나가 여자가 화장 한거랑 안 한거랑 얼마나 다른지 보여줬는데 깜짝 놀랐어요!! 이 사연 반영해주세요!!',
#  '새입니다 진 세입니닼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ순발력 좋은척하지말ㄹ랰ㅋㅋㅋㅋㅋㅋㅋㅋㅋ진세입니다~~~~~~~~숏박스 사랑해요♥️',
#  'ㅋㅋㅋ츄리닝 반반 나눠입는 디테일',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ또각또각 힐 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ아 영혼없는 동생 어쩔거야 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '아씨 졸라 웃겨서 애기 깰뻔',
#  '세상에서 제일 가는 포테이토칩 개웃기네 ㅜㅜ',
#  '역시 숏박스 남매편 젤 재밌어 ㅠ',
#  '둘이서 진짜 남매같아요',
#  '합격',
#  '찐형제->찐남매->찐자매..?',
#  '너무 재밌어서 좋아요 두번 눌렀어요~ㅎㅎ',
#  '하여튼 투덜거리면서 다 하긴 한다니까 ㅋㅋㅋㅋㅋ',
#  '김치는 역시 실비김치세요.',
#  '엄지렐라님 셀린디옹 티셔츠 구매처줌여 :)',
#  '그래도 마지막에 합격한줄알고 같이 기뻐해주려하는 디테일ㄷㄷ',
#  '티셔츠 ㅋㅋㅋ 셀린디온 ㅋㅋㅋㅋㅋ',
#  '티셔츠 셀린디온 ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '점점 재미가....',
#  'ㅋㅋㅋㅋㅋㅋ 넘 재밌어서 시간순삭😆',
#  '엄지누나 놀면 뭐하니?! 휴식보다 숏박스가 우선이야',
#  '아 진짜 잘 짠다',
#  'ㅠ ㅠ ㅠ ㅠ 아 나 저번주에 실비 김치 시킨거 아직 안왔는데 짘차 갱 ㅅ기넼ㅌㅌㅋㅋㅋ',
#  '흥얼~~ 에서 찐으로 터졌네ㅋㅋㅋ',
#  '이걸 웃으면서 볼 수 없는 사람들이 있을 겁니다. 취준생들 힘내세요!',
#  '깨워주는것 자체가 남매아님',
#  '뿌링클?\n나이스~ㅎㅎ',
#  '아ㅋㅋㅋㅋㅋI will set this one body on fireㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ킹받는데 꽤 신박하잖아?ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '역시 털리는게 정석인 진세님ㅋㅋㅋ',
#  '아ㅋㅋㅋ 저도 언니한테 왤케 귀칞게 구냐는 말 자주 하는데ㅋㅋㅋ다들 그런가봐요',
#  '우리 엄지렐라 오랜만이에요~~~',
#  '웃겨서 두번봤어요',
#  'ㅋㅋㅋ그래도 핏줄이라고 출근시간에 집에있으니 진심으로 걱정하는 저 얼굴이 찐텐이넼ㅋㅋㅋㅋㅋㅋ',
#  '뭐임 썸넬 둘이 왜케 닮음..? 분장한거에요?',
#  '티셔츠 셀린디온 뭔뎈ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '나 고정 좀.... 해줘요',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '티셔츸ㅋㅋㅋㅋㅋㅋㅋ셀린디온ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '왜 우리집이랑 비슷하냐 k남매는 다 비슷한가...?',
#  '압박 질문은 다 패스~ ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '정장에 나이키 반바지 ㅋㅋ',
#  '썸네일 엄지님 웃참하는거 같아서 쪼개면서 들어옴',
#  '항상 잘보고 있습니다.응원합니다!!',
#  '너무 몰입해서 남동생도 없는데 벌써 귀찮고 든든하다…',
#  'ㅋㅋㅋㅋㅋ  치킨은 못참치 ㅋㅋ',
#  '난 그냥 누나가 필요가 없어ㅋㅋㅋㅋ',
#  '그만 보고싶네\n어짜피 또 웃기는거..',
#  '현실남매는 대화자체를 안한다 리얼하지못하네요 ㅉㅉ',
#  '로나코 ㅋㅋㅋㅋ ㅅㅂ',
#  'ㅋㅋㅋㅋㅋㅋㅋ아 진짜 찐남매가 제일조아',
#  '죄송한데 ,, 그만 밝히시죠,,, 친 남매인거 ㅋㅋㅋ',
#  '또각 또각 또각 ㅋㅋㅋㅋㅋㅋㅋ',
#  '나가세요에서 터짐ㅋㅋㅋㅋㅋㅋㅋ',
#  '진세님이 점점 잘생겨보여요....',
#  '추천먼저 누르고 시청합니다!!!!',
#  '아 미친 동생은.티 누나는 바짘ㅋㅋㅋㅋㅋㅋㅋㅋㅋ나이키 나눠입기 ㄹㅇ 찐이곸ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '1:01 ???:리아..에밀리아땅',
#  '셀린디옹ㅋㅋㅋㅋ',
#  '난 그냥 누나가 필요가 없어 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '남매시리즈개좋아',
#  '친한데?ㅋㅋㅋㅋㅋ보통대화를안하는뎈ㅋㅋㅋㅋㅋ',
#  '와 ㅁㅊ 난 자매인데도 개똑같음ㅋㅋㅋㅋ 나는 항상 동생한테 부탁할거 있고 동생은 겁나 툴툴거리면서 결국 해주는ㅋㅋㅋㅋㅋㅋ',
#  '원훈이형 왜 안나왔어요 ㅠㅠ',
#  '면접 걍 탈락',
#  '셀린 디온 ㅋㅋㅋㅋ 저런 티셔츠는 어디서 구해요 ㅋㅋㅋㅋㅋㅋㅋ',
#  '순발력 좋은척 하지말라고 해놓고 지도 웃겨서 웃참하는거 ㅅㅂ 걍 나같음',
#  '진짜 친남매같애 턱 닮았어 ㅋ',
#  '웃음 참느라 콧구멍벌렁거리면서 봤네ㅋㅋㅋ',
#  '찐남매 진짜 너무웃겨요ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '완전 재밌어요 ^^ 좋은 영상 감사합니다!',
#  '엄지윤 진짜 짜증나요',
#  '엄지 계속 일해라 !!',
#  '왜요.. 리아 이름 예쁜데... 제 이름인데.. 말라리아는 생각도 못했어요. 가끔 자기소개할때 롯데리아라고는 해요.',
#  '셀린 디온 신경쓰여서 내용 스킵되네',
#  '아ᆢ셀랜디옹 티셔츠 진짜 웃기네\n셀렌느ᆢ 디올ᆢ 콜라보 라임 즥이네ㅋㅋ\n저번에 피타고라니 티셔츠 졸라웃겻는데ㅋㅋ\n찐남매 시리즈 누나 디셔츠의 디테일 졸잼ㅋㅋ',
#  '원훈님 댁이네요?? ㅋㅋㅋㅋㅋ',
#  '리아할때 나만 코리안줄암…?',
#  '나가세요 ㅋㅋㅋㅋㅋㅋ',
#  '우리누나도 이거 보고 이직 좋은데로 했음 좋겠다 ㅎㅎ',
#  '개리얼하다ㅋㅋ 물론 저 또한 아직 보기전입니다',
#  '나도 저런 동생..나듀',
#  '진세사랑♥️',
#  '진짜  퇴사 마려워지네요ㅋㄱㅋ',
#  '뿌링클? 특.\n안줄거임 ㅋㅋㅋㅋㅋ',
#  '티셔츠 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ 셀린 디온 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ셀린느도 아니고 디올도 아님ㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋ 아 누나였어',
#  '여동생만 둘 있는 본인은 누나가 진짜 몹시 몹시 필요합니다아아 이왕이면 두명 난 제발막내로....',
#  '전력회사 면접봤는데 망했다 생각하고 나갈때 불끄고 나가니까 합격받음',
#  '하~~  재미없다  ㅡ,ㅡ;;',
#  '셀딘 디온 티셔츠ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '찐남매가 제일재밋음 ㅋㅋㅋㅋㅋㅋ연기진짜잘하네요ㅋㅋㅋ',
#  '티셔츠 셀린디옹인거 첨알았네ㅋㅋㅋ',
#  '근데 어떻게 하면 세상 모든 개를 위한날을 클릭했는데 1빠로 나올수 있는거죠?',
#  '진짜 너무 재밌네ㅋㅋ',
#  '아니 ㅠㅠ  엄지 옷 이름 본사람  ㅠ 지존웃기네 셀린디온 ㅅㅂ ㅋㅋ   내가  어처구니가 읎어서  ~!  쪼옥 ㅋ',
#  '잡초입니다 꽃옆에서 잡 초칩니디',
#  '진세님 상의 엄지님 하의 세트..? ㅋㅋㅋ 찐남매 디테일??',
#  '1:18 이거 동생들 형, 누나 가 뭐 사준다고 하면 애써 못이기는척 하는거 개공감 ㅋㅋㅋ',
#  '찐남매 썸네일은 못 참지 ㅋㅋㅋㅋ',
#  '삼성엘지카카오빙그레?',
#  '엄지렐라 나와서 조아요..ㅎ',
#  '실제로 보고 영상에 보니까 더반가워요오 같이 사진 찍고싶었는데 아쉬워요우🤍',
#  '실비김치 현실고증 오졌고ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '볼링장 해주세요 ㅋㅋ',
#  '"야, 너 취업된거야."',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '셀린디온 뭐얔ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '안녕하세요 유리 라고해요',
#  '현실남매까진 재밌게 봤었는데 큰일났네',
#  '숏박스는 이거지',
#  '실비김칰ㅋㅋㅋㅋㅋ',
#  '실비김ㅋㅋㅋㅋㅋㅋㅋ칰ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '내동생은 진짜 착한거구나 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ개웃곀ㅋ',
#  '갑자기 김치가 화악~ 땡기넹',
#  '순간 썸내일 보고 빵떡인줄',
#  '3:05 웃기긴한데 혈육이 웃겨서 웃는건 자존심상함ㅋㅋㅋㅋㅋ',
#  '위아래 옷 나눠입은거 ㅋㅋㅋㅋㅋㅋ 디테일 찐이다',
#  '재밌당,, 역시 유명해져도 괜찮네요',
#  '원훈씨 연기가 나날이늘어가요~^^',
#  '큰일났다.. 조진세가 잘생겨보이기 시작했다..',
#  '뿌링클 ㅋㅋㅋㅋ',
#  '진세님 파마 잘어울리세요',
#  '진세입니다 개웃기네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '남매가 저런 상황극하는 것부터 좀 이질감들긴 하지만...ㅋㅋㅋ',
#  '사실 예전보다 웃기거나 공감되지는 않지맛 진세님 연기력때문에 끝까지 보게 되네요',
#  '진세 입술 치약묻은거임?',
#  '역시 숏박스야! 대단해 이제 볼게요',
#  '왤케짧아ㅜㅜㅜ',
#  '엄지 졸라 기여움 ㅋㅋㅋㅋㅋ',
#  '아 숏박스!! 보기가 너무 아까워!! 3분은 너무 짧아!! 아껴볼거야!... 내후년쯤 봐야겟다',
#  '알고보니 실비김치때문에 연차냄',
#  '현실남매는 아예 사람취급을 하지 않음ㅋ\n환타지 재밋다 캬캬',
#  '나가 ㅋㅋㅋㅋㅋㅋㅋ',
#  '꿈에서 본 것 같았는데 생각해보니 저 대화를 남동생하고 실제해서 기시감이 쩔었다 ㅋㅋㅋㅋㅋㅋ',
#  '3:08 아닌 척 툴툴대지만 막상 자기 누나 붙었나 싶어 기대하는 톤으로 묻는 게 ㄹㅇ',
#  '깨울때 하는말 왜이렇게 똑같지?ㅋㅋㅋㅋㅋㅋ',
#  '셀린 디온 티셔츠 센스만점입니다',
#  '언니 일단 안경부터 좀 닦는 게 어떨까요',
#  '아 진짜 아직 안봤는데 너무 웃김',
#  '진짜 연기력 울트라캡숑짱 ㅋㅋ 먼말인지 알지 흐흐흐',
#  '아 진짴ㅋㅋㅋㅋㅋㅋㅋ면접에서 건물에 불싸지른다고 예곸ㅋㅋㅋㅋㅋㅋ',
#  '뿌링클!',
#  '셀린디온ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '아 진짜 미쳤나봐ㅋㅋㅋㅋ 실비김치 개터졌넼ㅋㅋㅋㅋㅋ',
#  '저는 남매가 아니라서 잘 모르겠지만 티격태격 해도 대화나 상횡극이나 뿌링클은 되네요 부럽',
#  '오늘도 개웃기넹',
#  '♥♥♥♥♥♥♥ 꺄아아악 찐남매 ♥♥♥♥♥♥♥♥',
#  '오늘따라 왜 진세님이 잘생겨 보이지..?',
#  'ㅋㅋㅋㅋ',
#  '빙그레는 ㄹㅇ 쓰레기임',
#  '순발력 좋은척 하지마 미친놈아 이부분 왜케웃김ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ\nㅋㅋㅋㅋㅋㅋㅋㅋ진짜 저기서 현웃터졌네 아 진짜 내사랑 찐남매 시리즈 ㅜㅜㅜㅜ 숏박스에서 찐남매가 젤 재밌어여 ㅜㅜㅜㅜㅜㅜㅜㅜㅜ',
#  '03:07 흥얼 귀엽다 ㅎㅎㅎ',
#  '어휴 누나가 없어서 다행인듯 ㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋ그래도 다 해주네 ...동생착하닼ㅋㅋㅋㅋㅋㅋ',
#  '실비김치가 뭔가요? ㅋㅋ',
#  '이제야 내가 아는 숏박스 같네요 다행입니다 형누나들 사랑해요😍',
#  '진세 뭐 바구니니 왜 다 받아주는건데 ㅋㅋㅋㅋ 너무좋아',
#  '아 세상에서 제일 가는 포테이토칩 미친거같아요 진짜 ㅠㅠㅠㅠㅠㅠㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '진세씨 점점 잘생겨져가고 있는데 !!!\n이사실을 알고 있는가?? ㅋㅋ\n낼 결혼식장에서 진세씨 우는거 아니야 ㅋㅋ',
#  'ㅋㅋㅋㅋ뭔가 남매는 아니지만 공감되는 이느낌은 뭐지?',
#  '흥얼 ㅋㅋㅋ',
#  '숏박스 시리즈중에 다른 컨셉은 그냥 숏무비 느낌인데 찐남매랑 장기연애 시리즈는 진짜 리얼같아서 너무 재밌음',
#  '5시간 전 내 가 한말ㅋㅋㅋ',
#  '1:10 엌ㅋㅋㅋㅋㅋㅋㅋㅋ 진세님 대사 예상 못하고 있다가 뿜음',
#  '한달치 몰아보려고 안보고있지롱',
#  '이러니까 요새 기업에서 뽑을 사람이 없다고 하는구나',
#  'ㅅㅂ 옷이 셀린느인줄알았는데 셀렌 디온이네\nㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '선화동 실비김치???',
#  '되도 않는 노래 다 처불렀나 슬슬 기어나오네',
#  '셀린은 아니지않냐',
#  '보다가 알았는데 우리집 소파랑 똑같누',
#  '나도 남매있으면 저럴까? 외동 ㄴㅇㅅ',
#  '진세 왜 잘생겨보이지? 킹받네',
#  '진세 ㅈㄴ 짜증나는 표정 잘내네 ㅋㅋㅋㅋㅋㅋㅋㅋ ㄹㅇ',
#  '오늘 면접 보고왔는데…..',
#  '집옷이 셀린느 ㄷㄷ 역시 숏박스',
#  '모든 남동생에게 누나는 돼지다',
#  '힐 안돼요',
#  '셀린디온ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 티셔츸ㅋㅋㅋㅋ',
#  '남매들 종특..절대 이름을 부르지 않고, 성별불구하고 욕과 돼지가 난무한다ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '이거 실비김치 ppl인가요?\n갑자기 먹고싶은데요!?',
#  '하기 싫지만 그걸 또 받아주는 진세님 ㅋㅋ',
#  '돈 벌려고 지원한거지 무슨 지원 동기여…',
#  '뿌링클은 못참짘ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '그래도 누나라고 마지막에 어디 된건줄알고 기대하는거 넘좋당',
#  '엄지님 또각또각 걸어오는 모습 킹받네요ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '오빠와 여동생 컨셉으로도 찍어주세요!!!!🙏🏻',
#  '이렇게 해도 뿌링클 받는건가요?',
#  '진세 왜 점점 잘생겨짐?',
#  '나이키 셋업 누나가 바지 뺏어입은거 현실고증 미쳐 ㅋㅋ',
#  '아니 시간 왜케 빨리가 ㅋㅋㅋㅋ 너무 재밌어서 순삭이네 ㅋㅋㅋ',
#  '존나 하기싫은대 뿌링클걸고 면접봐주는거 개웃기네 ㅋㅋㅋㅋㅋㅋㅋ 디테일까지 살아있다',
#  '면접관 함 해주고 뿌링클은 너무 혜자 아닌가?? 천사네 누나가..',
#  '넘 웃겨여.',
#  '로나 코 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 난 버터 치킨에 찍어먹다 뿜었다 ㅋㅋㅋ',
#  '안녕 클레오파트라 02:57',
#  '3:07\n😋',
#  '착한동생 특: 귀찮아하면서 할건 다 해줌ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '찐남매랑 장기연애 진짜ㅠㅠ 내 최애',
#  '👍',
#  '보통 노래한곡 시간이랑 비슷한 길인데 시간 순삭이네 순살치킨 시켜야지 김치 꺼내놓고 대기해야지',
#  '엄지한테서 왜\n원훈이형이보이냐.....',
#  '아 진짜 둘이 개웃겨ㅋㅋ 댓글 달았으니까 이제 봐야지',
#  '실비김치는 인정이지...연차내고 놀면서 뿌링클 시켜먹을때 느끼하니까 맵싹하게 먹으면 딱이다 진짜.',
#  '지금당장 면접자 역할을 해주지 않으면 턱으로 찍어버릴것이다',
#  '확실히 믿고보는 찐남매ㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '짧고 굵다',
#  'ㄹㅇ 연기쩔어ㅋㅋㅋㅋㅋㅋ',
#  '입박면접 탈압박 ㅋㅋㅋㅋㅋㅋ',
#  '실비 김치ㅋㅋㅋㅋㅋㅋ',
#  '자매도 해주세요!',
#  '와 나도 이직해야하는데..\n면접관 좀 해주세여 진세님😎',
#  '실비김치는 못참짘ㅋㅋ',
#  '퇴직서 오늘 제출하면서 월요일날 다시 이야기하기로했는데 바로 숏박스 퇴직올라오는거 운명이네 사랑해',
#  '왤케잘생겨보임?ㅋㅋ',
#  '금요일 저녁 못참치',
#  '저번영상에서 너무재밌어서 구독두번눌렀습니다 그런데 이영상은 두달만에보네요',
#  '실비김치 아싸~ 나도 누나 있고 싶은데? 🥲',
#  '엄지 티 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ셀린디온 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅁㅊ ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '뿌링클 ㅋㅋㅋ 아 미쵸 ㅋㅋ 진세씨 살앙해요♡♡',
#  'ㅋㄱㅋㄱㅋㄱㅋ 이시리즈 너무 좋아..',
#  '요새 저런 굵은테 김구 안경이 유행인가..',
#  '초록색잡초 ㅋㅋㅋㅋㅋㅋㅋ',
#  '세상에서 제일가는 포테이토칩 개킹받넼ㅋㅋㅋㅋ\n어차피 압박 딜 1도 안박힘',
#  '와 손석구 꿈 꾸는데 깨워? 이건 진짜 맞아야됨',
#  '빙그레 유료광고인줄 알았네요',
#  '뿌링클 ㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋ 아레알 뿌링클은 못참지....',
#  '혹시 진세님이랑 지윤님 바지 나눠입은 건가요? 엄지님 바지 나오고 부터  진짜 궁금했어요',
#  '엄지 점점 원훈이형 닮아가는디😂',
#  '나가세욬ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '뿌링클? 할 때 누구보다 빨랐다',
#  '보지마 멈춰 손가락 넘춰라 \n진짜 재미 있어서 아꼈다 내일보는게 나을걸',
#  '🙃🙂🙃🙂🙃🙂🙃🙃😂😂',
#  '숨 쉴수있게 해주셔서 감사합니다',
#  '기다렸다구',
#  '뭔가 숏박스 만의 찐자매 도 보고싶긴한데.. 진세 여장시켜서 해보자!',
#  '구글에 불 지르겠대 ㅋㅋㅋㅋㅋ',
#  '역시 엄지',
#  '엄지렐라님 셀린 디온 티셔츠 32차 공구 언제 열리나요?',
#  '진짜 남매라고 해도 믿겠어요~\n너무 찰진연기!~~~~\n두분 멋져요👍',
#  '진세 ㅋㅋㅋ 다 해주네 ㅋㅋ',
#  '아유 얄미워 ㅎㅎㅎㅎ 😆',
#  '공감 백프로요 대박 ㅋㅋㅋㅋ',
#  '리아에서 빵 터졌다.. 나도 영문이름 리아 어? 괜찮은데? 했는데 말라리아 ㅋㅋㅋㅋㅋ',
#  '새라고 하니까 진세 이러네 ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '남매니까 말투도 비슷하게 하신건가요??',
#  'ㅋㅋ 집은 없어도 잘돌아간데 ㅋ',
#  '역시 찐남매가 찐야',
#  '잘봤습니다 ㅎㅎ',
#  '둘 다 존귀',
#  '_ㅋㅋㅋㅋㅋ 뿌링글은 못참지_',
#  '실비김치가 맛있긴하지',
#  '네이버 면접가서 잡초얘기하는 인간 분명히 있다..ㅋㅋ',
#  '요번편은  대사가 아주 찰지다 ㅋㅋㅋ',
#  'ㅋㅌㅋㅋㅋㅋㅋ 처음에 볼 위에 핸드폰 있는게 출근시간에 일어나서 회사에 연차쓰겟다고 전화하고 바로 다시 잠든건가',
#  'ㅋㅋㅋㅋㅋ찐남매 연기무어냐ㅋ',
#  '로나 코 ㅋㅋㅋㅋ',
#  '숏박스 객원 진세님은 이제는 원 맴버로 너주세요~~',
#  '재미없다 이제',
#  '면접 떨어져서 하루종일 우울한 상태로 있는데 영상보면서 나도 모르게 큭큭대고 있는 나 자신 발견ㅎㅎ',
#  '턱남매 보기 좋다',
#  '남매랑 장기연애 요거 두개가 젤 조아욬ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '지윤님 티셔츠 엄지렐라 명품녀 컨셉 ㅋㅋㅋ 숏박스 속 엄지렐라 깨알 디테일!',
#  '실비김치......먹고 구급차 부를뻔 한 기억이....',
#  'bh26b',
#  '저거 나이키 파란색 위아래 세트인거 같은데 바지 나시 나눠입은거 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '좋았다 엄지♥️ 진세♥️',
#  '뭐임진짜언제영상나옴?',
#  '3:05 진세입니다!할 때 웃참하는 연기 리얼하닼ㅋㅋㅋㅋ',
#  '코로나 로나 ㅋㅋㅋ',
#  '티셔츸ㅋㅋㅋㅋㅋㅋ Dion zㅋㅋㅋㅋㅋㅋㅋㅋㅋ 개웃기넼ㅋㅋㅋㅋㅋ',
#  '뿌링클? 대기업? 김치? 무슨광고지? 광고가 들어잇긴햇던걸까 ㅎㅎ',
#  '엄지윤 누나 영어 진짜 잘한다',
#  '어 영상 올라왔네 지금못봐여 좋아요만 누르고 갈게요',
#  'ㅋㅋㅋ동생은 은근 무시하면서 걱정해줌\n귀여운것',
#  '오늘 조진세 오ㅑ케 잘생겨 보임? 나 남자임',
#  '이런 거를 해주세요 ... 개조아',
#  '야 이거 빨래한 샠이 누구냐?',
#  '보기 전 벌써 웃고있음',
#  '👍😎🤩👏',
#  '누나들은 진짜 동생들 존나 귀찮게햌ㅋㅋㅋㅋㅋㅋ',
#  '02:55\n이 부분 원훈이형이랑 싱크로율 58000%이다\n사랑하면 닮는다더니...',
#  '방화예고 미쳐 ㅋㅋㅋㅋㅋㅋㅋㅋ악ㅋㅋㅋ엄청웃었넼ㅋㅋㅋ',
#  '진세님 입술은 항상 마를일이 없구나',
#  '역시 숏박스!!',
#  '진짜 현실적인게 존나 웃기다',
#  '마이 네임 이즈 로나 ㅋㅋㅋ 코로나 ㅋㅋㅋㅋㅋㅋㅋ',
#  '찐남매 제일 재밌어 ㅋㅋㅋ',
#  '세상에서 제일가는 포테이토칩',
#  '엄지누나 자취하고 진세형이 놀러가는 그런 시나리오도 해주세요 ㅋㅋㅋㅋㅋㅋ 막 엄지누나 냉장고 털고 그런거 남자 팬티있고',
#  '마법의 단어 : 뿌링클',
#  '또올려주세요',
#  '와 이편 리얼해 ㅋㅋㅋㅋㅋㅋㅋㅋ난 누나가 필요가 없어 ㅋㅋㅋㅋㅋ',
#  '왜 양말 신고 자요 ㅋㅋㅋㅋㅋ',
#  '셀린디온 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '합격전화보다 설레는 실비김치 배송전화 머릿속에선 이미 짜파게티 끓이고있음',
#  'ㅋㅋ',
#  '일단 추천누르고 본다ㅋ',
#  '돼지새낔ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '실비김치는 킹정이지',
#  '엄지 티셔츠 셀린디온 뭐야 ㅋㅋㅋㅋㅋㅋㅋ 타이타닉돋넼ㅋㅋㅋ',
#  '코리아인 줄 알았는데 말라리아ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 진짜 이런 센스는 어디서 나오는 건지',
#  '제일가는 포테이토칩 ㅋㅋㅋㅋㅋㅋ',
#  '조진세 왜 저래 왜 잘생겨짐 내 눈이 이상한가',
#  '취준이라 더 웃기네 ㅋㅋㅋ',
#  '누나 바지랑 동생 상의 세트인거 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 누나가 동생 바지 뺏어입은듯한 디테일?',
#  '숏박스 구독자 300만명 가즈아~! 힘내세요!! 300만때 300원짜리옷입고 사람많은곳 홍대 등 가서 춤춰주세요 조진세님이 쳐주셨으면 합니다~!',
#  'MBTI 컨텐츠도 해주셨으면 좋겠어요!!!!!!!!',
#  '기대되서 보기도 전에 좋아요 눌렀다ㅋㅋ\n공감하시는분 좋아여',
#  'ㄹㅇ 남동샹 있는 누나 입장에서 개공감^^ 그리고 저 뺀질한 남동생 태도에 한소리 하다가 결국 싸우고 폭발함.',
#  '말라리앜ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '집은 너없어도 잘돌아가요 \n지식인에서 퍼온데 ㅋㅋㅋㅋ',
#  '누나 면접질문 내주는거 ㅈㄴ공감;;',
#  '진세님이 입고있는 상의 유니폼, 하의는 엄지온니가 입고있는 현실남매 디테일ㅋㅋㅋㅋㅋ',
#  '진짜 무심한 목소리로 피드백 주는거 겁나 웃기네 ㅋㅋㅋ 영어 번역기 반박 개웃기네 ㅋㅋㅋㅋ 남동생 캐릭 개쩌는듯 댕청미 내는 누나 캐릭도 오지는듯 ㅋㅋ',
#  '어 여기서 실비김치 먹방 기다리면 되는거죠???',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ그래도 다 해주는 동생~',
#  '한시간 만에 조회수 38만 ㄷㄷ',
#  '둘이 찐남매 연기가 아니라 ㄹㅇ 닮았는데?',
#  '진세 오늘 왜 잘생김',
#  '볼때마다 너무 재미있어요 \n항상 알람만 기다리고 있어요~',
#  '진짜 개 재밌네 ㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋ',
#  '아니 왜 이렇게 웃겨',
#  '근데 진짜 너무 닮았어 찐남매인줄알았어요 ㅎ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ개웃겨',
#  '누나 진짜 필요 없어보임.. 꺼져!!!!',
#  '숏박스 굉장하다',
#  '옷 디온이 왤케 웃기냐ㅋㅋㅋㅋㅋㅋㅋ',
#  '2:23 ㅋㅋㅋㅋㅋ',
#  '역시 이 시리즈는 날 배신하지 않아',
#  '굿.',
#  '퇴사왕으로서 지나치기 어려운 제목이었습니다',
#  '빙그레 현직자입니다.\n혹시 광고인가요?\n저기에 이름나올 레벨이아닌데..\n저도 하반기 대기업 쓸겁니다 같이 가요\n\n혹시..엄지님의 바나나맛우유사랑으로 대본에 넣어주신거라면 ~_~',
#  '역시 쏫박스최고....',
#  '찐남매 기다렸다아',
#  '우리집이네….?ㅎ',
#  'ㅋ ㅋ ㅋ ㅋ ㅋ ㅋ ㅋ ㅋ ㅋ ㅋ ㅋ ㅋ \n나 너무 웃기잖어ㅓㅓ',
#  '유튜브 재미있어요 엄청',
#  '제일가는 포테이토칩 이러고 있넼ㅋㅋㅋㅋ',
#  'ㅎㅎㅎ 진짜 남매 확정!',
#  '어제 저희 지역오셔서 사진 찍어주셔서 감사합니당',
#  '또 부산 와줘용 핑계로 부산 또 가게요♥️ㅋㅋ',
#  '실비김치 존나 웃기네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '연기 진짜 잘하시네요 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '진세님 입 옆에 허연거 일부로 그러신거 맞죠? 하허허',
#  '뿌링클?!',
#  '3:21 \n\nㅇㄱㄹㅇ',
#  '🤣👍🏻👍🏻👍🏻👍🏻👍🏻',
#  '후 진짜 사랑할수밖에없다. ㅜㅜ♡',
#  '그래서 실비김치 먹방은 언제 올라오죠?',
#  '요새 줫나노잼이네;;',
#  '오랜만에 엄지유니언니 너무 귀여워어어요우',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ뿌링클?ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ우리동생이랑똑같누 턱세오빠알라뷰',
#  '셀린 디온 ㅋㅋㅋ',
#  '뻥튀기 아저씨야',
#  '쎌린 디온 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '엄지언니 보고싶었어 ❤️ 진짜 사랑해 세상 제일 귀여워진짜',
#  '우리집 몰카찍은거 올린줄 ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '둘다 진짜 미치게 귀엽고 2:56 지윤님 표정 진세님 평소 표정이랑 똑같은것도 너무 웃김 ㅋㅋㅋ',
#  '디온ㅋㅋㅋㅅㅂㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '찐남매랑 장기연애가 젤 재밌어 ㅋㅋㅋ\n결과적으로 엄지렐라가 나올때가 제일 재밌는...?!!',
#  '세상에서 제일가는 포테이토칩 ㅋㅋㅋ',
#  '확실히 엄지가 나오니까 몰입이 배가 된다. 엄지짱',
#  '숏박스최고!',
#  '저런 동생있으면 좋겠다. 나도 동생임',
#  '닮았네ㅋㅋㅋㅋㅋㅋ',
#  '역시 금요일을 기다리는 이유는 바로! 숏박스!',
#  '잠만 진세님 점점 왤케 잘생겨짐 하',
#  'ㅋㅋㅋㅋ 손석구꿈 ㅋㅋㅋㅋㅋㅋ',
#  '리아할때 코리아일줄..',
#  '손석구 꿈이면 못 참지 ㅋ ㅋ ㅋ ㅋ 💘',
#  '아 졸라 못생겼어 이 말에 응 니 동생이야 이거였으면 더 웃겼를텐데 제 동생이 맨날 하는 말이거든요 \nㅇㅇ 니얼굴 나 닮음',
#  '나이스 찐남매',
#  '모의면접 봐주니까 냉장고 문 똑똑똑~ 하고 안녕하십니까! 하던 호적메이트 생각나네요ㅋㅋㅋㅋ',
#  '참고로 전 한때 친동생(여)이랑 5년동안 쌩깐적도 있었습니다 저 정도면 사이 진짜 좋은 남매입니다..',
#  '와 근데 진세씨는 머리가 너무 예쁘네요.',
#  '실비김치  못참지ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '흥얼~ \n개귀엽ㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ레전드',
#  '또각또각ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '숏박스분들은 아직도 댓글 하나하나 다 보시네...대박........정성 진짜 대박이에요ㅠㅠ❤️',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 오늘 영상 꿀잼 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '그냥 찐남매보다 이거찍으면서 거 찐남매된듯….!',
#  '그래도 동생이라고 누나가 합격한줄알고 기대하는보소 ㅋㅋㅋㅋㅋㅋ',
#  '진짜 미쳤다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '누가 첫째인지 정말 궁금했는데!!!K 장녀였군여!!!',
#  '티셔츠 셀린디온이네ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 타이타닉ost 함 불러주이소',
#  'ㅋㅋㅋ존잼 ㅋㅋ엄지 졸귀',
#  '면접편 만들면 재밌겠다',
#  '코리아🇰🇷',
#  '진세님 엄지님 너무 귀여워요\n믿보숏이네요 XD ♡',
#  '엄지 티셔츠 가수 셀린디옹 넘웃겨 ㅋㅋ 순간 명품인줄 ~',
#  '2:59 좋은 척 하지 말라하면서 은근 만족한 듯? ㅋㅋㅋㅋㅋ',
#  '썸네일 뭔가 둘이 닮았네 의도한건가',
#  '실제 남매는 말을 안섞습니다',
#  '엄지님 핸드폰 볼에 두고 잔 거 설마 그 다음날 연차라고 남친이랑 밤새 통화한 디테일인가요..~~',
#  '이런 짧은 영상에 몰입감이 개쩌는게 숏박스는 레전드다 가슴이 웅장해진다',
#  '찐남매들 서로가 무조건싫나? 너무 개오바임',
#  'ㅋㅋㅋㅋㅋㅋ아 완전 웃겨 ㅋㅋㅋㅋㅋㅋ 너무 자연스러움',
#  '저렇게 웃긴 누나 있으면 재밌겠다..\n아 물론 친누나로 말고 ㅎ',
#  '손석구 짱!!!!!^',
#  '티셔츠 셀린느디옹 ㅋㅋㅋㅋ킹받네 ㅋㅋㅋ',
#  '역시 재밌다 ㅋㅋㅋㅋ 01:32 힐신고 걸어 오시는거 빵터졌어요~🤣 또각 또각 또각',
#  '뿌링클 한마디에 왤케 웃기지',
#  '찐남매라면 손이 아니라 발로 깨우지 않나요? ㅋㅋㅋㅋㅋㅋㅋ',
#  '뿌링클에 영혼을 파는 세',
#  '아니그래서 누나야 동생이야? 나 헷갈려....',
#  '엄지윤은 못 참지~~~💘',
#  '저 돼지새끼... ㅋㅋㅋㅋㅋㅋㅋㅋㅋ 진짜웃겨ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '신입사원면접인가...',
#  '집에 도착해서 씻고 누워서 볼거양!',
#  'ㅋㅋㅋㅋㅋㅋㅋ실비김치 ㅋㅋㅋㅋㅋ',
#  '1:02 엌ㅋㅋㅋㅋㅋㅋㅋ',
#  '이집 맛있다 진짜로...',
#  '분장인가 아님 몇시간 자다가 이제 슛들어간다 하고 찍은건가 ㅋㅋㅋㅋㅋ 부은 얼굴도 리얼하네 ㅋㅋㅋㅋ',
#  '연기는 좋은데 .내용이 오바스러움',
#  '셀린디옹 ㅋㅋㅋㅋ',
#  '뿌링클 한마디에 바로 준비하는거 현실성이 좀.. 치즈볼까지 얹어줘야하는거 아닙니까!!!!!',
#  'ㅅㅂ 또각또각 ㅋㅋㅋㅋㅋ',
#  '2:55 원훈이형과 싱크로율 판박이인 줄ㅎㅎ\n역시 장기커플!!',
#  'I will set this one body one fire 은 방화 하겄다는 소리가 아니라 분신잣살 하겠다는 소리 아닌가염...? ㅋㅋ',
#  '진세님 점점 잘생겨지심👍',
#  '금요일 6시에 나퇴사할거야라니 ㅋㅋ',
#  '숏박스분들 운 좋게 공항에서 봤는데 영상도 멋있고 예쁜데 실물이 진짜 최고입니다👍👍',
#  'ㅋㅋㅋㅋㅋ 세입니다. 진새 ㅋㅋ 멋졌다. ㅋㅋㅋ',
#  '분명히 연차 사유는 실비김치다',
#  '잘먹겠습니다 꺼ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ억',
#  '대본이 너무 좋네요',
#  '그냥 썸네일만 봐도 개공감ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '로나코 ㅋㅋㅋㅋㅋㅋ',
#  '새 입니다 진새입니다 개터졌네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '앜ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 진짜 재밌어요 ^_^',
#  '숏박스는 못 참지',
#  '숏박스 첫 영상부터 다본 구독자입니다 이렇게 잘되서 너무 뿌듯하고 좋네요 앞으로도 렇게 쭉 재밌게 영상 많이 올려주세요 응원합니다 숏박스 화이팅 🤟🏻',
#  '누나한테 돼지새키라니 화목이 넘치는 남매',
#  '진세님 동시통역 가능...섹시해',
#  '꾸준히 웃기냐 ㅋㅋㅋ ㅁㅊ',
#  '간만에 쉬면 니가 뭔데 쉬냐고 존나 지랄함...',
#  '실비김치가 핵심이었군',
#  '영상 올린지  1시간인데 30만 우와 !!',
#  '진세형..뿌링클도 못받고..',
#  '3:21 진심 내 동생인줄ㅋㅋㅋㅋㅋㅋㅋ',
#  '구글번역기  개공감ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '1시간전!!!!',
#  '찐남매 자주 찍어줘요ㅡ 최고다 \n셀린느 뿌링클 실비김치 협찬 감사합니다 ㅋㅋㅋ',
#  '굳굳',
#  '손석구 꿈 ㅋㄱㄱㄱㄱㄱㄲ',
#  '퇴사 하고싶다',
#  '이번거 디테일 미쳤다!',
#  '아 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '묵묵히 지켜주는 잡초가 되고 싶다면서 잡초처럼 뽑아달라니요 ㅋㅋㅋㅋㅋㅋ',
#  'ㅎㅎㅎㅎ ㅋㅋㅋㅋ 역쉬 배꼽 빠집니다~^^♡',
#  '2:56 사랑하면 닮는다던데 원훈님 같아ㅋㅋㅋ',
#  '와 턱님 연기 개리얼👍🏻',
#  '진짜 언제봐도 현실적 ㅋㅋㅋㅋ',
#  '숏박스는 역시 뭔가 다르닼 ㅋㅋㅋ',
#  '너 입사된거야',
#  '스낵타운 항상 응원합니다 !',
#  '진짜 개재밌네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '과연 이직에 성공했을까..?',
#  '저정도면 남매사이 겁나좋네ㅋㅋㅋ',
#  '찐남매가 젤 재밌다요',
#  '엄지윤님 안경이랑 제안경이랑 똑같은 제품이네요 ㄷㄷ',
#  '새입니다 진세입니다에서 진짜 뿜었다 ㅋㅋㅋ',
#  '리아 라고할때 코리아? 예상했다가 말라리아 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '숏박스는 남매 시리즈가 제일 꿀잼임 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 얼굴만 봐도 재밌다 ㅋㅋㅋㅋㅋ',
#  '역시 최곸ㅋㅋㅋㅋㅋ',
#  '왜 둘이 닮았냐…',
#  '꾸앙 너무 재미떵ㅋㅋㅋㅋㅋ 남매시리즈 넘 좋아여 공감 X10000000000',
#  '지윤인 이런모습이 젤어울리고 이뻐보임.존잼ㅋㅋㅋㅋㅋ',
#  '남동생 축구바지 뽀려입는 거 디테일 인정',
#  '내 기억속 조진세는 강한 남자였는데..   she x 5',
#  '세상에서 제일가는 포테이토칩이 젤 웃기네',
#  '연기파 배우 진세님!!!!!',
#  '스트레스 만땅일 때 숏박스 보면 완전 힐링.. 감사합니다💗💗💗',
#  '자! ☝🏻그럼 퇴직하는 절차를 밟아보도록 하지!',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ웃기넹',
#  '와 연기하난 최고네ㅋㅋㅋㅋㅋㄲ ㅋㄱㅋ\n찐남매가 진짜 찐남매네ㅋㅋ',
#  '안 봐도 재밌어서 안 봐요',
#  '쎌린디옹ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '첫장면 부터 터지네 ㅋㅋㅋㅋ',
#  '진세형은 두상이 예쁘셔서 변발이 잘어울리실것같아요!',
#  '1:42 ㅋㅋㅋㅋㅋ 나가',
#  '역시 숏박스!! 저도 아직 안봤습니다',
#  '아 남매컨셉 너무좋아징짜ㅜㅋㅋㅋㅋㅋㅋ\n사랑해🧡🧡🧡🧡🧡🧡🧡🧡ㅎㅎ',
#  '저는 항상 친누나가 있으면 좋겠다는 생각을 했습니다. (이 영상을 보기 전까지요)',
#  '회사 건물이 아니라 내 몸에 불지르겠습니다 라는 뜻이에욬ㅋㅋㅋㅋㅋㅋ 근데 또 "this"라는 말을 할때 손이 면접관을 가르키고있으면 면접관님을 제가 불지르겠습니다 라는 뜻도 되구요. 자해공갈 및 협박 또는 살해 예고하는 포부 넘치는 면접생!!! ㅋㅋㅋㅋㅋㅋㅋ 당장 뽑아다가 경찰서에 심어놔야죠!! ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '티셔츠에 셀린 디온 뭐야 ㅋㅋㅋㅋㅋㅋ',
#  '숏박스 숙소가 너무 비어보이네요 조명 회사 다니는 제가 채워드리고싶습니다 …',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋ결국 다니던 회사를 계속 다니게 되었다는 내용이군 ㅋㅋㅋㅋ',
#  '아 이번편 호흡 너무 좋은데요ㅋㅋㅋ\n세상에서 제일가는 포테이토칩ㅋㅋㅋㅋㄱㅋㅈㅋㅋ',
#  '역시',
#  '여억시 제가 뭔말 할려고 했죠?',
#  '일단 틀어놓고 댓글창 열기 숏박스 드라마 시트콤으로 스케일 크게 만들고 싶다',
#  '근데 왜 둘이 닮았어요..? 진세님 조아요ㅠㅜㅜㅠ💙',
#  'fire에서 4fire가 떠오르면 정상인가요?',
#  '셀린디온 디테일ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '일단 남매가 저렇게 함께 오랜시간을 보내는것이 불가능합니다.',
#  '엄지 티셔츠ㅋ 셀린 디옹 ㅋㅋㅋ노래 겁나 좋아했는데ㅋㅋㅋ',
#  '진짜 자매만 있는 나는....\n소외감 느끼는 중.....',
#  '언제나 공감되는 숏박스',
#  '진짜 졸라 재밌네 ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '셀린 디온 미친 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '점점 재미가..ㅜㅜ',
#  '이분들 생물학적으로 남매맞죠??  친구가 자꾸 아니라네요;; 누가봐도 닮았는데.. 어쨋든 조진세, 엄지윤 화이팅!',
#  '리얼박스 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '2:54 표정과 말투가 김원훈님 같은데요. 역시 장기연애하면서 서로 닮아가는군요👍',
#  '다행이다,, 지윤이 같은 여자친구가 없어서..',
#  '티셔츠 쎌린느 디온이네ㅋㅋㅋㅋㅋ\n셀린디온잼ㅋㅋㅋㅋ',
#  '2:55 너 지금 너무 뻔해 <- 이거 대사 처리 너무 원훈이형 스타일ㅋㅋㅋㅋ 역시 숏박스팀',
#  '0:11 으응 거리거 개 웃기네 진짜',
#  '엄지윤 압박 드립칠때 김원훈 따라하는 거 ㅈㄴ 웃기네 ㅋㅋㅋ',
#  'ㅋㅋㅋ아진짴ㅋㅋㅋ 원훈님 너무 재밌어요',
#  '오 역시 숏박스 재밌겠죠 좋아요 누르고 갑니다~',
#  '이정도 케미면 유전자검사 받아봐야 되는거 아니냐',
#  '셀린디온 ㅋㅋㅋㅋㅋㅋㅋ',
#  '역시  숏박스네요 근데 왜 알림이?',
#  '근데 여담이지만 진세님 좀 잘 생겨지신거 같아여 ㅎ 턱도 좀 짧아지신거 같고.....',
#  '티셔츠 셀린디온 뭔데 ㅋㅋㅋㅋㅋㅋㅋ',
#  '리아 나올때 코리아 나올줄 알았더니 말라리아 였어 ㅋㅋㅋㅋㅋ',
#  '셀린느 인줄 알았는데 셀린디온이네 엌ㅋㅋㅋ',
#  '아 엄지님 여기서 엄지렐라채널 홍보 은근히 하고 지렐이세여~~',
#  '썸넬 하관 진짜 똑같다',
#  '썸네일보고 헐레벌떡 들어왔어요',
#  '엄지님 가끔 뚜루공주 조수연님 얼굴이 보임ㅋㅋㅋ',
#  '구독자 217만명 ㅎ',
#  '역시 찐남매 진짜 서로 동생누나 사랑하나보닼ㅋㅋㅋㅋㅋ 안도와주는 남매도 많은데 못이기는척 다해주네요!',
#  '아니 엄지누나 티셔츠 셀린디온이네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '도대체 이런 포인트는 어디서 잡아내는거야\n물론 재생버튼은 누르지도 않았습니다',
#  '2:58 ㅈㅇ ㄱㄴ ㅍㅌㅇㅌ ㅊ~',
#  '역시숏박스저는지금부터볼겁니다',
#  '찐남매 만을 기다리고있었다구!!',
#  '진세님 왜 점점 잘생겨지지?',
#  '원훈님 다른 채널로 이직하셨나요? 잘 하셨어요~ 진세님 꽃길만 걸으세요~~~👍👍',
#  '조진세ㅠ왤케잘생김?',
#  '엄지님 프로토스 출신이신가 질럿인 줄ㅋㅋ',
#  '역으시 선구독좋아요지ㅎㅎ\n나도나도',
#  '셀린느티를 잠옷으로 입는구나,,했는데\n셀린디온이네ㅋㅋㅋㅋㅋㅋ',
#  '오늘의 드립이 맛있네',
#  '정현~ 몬스터~',
#  '흥얼 ~ 할때 귀엽네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '오자마자 나가라는거에 빵터졌네ㅋㅋ낄낄낄ㅋㅋ',
#  '오랜마이여유',
#  '연기톤 없이 ㅈㄴ 담백해서 좋음 ㅋㅋ',
#  '저 돼지새끼 저거 할때 연기가 아닌거같애.....ㅋㅋㅋㅋㅋㅋ',
#  '역시 오늘도 재미있는 숏박스 오늘도 재미있게 봤습니다.',
#  'ㄹㅇ 케미가 ㅋㅋㅋㅋ',
#  '금요일 퇴근길 지하철에서 본 사람 손ㅋㅋㅋㅋㅋㅋㅋ',
#  '이분들 갈수록 왜이렇게 재밋는지 모르겠네 (진짜 모름)',
#  '뿌링클 ㅋㅋㅋ 이건못참지',
#  '진세형 나 내년에 결혼하는데 사회봐준다고? 감사',
#  '2:31 애송이새깈ㅋㅋㅋㅋㅋ',
#  '진짜 내동생같아서 개좆같내 당분간 안보겠습니다.',
#  '역시 숏박스는 엄지가 나와 줘야..',
#  '뭐야 왜 내 맘 읽어요(물론 제목)',
#  '퇴사할꺼야 매일 ×100000 하는 공감',
#  '구글 건물에 불지른데ㅋㅋㅋㅋ',
#  '두분 닮았어요!',
#  '믿고보는 숏박스~ 지윤&진세 남매편 늘 재미있게 보고있어요',
#  '엄지렐라 옷 셀린느+디올 콜라보한 셀린디온이네ㄷㄷ',
#  '2:55 원훈님 말투랑 비슷해지네 ㅋㅋㅋㅋㅋㅋ',
#  '셀린디온ㅋㅋㅋㅋ',
#  '뿌링클 이야기 하자마자 대본 낚아채는거 개 귀엽네ㅋㅋㅋㅋㅋㅋ 갈굴 맛 나네',
#  '동생한테 면접질문 시키는거 개국룰 ㅋ',
#  '(앞광고) 하필 김원훈님이 나오시지 않는 찐남매 편이라 이런 댓글 달기 뭐하지만.. 김원훈님 인터뷰 영상을 저희가 얼마 전에 올렸습니다. 네, 우선 뭐.. 그렇다는겁니다... 본편 영상 열심히 만들고 있습니다😅\nhttps://youtube.com/shorts/a9FY5n6iueY?feature=share',
#  '마지막에 실비김치 뭐야 ㅋㅎㅋㅎㅋㅎ',
#  '나가세요 ㅋㅋㅋㅋ',
#  '제목 ㅈㄴ 맘에드네',
#  '쩝쩝충 못참지 ㅇㅈ',
#  '밤에 찍은거 같아요',
#  '2:55ㅇ약간 원훈님 느낌난다 여기',
#  '영어이름 엄지렐라 인줄 알았는데',
#  '실비김치는 인정이지',
#  '친누나 없지만 이름대신 다르게 부르는것부터 고증부터 ㄹㅇ 공감..ㅋ',
#  '숏박스 구독자들답게 보지도 않고 숏리플 다는거 보소 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '사실 연차 안써서 회사에서 전화오길 기다렸는데,,',
#  '셀린디온ㅋㅋㅋㅋㅋ ㅈㄴ 감쪽같지 않네',
#  '너무 오랜만이네요',
#  '엄지언니 손석구 실제로 팬인듯ㅈㅋㄱㅋㅋㄱㅋㅋㅋㅋㅋ',
#  '존잼',
#  '3남매로도 시리즈 만들면 잼있을것 같은데.....ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '2:50 너지금 너무 뻔해 하는 엄지님 말투 넘 원훈님 말투같음ㅋㅋㅋㅋ 장기커플 ㅋㅋㅋ',
#  '보통 누나들이 돼지새키긴 함',
#  '점점 재미없어지는거 나만그러냐..?',
#  '쎌린느인줄 알았는데 다시보니 셀린디온 ㅋㅋㅋㅋ',
#  '아 티셔츠 셀린디온ㅠㅠㅠㅠㅠㅠㅠㅠㅠ',
#  '조진세 잘생긴새끼',
#  '이번 영상은 진세씨 연기가 참 좋네요. 여태 이빨을 감췄었구나...',
#  '리아해 리아 말라리아 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '사진이랑 너무 다른거 인정 ㅎㅎ\n차이가 너무 나는분 많아요',
#  '하지마하지마\n\n쿠팡으로  오세요^^',
#  '찐 남매는 저렇게 사이가 좋지 않습니다.. 찐은 투명인간이죠ㅋㅋ',
#  '썸네일 보니깐 안봐도 재밌겠네. 안봐야지',
#  '나가면 후회합니다.  그냥 버티세요.',
#  '두분다 못생겨서 더 재밌어여 ㅎ',
#  '손석구가 꿈에서 납치당한거\n턱좌형님이 현실로 납치하셨네',
#  '하 킹 받는 게 진세형 날이 갈수록 뭔가 잘생겨지는 거 같아서 인생에 회의감이 들 정도네요',
#  '턱세님 아침인건 알겠는데 입가에 침고인거좀 닦아주세여.',
#  '안녕하세요 하자마자 나가세요 가 ㅈㄴ 웃기네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '남매끼리 억지 드립 줄어서 ㄹㅇ 더 재밋어졌네ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '리아 코리아',
#  '진세님 가면 갈 수록 턱이 잘생겨지시네요ㅎㅎㅎ',
#  '실비김치 마무리 깔꼼했다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '0:09 고양이가 싫다고 하는 소리같다 커엽',
#  '와 진짜 최고의 유튜브다 전 세계를 흔들어 놓으셨다',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ아 너무좋아진짜 ㅠㅠㅠㅠㅠ',
#  '29분만에15만 당신들은 ㅋㅋㅋ존경합니다',
#  '진짜 내 옆에서 없어졌으면 좋겠는데 치킨 사주니까 어쩔수 없이 참고 같이 사는중 개열받아',
#  '뿌링클 진짜ㅋㅋ 만능언어 인정',
#  '포테이토칩ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ아니 너무귀엽잖아!!!!!!!!!!',
#  '진세형님 살 빠지셨나요 볼살이 들어가고 턱이 더 나왔는데',
#  '아니 보다보니까 두분 좀 비슷한 느낌 있음...',
#  '엄지님이 "너 지금 너무 뻔해" 라고 말할때 원훈님이랑 겹쳐보이네요ㅋㅋㅋ\n사랑할 수록 닮는다더니..⭐️',
#  '팔라고 광고까지 보고 찐남매 숏박스보니 영상 두개보는거같누 개꿀 ㅋㅋㅋ (광고 이렇게하는거맞지 숏박스형?)',
#  '뿌링클에 팔아먹는 귀찮음',
#  '이야~~ 재밌겠다 아직 안봤음',
#  '밉상 연기 갑들....',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ실비김치 광고인가했네',
#  '찐남매랑 장기커플 콜라보 2 보고싶슴당 고깃집 다음 버전 없나영 ㅠㅠㅠㅠㅠㅠ졸잼',
#  '아니 27분인데 조회수 14만이ㅜ말이되냐 ㅋㅋㅋㅋ케',
#  'PPL도 잘 녹이긴 하는데 역시 꿀잼은 숙제없는 숏박스지~',
#  '진세님 잘생겼다',
#  '나도 유쾌한 누나ㅋㅋㅋㅋ',
#  '넘재미쎀ㅋㅋㅋ',
#  '썸네일이 진짜 남매같은디',
#  '300만 뷰에서 200만으로 살짝 내려가자마자 \n\n바로 치트키로 찐남매.. 이야.. 이거이고.. \n\n너무 재미있는데요? ㅋㅋㅋ \n\n네이버 잡초부터\n구글.. 불사지르겠다 까지.. \n\n대본의 탄탄함.. 감탄받고갑니당👍👍',
#  '지윤 누나가 원훈이 형 닮아가는게 조금씩 보이는거 같네 ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '역시!',
#  '오 난 찐남매가 제일 재밌음',
#  '진세형 우리 아빠 닮았어요. 전 마흔 넷입니다',
#  '찐남매 시리즈가 제일 현실감 있어요. ㄷㄷㄷ 진세님 연기력 최고.',
#  '회사 나없으면 안돌아가 보고 개웃었음ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '엄지렐라님 말투가 원훈이형 닮아가는 건 기분탓인가…?',
#  '구글 서류 합격하고 면접까지 갈정도면..대단한데??ㅋㅋㅋㅋㅋ',
#  '남매 시리즈 개 좋아 ㅋㅋ',
#  '정말 찐이다',
#  'ㅋㅋㅋㅋ역시 숏박스!',
#  '흠. 숏박스  돈좀 벌었나.  영상이 점점 짧아지는거 같은데',
#  '제일가는 포테이토칩 미쳣냐고 ㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '별놈들 문신돼지충에 나왔던 99조진세 96원훈 컨셉으로 한번 나와주세요',
#  '아앜ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㄹㅇ 졸잼 ㅋㅋ 아직 보진 않았습니다',
#  '셀린디온 킬포ㅎ',
#  '박테리아가 아니었다니 ..!!',
#  '찐남매, 장기연애 시리즈는 볼때마다 설레고 짜릿함 ㅋㅋ',
#  '역시 시리즈 중엔 찐남매가 짱이다ㅋㅋㅋ',
#  '3분이 주는 행복이구만 ㅎㅎㅎ',
#  '엄지님 여기서는 진품 명품 입으니까 신기해용..',
#  '디테일 뭔데??ㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ남동생 종특 ㅈㄴ 귀찮은데 다 해줌 츤데레 ㅋㅋㅋㅋ 역시 진세형은 국민 남동생',
#  'ㅋㅋㅋㅋㅋㅋㅋ면접때 잡초 드립치는거 국룰이지.. ㅋㅋㅋㅋㅋㅋㅋㅋ 하아.. ptsd온다..',
#  '동생특: 싫다면서 다 해줌',
#  '진짜 영상안보고 댓글 다는 사람이 100명이네ㅋㅋㅋㅋㅋㅋㅋ다들 너무해ㅠ',
#  '아 김치개으ㅡㅅ기네',
#  '재미가 없다',
#  '아ㅡ재미있어요! 바로 이거지요!! 엄지님이 나와서 그런가 며칠전에 올라온 영상 보고 음… 걱정했는데 역시 숏박스 죽지 않았어요!!!',
#  '2:57 ‘이런 지원자 뽑으면 회사 망한다’라는 생각이 들 정도로 폐급 연기 잘한다 ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '로나 코에서 뿜었다ㅋㅋㅋㅋㅋㅋㅋㅋㅋㄱㅋㅋㅋㅋㅋㅋㅋㅋ ㅋ',
#  '누데이크 먹고싶다',
#  '부부는 닮는다더니 말투가 남자친구분을 닮아가시네',
#  '뿌링클 ㅎㅎㅎ',
#  '진세형 좀 낯설다...왜 잘생겨보이지...',
#  '둘이 결혼 했으면 좋겠다.',
#  "let me tell you 삼성 엘지 카카오 빙그레 let's go!",
#  '재미있어요!!',
#  'ㅋㅋㅋ',
#  '이렇게 빨리 온건 처음 ! 18분전',
#  '와 엄지윤 진짜 연기 현실적으로 잘한다!',
#  '둘이 진짜 생긴거 은근 많이닮았음 ㅋㅋㅋㅋㅋㅋㅋㅋ ㅇㄱㄹㅇ ㅂㅂㅂㄱ',
#  '구글 번역기 킹받아 ㅋㅎㅋㅎㅎㅋㅎㅋㅎㅋㅎㅋㅎ',
#  '세상에서.....제일가는 포테이토칩ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '오늘 사직서 냈다 질문 받는다',
#  '나도하고싶다. \n\n\n\n\n\n\n\n\n로또1등 후 퇴사',
#  '재밌닼ㅋ',
#  '제일가는포테이토칩ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '이 팀 구해줘 홈즈 정식 맴버로 넣어주세요 ㅎㅎ',
#  'ㅋㅋㅋㅋ ㅋㅋㅋㅋ ㅋㅋㅋㅋ 쵝오쵝오 ㅋㅋㅋㅋ ㅋㅋㅋㅋㅋ',
#  '아침에 출근 안 하는 날만 졸라게 깨우는 거 개웃기네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '0:57 라이 어때요? 또라이~',
#  '아ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 찐남매 진짜 존잼이다ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅠㅠㅠㅠㅠ',
#  '저 실비김치 시켜서 진짜 오늘 받았는데',
#  'ㅋㅋㅋ',
#  '재밋당',
#  '영어로 면접보는데 오 영어잘하네 한 내인생레전드',
#  '아 개재밌어 \n사실 아직 안봄',
#  '로나코 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋ내동생도 저렇게 순했으면 좋겠다...ㅎㅎ..진짜루',
#  '숏박스 배우님들 잘생겨지고 예뻐지시고 연기도 배우급이고 점점 퀄리티도 대박이네요 ! 물론 아직 보진 않았습니다',
#  '진세님 헤어스타일 잘어울려용!!',
#  '뿌링클과 실비김치는 못참지',
#  '여윽시 오늘도꿀잼티빙',
#  '재밌는데 좀 짜증좀 덜내면 안될가요 찌푸려지네요',
#  '안봐도 꿀잼일것 같으니까 안보겠습니다!!',
#  '쉬는날 걱정해주면서 깨우는거 개공감 ㅋㅋㅋㅋ 아 진짜 이새끼가 언제부터 나를 챙겼지 싶은 순간',
#  '티셔츠 셀린느 아니고 셀렌디온 임ㅋㅋ',
#  '1:41  나가세요. \nㅋㅋㄹㅋㄹㅋㄹㅋㄹㅋ 개웃기네',
#  '요즘 압박면접 하는 회사는 피하랫는데..',
#  '혹시 티셔츠 셀린 디온? 역시..👍',
#  '3:20 순간 우리 누나라 생각하고 대사쳤는데 똑같아서 소름 돋았네;',
#  '볼 수록 둘이 닮은거 같음 ㅋㅋ',
#  '진짜 이시리즈 개오랜만이네 ㅋㅋ',
#  '진짜 우리집보는것 같닼ㅋㅋㅋ 못 이기는 척이 아니고 못 이겨서 짜증을 내는거임ㅋㅋㅋㅋ 안 할 수 없으니깤ㅋㅋㅋㅋㅋㅋ',
#  '버스 방금 강남역에서 탔는데 다들 이거 보고있어서 저도 켰습니다!',
#  '❤️',
#  '슬슬 질리고 진부해진다',
#  '아껴봐야지\n\n잠자기전에 누워서 봐야징',
#  '면접관을 찐 혈육이라 생각하면 뭔 압박을 해도 안 통하긴 할듯 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '진짜 개재미있다ㅋㅋ',
#  '찐남매 편인데 내용은 찐남매랑은 좀 머네요....\n\n재밌지도 않아요....',
#  '학원이여서 소리도 안 키고 보는데 소리 안 들어도 재밌음 .. 지윤님 나오니까 너무 반갑네 지윤님 많이 나와주세요 !!',
#  '일단 하트 줘봐요^^~ㅋ',
#  'dion ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '아 난 엄지님이 너무 좋아ㅋㅋㅋㅋ 영상 분위기가 밝아져',
#  'ㅋㅋㅋ 이래서 이악물고 회사 다니죠',
#  '진세님 뿌링클에 모든걸 다 버리고 면접관 해주네ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'I will set this one body on fire = 이 한 몸에 불을 지르겠다ㅋㅋㅋㅋㅋㅋ',
#  '개웃긴게 툴툴대면서 다받아줌ㅋㅎㅋㅎㅋㅎㅋㅎㅋㅎㅋㅎㅋㅎㅋㅎㅋㅎㅋ',
#  '찐남매편 개좋음',
#  '나도 이젠 숏박스 없인 안돌아가',
#  '뿌링클 ㅋㅋㅋㅋㅋㅋㅋ\n저거 내가 하는건데 ㅋㅋㅋㅋㅋㅋㅋ',
#  '흥얼~',
#  '꿈 꿀때 깨우면 개빡치는거 개공감 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '실비김치 링크주세요!!!',
#  '근데 진짜 둘이 닮으심ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '1:32 또각또각또각 이 ㅈㄹㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '뿌링클은 못참지 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ\n아니 면접관놀이 개웃기넼ㅋㅋㅋㅋㅋㅋ',
#  '이런패턴 남매 이젠 질리네요 ㅋㅋㅋ 리얼을 강조한게 오히려 현실감 떨어짐 ;;;~~',
#  '아ㅋㅋㅋ찐남매 기다렸어여ㅋㅋㅋㅋ\n오늘도너무잘보고갑니다 핵꿀잼',
#  '셀린디옹ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '다른 시리즈도 다 재밌는게 특히 이 찐남매 시리즈가 진짜 대박임 이 시리즈 볼 때마다 나랑 내 남동생보는 것 같아서 재미가 두배임 정말 너무 현실적이야…',
#  '셀린디온ㅋㅋㅋㅋㅋㅋ',
#  '제일 행복한 사람 진"세"',
#  '215빠',
#  '턱 노답',
#  '뿌링킁 ㅋㅋㅋ',
#  '퇴근하고 바로 보니까 개꿀',
#  '제목 실비김치',
#  '셀린디온 ㅋㅋㅋ',
#  '거창한거 하려고하지마세요\n걍 뭘해도 웃기니까요',
#  '보고싶었어~',
#  '엄지렐라 쎌린 입은거 간지나네',
#  '참 디테일하게 똑닮은 우리딸 아들같은..판박이..',
#  '나샄ㅋㅋㅋㅋㅋㅋㅋ',
#  '조진새님 영어 이름 지어 드림.\n\n조진 새 = fucking bird',
#  '0:14 ㄹㅇ 개부럽다',
#  '와 역시 꿀잼 ㄷㄷ 믿고봅니다 저 역시 아직 보지않았습니다만..',
#  '요즘  찐남매들은  대화를  이렇게 많이하나?',
#  '진짜약간 닮은거같어',
#  '티셔츠 셀린느디옹 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '취준생 추천 영상',
#  '첨부터 터졌네 ㅋㅋ',
#  '엄지님 티셔츠를 보니... 엄지렐라와 세계관을 통일 하는건가 싶었네요~ ㅎㅎ',
#  '아니 근데 네이버 카카오 구글 다 서류 붙은 상황인거냐구ㅋㅋㅋㅋㅋ',
#  '엄지씨ㅋㅋㅋ 셀린디온 티셔츸ㄱㅋㄱ ㄱㄱ ㄱㄱㄱ',
#  '역시 개콘은 망해도 개그는 망하지 않는다',
#  '찐남매 장기연애 시리즈가 젤 재밌어요..ㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ진세님 진짜 계속 보는데 이제 존잘 남신으로 보이기 시작한다',
#  '세상에서 (제일 가는 포테이토칩)ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ나 운다 진짴ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '1:00 리아 개웃기네 ㅋㅋㅋㅋㅋㅋ',
#  '너무 오랜만이네',
#  '배달 기다리는 시간보다 내가 젤 기다리는 시간😆',
#  '1:42 사진이랑 달라서 컷 존나 웃기네 ㅋㅋ',
#  '이게 숏박스지.',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋ 진세님하고 엄지님은 찐남매 연기 미쳤다 진세님은 툴툴거리면서 못이기는척 누나 부탁들어주는 설정 개똑같음 ㅋㅋㅋㅋㅋㅋ 이게 바로 숏박스의 매력 생활 연기의 달인들',
#  '이건 못참지',
#  '실비김치 못참치',
#  '나사랑 구글ㅋㅋㅋㅋㅋ',
#  '아 ㅋㅋㅋㅋ집에서 짝퉁티셔츠 ㅋㅋㅋ디올이 아니라 디온ㅋㅋㅋㅋㅋ',
#  '리아 그러길래 롯데리아 생각하고잇엇는데 생각도 못함 말라리아 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '엄지 말투에서 원훈이 보이는거 \n너네 그거 의도 졸라 뻔해~ :-)',
#  '오랜만에 개웃긴거 올라왓네 ㅋㅋㅋㅋ',
#  '진세형 착하다 누나한테 바지도 빌려주고 ㅋㅋㅋ',
#  '턱 진짜 길긴하구낭',
#  '저번주에 여자친구랑 부산에서 콘서트 재밌게 봤습니다! 즐거웠어요 숏박스 화이팅!!',
#  'ㄹㅇ 개웃기노ㅋㅋㅋㅋ(아직 안봄)',
#  '아니 잡초 신박하다고 생각했는데 지식인에서 퍼온거였냐곸ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '3:07 흥얼~ 🙃 반복재생 🔁',
#  '저도 주세요 김치 ㅠㅠ',
#  '엄지렐라 티셔츠 셀린이래서 오~  역시 잘나가 이랬다가 밑에보니 디옹임 ㅋㅋ',
#  '쩝쩝충이 이걸..',
#  'wsg에서 퇴사한다는건 아닐거고 왜 엄지님 여기있어요',
#  '아 진짜 ㅋㅋㅋㅋㅋㅋㅋㅋ 찐남매가 제일웃김',
#  '요즘 지윤이 삼촌이 칭찬해.',
#  '진짜 숏박스는 연기가 진짜 현실 보는거 같음 ㄹㅇ 가슴이 웅장해진다',
#  '집안에 외동으로 태어난걸 가장 자랑스럽게 느낀 순간',
#  '진세형 말로 하니까 압박인지 모르잖아 턱으로 가자',
#  '티셔츠 셀린느인줄알았는데 셀린디옹ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '👍👍🤣🤣',
#  '뿌링클은 위대하지 ㅋㅋㅋㅋㅋ',
#  '묘하게 우리동생보다 누나말 잘들어주네 ㅠ부럽다',
#  '지도 뿌링클 오면 먹을거면서 ;',
#  '슬슬….',
#  '숏박스 형 나 오늘 생일이야 고정좀해줘!',
#  '찐남매 시리즈는 남매 사이가 아닌데도 묘하게 공감되는게 가끔 있으면서도 티키타카가 찰떡 같아서 너무 재밌음ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '디온 옷 이쁘네요...',
#  '들어오면 영상 바로 일시정지하고 댓글부터 본다 ㅋㅋㅋ',
#  '개콘 폐지는 신의 한수다...',
#  '실비김치 주문하러 가야겠다.슈우웅~~',
#  'ㅋㅋㅋ엄지윤연기는 진짜...연기가아니라 생활그자체인듯',
#  '9분 전!!!',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ개웃김 (이제 재생누름)',
#  '개 짜증나 귀찮게 하는거 우리누나 같애',
#  '2:05 지금 입사지원서쓰고 면접준비하는데 오 씨발 이거 좋은데 하고 이거 쓸뻔;;;',
#  'Wow 24,000 views in 7 minutes',
#  '둘이 진짜 현실남매 같음(현실남매가 인정함)',
#  'ㅋㅋㅋㅋ실비김칰ㅋㅋ',
#  '이야 오늘도 대박이시네요ㅋㅋ\n이건 진짜 찐이다',
#  '엄지 옷ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ엄데렐라 세계관 충동하ㅔ',
#  '남매만 기다렸다구여 ㅋㅋㅋㅋㅋㅋㅋ최고',
#  '로나와 리나 ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '선 댓글 퇴근 후 감상',
#  '잡초: 다른 식물이 자라는 데 해가 되기도 한다.네이버 국어사전',
#  'ㅋㅋㅋ',
#  'ㅋㅋㅋ엄지\n\n옷 쌜린디온ㅋㅋㅋㅋㅋ',
#  '진세님 면접관 빡친연기하면 잘 하실 듯 ㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋ아 개웃기네 (아직 안 봄)',
#  '야 올라온지 1분도 안됐는데 댓들이 100개가 넘엌 ㅋㅋㅋ',
#  'ㅋㅋㅋㅋ매번 부탁마다 승질내는거 현실고증 제대로네요 ㅋㅋㅋ 이번 에피소드는 진세님이 연기를 너무 맛깔나게 표현하신듯',
#  '포테이토칩ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '아 머랄까 맛이 안나는데?  초심 개 잃었네',
#  '너무 재밌게 잘 보고 있습니다~',
#  '5분전!!진짜 너무 연기 잘하셔요ㅋㅋㅋ영상 올라오는거 매일매일 체크하고 있었는데 학원 가따오고 딱 봤은데 딱 올라왔네요ㅎㅎ앞으로도 재미있는 현실 연기 많이 올려주세요ㅋㅋㅋㅋ',
#  '2:57 세상에서 제일가는 포테이토 칩',
#  '상하의 둘이 사이좋게 나눠입었네ㅋㅋㅋㅋㅋㅋ',
#  '대박~~~!!!\n아직 보진 못했습니다….ㅎ',
#  '리아 할때 롯데리아할줄',
#  '드뎌 찐남매군',
#  '헤헤',
#  '그래도 짤릴까봐 걱정되서 깨워주긴하넹ㅋㅋㅋㅋ',
#  '남매끼리 나이키 아래위로 나눠입은 디테일 존경합니다ㅋㅋㅋㅋㅋ',
#  '숏박스.. 우일이형 영입좀..',
#  '레알 찐남매ㅋㅋㅋ',
#  '볼수록 정말 두분 닮아가세요 ㅋㅋㅋ',
#  '찐형제도 보고싶습니다 ㅠ',
#  '나사요?',
#  '썸넬만 봐도 잼있닼ㅋㅋ',
#  '1:13 뿌링클은 못참쥐~~',
#  '역시 찐남매',
#  '아 진짜 개웃기네ㅋㅋ',
#  '진세님 윗도리랑 지윤님아랫도리 세트인거 킬포임 여러분 .. 디테일 개쩔어 ..',
#  ...]

# %% [markdown]
# #### 대댓글 정보 수집

# %%
##대댓글 찾기
for i in range(len(response.get('items'))):
    if response.get('items')[i].get('replies'):
        print(i)
        break


response.get('items')[9].get('replies')
# Out:
# 9
# {'comments': [{'kind': 'youtube#comment',
#    'etag': 's6h_Qs1ledFoy3r0X_1T-bNjusk',
#    'id': 'UgyhCLARKOLoW61wXMR4AaABAg.9fCJOke-hcg9fCR_gKHphO',
#    'snippet': {'videoId': 'uRFEhFIsyXY',
#     'textDisplay': '찐남매임? 어쩐지ㅋㅋㅋㅋㅋㅋㅋ',
#     'textOriginal': '찐남매임? 어쩐지ㅋㅋㅋㅋㅋㅋㅋ',
#     'parentId': 'UgyhCLARKOLoW61wXMR4AaABAg',
#     'authorDisplayName': '루',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/O1ekPu5yIKHweS8PoY3ITvwKclEO6cwe8vNog5Jy0J2qjhPIjS1ijrEEeHnLzDUm9L8p20YxFA=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/channel/UCzEEW1be_3Glc5RCqoRsG7w',
#     'authorChannelId': {'value': 'UCzEEW1be_3Glc5RCqoRsG7w'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2022-08-26T18:48:19Z',
#     'updatedAt': '2022-08-26T18:48:19Z'}}]}

# %% [markdown]
# ### Comments
# 비디오 내 댓글 조회 기본 코드
# ```python
# response = (
#     youtube
#     .commentThreads()
#     .list(
#       part='snippet,replies',
#       videoId=*video_id*,
#       maxResults=100
#       )
#     .execute()
#     )
# ```
#
# 1번의 query에 전체 데이터를 다 받을 수 없음 <br>
# 따라서 pageToken을 이용하여 다음 페이지의 정보를 받아야 함 <br>
# ```python
# if 'nextPageToken' in response:
#   response = (
#     youtube
#     .commentThreads()
#     .list(
#       part='snippet,replies',
#       videoId=video_id,
#       pageToken=response.get('nextPageToken'),
#       maxResults=100
#       )
#     .execute()
#     )
# ```

# %% [markdown]
# ## 6.2 Dart
#
# url에 key와 value값을 추가하여 호출
#
# site: https://opendart.fss.or.kr/ <br>
# reference: https://opendart.fss.or.kr/guide/main.do?apiGrpCd=DS001 <br>

# %% [markdown]
# ### 공시정보
#
# ```python
# https://opendart.fss.or.kr/api/document.xml
# ```

# %% [markdown]
# ### 기업개황
#
# ```python
# https://opendart.fss.or.kr/api/company.json?crtfc_key=xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx&corp_code=00126380
# ```

# %% [markdown]
# ### 공시검색
#
# ```
# https://opendart.fss.or.kr/api/list.json?crtfc_key=xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx&bgn_de=20200117&end_de=20200117&corp_cls=Y&page_no=1&page_count=10
# ```

# %% [markdown]
# ### 재무재표
#
# ```python
# https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json?crtfc_key=xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx&corp_code=00126380&bsns_year=2018&reprt_code=11011&fs_div=OFS
# ```
