# %% [markdown]
# # Data Collection for Next Curriculum
#
# news (2021년 네이버 언론사 모바일 랭킹뉴스 매체별 점유율, 기자협회보)
# - 2022-07-01 ~ 2022-08-31
# - 중앙일보, 한국경제, 조선일보, 매일경제, 머니투데이
#
# youtube
# - 너덜트, 슈카월드, 호갱구조대, 1분만, 장삐쭈
# - 각 채널 별 영상 2개씩 <br>
# 너덜트: 오늘 수정이네 집에서 자고 가려고, 꿈이요? 퇴산데요 <br>
# 슈카월드: 화려했던 비전펀드 창사 이래 최대 적자, 카페인이 필요한 사람들 <br>
# 호갱구조대: 님들이 뭔데요....?, 선을 넘기 시작한 요즘 예능들 <br>
# 1분만: 중2때 하면 안되는 것들, 내가 100만이 될상인가? <br>
# 장삐쭈: [신병] 집합, [신병] 선택 <br>
# - 영상별 댓글 수집
#
# dart
# - 국내 시가총액순 20위까지 (우선주 제외)
# - 기업개황, 재무제표

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
api_key = 'c7807edc749df6530c4b6f6bbc4aadbf0b33b969'
comp_codes = ['00126380','01515323','00164779','00877059','00356361','00164742','00126362','00266961','00258801','00106641','00413046','00149655','00155319','00688996','00164788','00688996','00164788','00631518','00382199','00181712']
len(comp_codes)
# Out:
# 20

# %%
total_grp = []

for i in comp_codes:
    comp_information = f'https://opendart.fss.or.kr/api/company.json?crtfc_key={api_key}&corp_code={i}'
    response = requests.get(comp_information)
    total_grp.append(eval(response.text))
    response_pd = pd.DataFrame(total_grp)
    
# response_pd.to_csv('./company_intro.csv', index = False) #csv 파일로 만드는법

# %%
financial_statement_url  = f'https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json?crtfc_key={api_key}&corp_code={comp_codes}&bsns_year=2021&reprt_code=11011&fs_div=CFS'
for result in comp_codes:
    
response2 = requests.get(financial_statement_url)
# Out:
# {'status': '000',
#  'message': '정상',
#  'corp_code': '00126380',
#  'corp_name': '삼성전자(주)',
#  'corp_name_eng': 'SAMSUNG ELECTRONICS CO,.LTD',
#  'stock_name': '삼성전자',
#  'stock_code': '005930',
#  'ceo_nm': '한종희, 경계현',
#  'corp_cls': 'Y',
#  'jurir_no': '1301110006246',
#  'bizr_no': '1248100998',
#  'adres': '경기도 수원시 영통구  삼성로 129 (매탄동)',
#  'hm_url': 'www.sec.co.kr',
#  'ir_url': '',
#  'phn_no': '031-200-1114',
#  'fax_no': '031-200-7538',
#  'induty_code': '264',
#  'est_dt': '19690113',
#  'acc_mt': '12'}

# %%
financial_statement_url  = f'https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json?crtfc_key=xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx&corp_code=00126380&bsns_year=2018&reprt_code=11011&fs_div=CFS'
response2 = requests.get(financial_statement_url)
response2.text
# Out:
# '{"status":"000","message":"정상","list":[{"rcept_no":"20190401004781","reprt_code":"11011","bsns_year":"2018","corp_code":"00126380","sj_div":"BS","sj_nm":"재무상태표","account_id":"ifrs_CurrentAssets","account_nm":"유동자산","account_detail":"-","thstrm_nm":"제 50 기","thstrm_amount":"174697424000000","frmtrm_nm":"제 49 기","frmtrm_amount":"146982464000000","bfefrmtrm_nm":"제 48 기","bfefrmtrm_amount":"141429704000000","ord":"1","currency":"KRW"},{"rcept_no":"20190401004781","reprt_code":"11011","bsns_year":"2018","corp_code":"00126380","sj_div":"BS","sj_nm":"재무상태표","account_id":"ifrs_CashAndCashEquivalents","account_nm":"현금및현금성자산","account_detail":"-","thstrm_nm":"제 50 기","thstrm_amount":"30340505000000","frmtrm_nm":"제 49 기","frmtrm_amount":"30545130000000","bfefrmtrm_nm":"제 48 기","bfefrmtrm_amount":"32111442000000","ord":"2","currency":"KRW"},{"rcept_no":"20190401004781","reprt_code":"11011","bsns_year":"2018","corp_code":"00126380","sj_div":"BS","sj_nm":"재무상태표","account_id":"dart_ShortTermDeposi
# ...

# %%
## csv 저장
pd.DataFrame().to_csv('./results.csv', index = False)
