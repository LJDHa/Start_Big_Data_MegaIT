# %% [markdown]
# ## 4.6 Database Link in Python

# %% [markdown]
# ### psycopg2
#
# 설치
# ```cmd
# pip install psycopg2
# pip install psycopg2-binary #위의 설치 에러 시 이 코드 실행
# ```
# <br>
#
# 사용법
# ```python
# conn = psycopg2.connect(
#   host='address',
#   dbname='database name',
#   user='user name',
#   password='password',
#   port=port
#
# cur = conn.cursor()
# ```
#
# CRUD
# ```python
# cur.execute(f'INSERT INTO test (id, press_name) VALUES ({id}, {press_name});')
# conn.commit() # CREATE
#
# cur.execute('SELECT * FROM test;')
# result_one = cur.fetchone() # READ
# result_many = cur.fetchmany()
# result_all = cur.fetchall()
#
# cur.execute(f'UPDATE test SET press_name={press_name} WHERE id > 5')
# conn.commit() # UPDATE
#
# cur.execute('DELETE FROM test WHERE press_name LIKE %조선%;')
# conn.commit() # DELETE
# ```
# <br>
#
# pandas 내의 method를 통해서도 사용 가능
# ```python
# pd.read_sql('SELECT * FROM test', conn)
# ```
# <br>
#
# Closer <br>
# 사용 후 연결 해제 <br>
# ```python
# cur.close()
# conn.close()
# ```
# <br>
#
# 아래와 같이 사용 가능
# ```python
# with conn.cursor() as cur:
#   cur.execute(query)
#
# conn.close()
#
# with psycopg2.connect():
#   with conn.cursor() as cur:
#     cur.execute(query)
# ```

# %% [markdown]
# ### sqlalchemy
#
# 설치
# ```cmd
# pip install sqlalchemy
# ```
# <br>
#
# 사용법
# ```python
# from sqlalchemy import create_engine
# from sqlalchemy.types import Integer, Text, String, DateTime
#
# db_url = f'postgres+psycopg2://{USERNAME}:{PASSWORD}@{DB_HOST}:{PORT}/{DB_NAME}'
# engine = create_engine(db_url, echo=True)
#
# test.to_sql(
#   'schema',
#   engine,
#   if_exists='append', # replace: 덮어쓰기
#   index=False,
#   chunksize=5000,
#   dtypes={
#     'id': Integer,
#     'press_name': Text
#   }
# )
# ```

# %% [markdown]
# # 5.Crawling
#
# 스크레이핑(Scraping)이라고도 하며 웹 페이지 내의 데이터를 추출하는 것을 의미 <br>
# 데이터를 수집하기 위한 방법으로 많이 사용 <br>
# 크게 두 가지의 방법이 존재
# 1. 정적크롤링 <br>
# 정적 데이터를 수집하는 방법 <br>
# 정적 데이터란 페이지 내에 원하는 정보가 모두 들어남
#
# 2. 동적크롤링 <br>
# 동적 데이터를 수집하는 방법 <br>
# 동적 데이터란 클릭, 로그인 등의 행위를 통해 원하는 데이터에 접근 가능 <br>
#
#
# |    |정적 크롤링|동적 크롤링|
# |----|--------|--------|
# |방법 |주소 사용  |브라우저 사용|
# |수집 범위|제한적  |제한 없음|
# |속도|매우 빠름|매우
# <br>
#
# 크롤링 시 사이트에서 크롤링을 허용하는지를 반드시 확인해야 함 <br>
# robots.txt를 뒤에 붙여 확인 가능 <br>
# 강제는 아니나 이를 무시하면 추후 법률적 문제가 생길 수 있음
# ```
# www.daum.net/robots.txt
# User-agent: *
# Disallow: /
# ```
# *: All <br>
# /: All Directories

# %% [markdown]
# ## 5.1 HTTP
#
# WWW(World Wide Web, W3) 상에서 정보를 주고받을 수 있는 프로토콜 <br>
# 클라이언트와 서버 사이에 이루어지는 요청/응답 프로토콜

# %% [markdown]
# ### API
# #### 데이터 제공자와 이용자의 약속 (note) <br>
# API(Application Programming Interface) <br>
# - Application: 고유한 기능을 가진 모든 소프트웨어
# - Interface: 두 애플리케이션 간의 규약 <br>
# 이 계약은 요청과 응답을 사용하여 두 애플리케이션이 서로 통신하는 방법을 정의합니다.

# %% [markdown]
# ### REST
# REST(Representational State Transfer): 자원을 이름으로 구분하여 해당 자원의 상태를 주고받는 것 <br>
#
# REST 구성
# 1. 자원(Resource): HTTP URI
# 2. 자원에 대한 행위(Verb): HTTP Method
# 3. 자원에 대한 행위의 내용(Representations): HTTP Message Pay Load
#
#
# - HTTP URI(Uniform Resource Identifier)를 통해 자원(Resource)을 명시
# - HTTP Method(POST, GET, PUT, DELETE)를 사용하여 URI에 대한 CRUD Operation을 적용 <br>
# <br>
#
# HTTP Methods
# - GET: 자원 검색
# - POST: 자원 작성
# - PUT: 자원 업데이트
# - DELETE: 데이터 삭제
# - HEAD: 자원 검색 (GET과 유사하나 상태 줄과 헤더만 반환)
# - OPTIONS: 자원이 지원하고 있는 메소드의 취득
# - PATCH: 자원 일부 수정 (PUT과 유사하나 일부만 수정)
# - CONNECT: 자원의 터널 접속을 변경
# - TRACE: 리소스에 대한 경로를 따라 메시지 루프백 테스트를 수행
# <br>
#
# HTTP Status
# 1. 1xx(Informational): 요청 처리중
# 2. 2xx(Successful): 요청 정상 처리 <br>
# 200: 요청 성공
# 3. 3xx(Redirection): 요청을 완료하려면 추가 행동이 필요
# 4. 4xx(Client Error): 클라이언트 오류, 잘못된 문법등으로 요청을 수행할 수 없음 <br>
# 400: Bad Request, 클라이언트의 잘못된 요청으로 서버가 요청을 처리할 수 없음 <br>
# 401: Unauthorized, 해당 리소스에 대한 인증이 필요함 <br>
# 403: Forbidden, 서버가 요청을 이해했지만 승인을 거부함 <br>
# 404: Not Found, 리소스를 찾을 수 없음 <br>
# 5. 5xx(Server Error): 서버 오류

# %% [markdown]
# ### REST API
# REST의 원리를 따르는 API <br>
# ※ RESTful: REST의 원리를 따르는 시스템

# %% [markdown]
# ## 5.2 HTML
# HTML(HyperText Markup Language)은 웹 페이지 표시를 위해 개발된 지배적인 마크업 언어 <br>
# HTML은 웹 페이지 콘텐츠 안의 꺾쇠 괄호에 둘러싸인 "태그"로 되어있는 HTML 요소 형태로 작성 <br>
# HTML은 웹 브라우저와 같은 HTML 처리 장치의 행동에 영향을 주는 자바스크립트, 본문과 그 밖의 항목의 외관과 배치를 정의하는 CSS 같은 스크립트를 포함하거나 불러올 수 있음 <br>
# <br>
# HTML 선택자: HTML에서는 다수의 동일한 태그가 존재하는데 각 태그를 구별할 수 있도록 선택자를 이용
# ```html
# <div>
# 	<div>
#       <a> c </a>
#       <span> c++ </span>
#     </div>
#
#     <div>
#       <a> java </a>
#       <span> python </span>
#     </div>
# </div>
# ```
#
# ```html
# <div id="contents">
# 	<div class="data1">
#       <span class="language"> c++ </span>
#       <span class="language"> java </span>
#       <span class="language"> python </span>
#   </div>
#
#   <div class="data2">
#       <a class="framework"> tensorflow </a>
#       <a class="framework"> pytorch </a>
#       <a class="framework"> spring </a>
#   </div>
# </div>
# ```

# %% [markdown]
# ## 5.3 정적크롤링

# %% [markdown]
# #### 5.3.1 라이브러리

# %% [markdown]
# ##### 5.3.1.1 requests
#
# requests: 파이썬용 http 라이브러리 <br>
# reference: https://requests.readthedocs.io/en/latest/
#
# 메소드별 사용법
# ```python
# GET: requests.get()
# POST: requests.post()
# PUT: requests.put()
# DELETE: requests.delete()
# ```
#
# ```python
# import requests
#
# requests.get("https://jsonplaceholder.typicode.com/users/1")
# ```

# %% [markdown]
# ###### Response Body
#
# 요청이 정상적으로 처리가 되면, response body에 요청한 데이터가 담겨져 옴. <br>
# response body 크게 3가지 방식으로 읽을 수 있음 <br>
# 1. content: binary 원문을 읽음
# ```python
# response.content
# ```
# 2. text: utf-8로 인코딩 된 문자열로 읽음
# ```python
# response.text
# ```
# 3. json: 응답이 json이면 dict로 읽음
# ```python
# response.json()
# ```

# %% [markdown]
# ###### Request
#
# param: 주소에 포함된 변수를 담음<br>
# ex) https://www.naver.com/post/12345 <br>
# -> 12345 <br>
# query: 주소 바깥? 이후의 주소를 담음<br>
# ex) https://www.naver.com/post/post_id=12345&id=1 <br>
# -> 12345, 1
# body: XML, JSON 등의 데이터를 담음, 주소에서는 확인 불가<br>
# <br>
#
# requests에서는 아래와 같이 사용
# - get
# ```python
# response = requests.get("https://naver.com/post", params={"post_id": "12345", "id": "1"})
# ```
#
# - post, put: HTML 데이터 전송
# ```python
# response = requests.get("https://naver.com/post", data={"post_id": "12345", "id": "1"})
# ```
# json 형태로도 요청 가능
# ```python
# response = requests.get("https://naver.com/post", json={"post_id": "12345", "id": "1"})
# ```

# %% [markdown]
# ###### headers
#
# 일부 웹 사이트는 bot agent를 차단 <br>
# 이 경우 header의 user-agent를 아래와 같이 넘기면 해결 <br>
# ```python
# requests.get("https://naver.com/post", headers={'User-Agent': 'Mozilla 5.0'})
# ```

# %% [markdown]
# ##### 5.3.1.2 BeautifulSoup
#
# BeautifulSoup: html, xml 등으로부터 원하는 정보를 가지고 올 수 있도록 하는 라이브러리 <br>
# reference: https://www.crummy.com/software/BeautifulSoup/bs4/doc/
#
# ```python
# import requests
# from bs4 import BeautifulSoup
#
# response = requests.get(url)
# bs = BeautifulSoup(response.text, 'lxml')
# ```

# %% [markdown]
# ###### Parser
#
# |parser|특징|설치|속도|사용방법|
# |------|---|---|---|------|
# |html.parser||기본|보통|BeautifulSoup(html_doc, 'html.parser')|
# |lxml|xml 지원|lxml 필요|빠름|BeautifulSoup(html_doc, 'lxml')|
# |xml|xml 지원|lxml 필요|빠름|BeautifulSoup(html_doc, 'xml')|
# |html5lib|브라우저와 동일|html5lib 필요|느림|BeautifulSoup(html_doc, 'html5lib')|

# %% [markdown]
# ###### find
# 속성과 값을 이용하여 원하는 값을 찾음
#
# find: 매칭되는 값 중 상위 1개 반환
# find_all: 매칭되는 전체 반환
#
# 특정 태그 추출
# ```python
# soup.find_all('p') # p 태그 추출
# ```
# <br>
#
# 특정 클래스 추출
# ```python
# soup.find_all(class_='a') # a 클래스 추출
# ```
# <br>
#
# 특정 태그와 class 추출
# ```python
# soup.find_all('p', attrs={'class': 'a'}) # p 태그와 a 클래스 모두를 갖는 값 추출
# ```
# <br>
#
# 특정 id 추출
# ```python
# soup.find_all(id='b') # b id를 갖는 값 추출
# ```
# <br>

# %% [markdown]
# ###### select
# CSS Selector로 태그를 찾아 반환 <br>
# CSS에서 HTML을 태깅하는 방법을 활용 <br>
# <br>
# select_one: 매칭되는 값 중 상위 1개 반환 <br>
# select: 매칭되는 전체 반환 <br>
# <br>
#
# 특정 태그 추출
# ```python
# soup.select('p') # p 태그 추출
# ```
# <br>
#
# 특정 클래스 추출
# ```python
# soup.select('.a') # a 클래스 추출
# ```
# <br>
#
# 특정 태그와 class 추출
# ```python
# soup.select('p.a') # p 태그와 a 클래스 모두를 갖는 값 추출
# ```
# <br>
#
# 특정 id 추출
# ```python
# soup.select('#b') # b id를 갖는 값 추출
# ```
# <br>
#
# 특정 태그와 id 추출
# ```python
# soup.select('p#b') # p 태그와 b id 모두를 갖는 값 추출
# ```
# <br>
#
# 특정 태그와 class, id 모두 추출
# ```python
# soup.select('p.a#b') # p 태그와 a 클래스 b id 모두 갖는 값 추출
# ```
# <br>
#
# 특정 태그 아래에 있는 태그 찾기
# ```python
# soup.select('div p') # div 아래 p태그가 있는 값 추출
# soup.select('div > p') # div 바로 아래 p태그가 있는 값 추출
# soup.select("div > #link") # div 바로 아래 link id가 있는 값 추출
# ```
# <br>
#
# 형제 태그 찾기
# ```python
# soup.select("#link + .sister") # link 태그와 형제 태그 중 바로 직후 1개
# soup.select("#link ~ .sister") # link 태그와 형제 태그 중 뒤에 태그 전부
# ```
# <br>
#
# 여러 태그 중 i번째 태그 추출
# ```python
# soup.select('a:nth-of-type(i)') # 추출된 a태그 중 i번째 값 반환
# ```
# <br>
# <br>
#
# 정규표현식 활용 <br>
# ```python
# soup.select('[class~=a]') # class 속성 중 a를 포함하는 태그
# soup.select('a[href]') # a 태그 중 href 속성이 존재하는 태그
# soup.select('a[href="https://www.naver.com"]') # a 태그 중 href 속성이 https://www.naver.com과 매칭되는 태그
# soup.select('a[href^="https://"]') # a 태그 중 href 속성이 https://로 시작하는 태그
# soup.select('a[href$="ac.kr"]') # a 태그 중 href 속성이 ac.kr로 끝나는 태그
# soup.select('a[href*="naver"]') # a 태그 중 href 속성 중 naver를 가지는 태그
# ```
#
# <br>
# <br>
#
# 출력
# ```python
# soup.strings # 값 반환
# soup.stripped_strings # 공백을 제거한 값 반환
# ```

# %% [markdown]
# ### 5.3.2 실습

# %% [markdown]
# ##### 예제
#
# ```html
# <div id="contents">
# 	<div class="data1">
#       <span class="language"> c++ </span>
#       <span class="language"> java </span>
#       <span class="language"> python </span>
#   </div>
#
#   <div class="data2">
#       <a class="framework"> tensorflow </a>
#       <a class="framework"> pytorch </a>
#       <a class="framework"> spring </a>
#   </div>
# </div>
# ```

# %%
response = '''<div id = "contents">
	<div class="data1"> 
      <span class="language"> c++ </span> 
      <span class="language"> java </span> 
      <span class="language"> python </span> 
  </div> 
    
  <div class="data2"> 
      <a class="framework"> tensorflow </a> 
      <a class="framework"> pytorch </a> 
      <a class="framework"> spring </a> 
  </div> 
</div>'''

# %%
from bs4 import BeautifulSoup
import requests

# %%
bs = BeautifulSoup(response, 'lxml')
print(bs)
# Out:
# <html><body><div id="contents">
# <div class="data1">
# <span class="language"> c++ </span>
# <span class="language"> java </span>
# <span class="language"> python </span>
# </div>
# <div class="data2">
# <a class="framework"> tensorflow </a>
# <a class="framework"> pytorch </a>
# <a class="framework"> spring </a>
# </div>
# </div></body></html>

# %%
bs.select('div')
# Out:
# [<div id="contents">
#  <div class="data1">
#  <span class="language"> c++ </span>
#  <span class="language"> java </span>
#  <span class="language"> python </span>
#  </div>
#  <div class="data2">
#  <a class="framework"> tensorflow </a>
#  <a class="framework"> pytorch </a>
#  <a class="framework"> spring </a>
#  </div>
#  </div>,
#  <div class="data1">
#  <span class="language"> c++ </span>
#  <span class="language"> java </span>
#  <span class="language"> python </span>
#  </div>,
#  <div class="data2">
#  <a class="framework"> tensorflow </a>
#  <a class="framework"> pytorch </a>
#  <a class="framework"> spring </a>
#  </div>]

# %%
bs.select('div')[0]
# Out:
# <div id="contents">
# <div class="data1">
# <span class="language"> c++ </span>
# <span class="language"> java </span>
# <span class="language"> python </span>
# </div>
# <div class="data2">
# <a class="framework"> tensorflow </a>
# <a class="framework"> pytorch </a>
# <a class="framework"> spring </a>
# </div>
# </div>

# %%
bs.select('div')[0].select('a')
# Out:
# [<a class="framework"> tensorflow </a>,
#  <a class="framework"> pytorch </a>,
#  <a class="framework"> spring </a>]

# %%
bs.select('div')[0].select('span')
# Out:
# [<span class="language"> c++ </span>,
#  <span class="language"> java </span>,
#  <span class="language"> python </span>]

# %%
bs.select('div')[0].select('.framework') #class이름을 입력할경우 (class 는 "."을사용함)
# Out:
# [<a class="framework"> tensorflow </a>,
#  <a class="framework"> pytorch </a>,
#  <a class="framework"> spring </a>]

# %%
bs.select('div')[0].select('a.framework') #a tag 밑에 class이름을 입력할경우
# Out:
# [<a class="framework"> tensorflow </a>,
#  <a class="framework"> pytorch </a>,
#  <a class="framework"> spring </a>]

# %%
bs.select('div#contents') #id의 내용을 찾을시 "#"를 사용
# Out:
# [<div id="contents">
#  <div class="data1">
#  <span class="language"> c++ </span>
#  <span class="language"> java </span>
#  <span class="language"> python </span>
#  </div>
#  <div class="data2">
#  <a class="framework"> tensorflow </a>
#  <a class="framework"> pytorch </a>
#  <a class="framework"> spring </a>
#  </div>
#  </div>]

# %%
bs.select('span:nth-of-type(2)')
# Out:
# [<span class="language"> java </span>]

# %%
bs.select('div span') # div 하단에 있는 모든 테그를 잡을수있다


bs.select('div>a') #div 바로 하단에 있는 테그를 잡을수 있다
# Out:
# [<a class="framework"> tensorflow </a>,
#  <a class="framework"> pytorch </a>,
#  <a class="framework"> spring </a>]

# %% [markdown]
# #### 네이버 뉴스

# %%
import requests
import pandas as pd
import psycopg2
from tqdm import tqdm

# %%
response = requests.get('https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=023', headers = {'User-Agent':'Mozilla 5.0'}) #bot은 접속이 안되서 header 정보 필요

# %%
bs = BeautifulSoup(response.text,'lxml') #beautiful soup은 정리해서 보여준다 text 정보를
bs
# Out:
# <!DOCTYPE HTML>
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh"/>
# <meta content="width=1106" name="viewport"/>
# <meta content="조선일보 언론사홈" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=023" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png" property="og:image"/>
# <meta content="언론사 주요 뉴스와 속보를 만나볼 수 있습니다." property="og:description"/>
# <meta content="네이버" property="og:article:author"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="조선일보 언론사홈" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png" name="twitter:image"/>
# <meta content="언론사 주요 뉴스와 속보를 만나볼 수 있습니다." name="twitter:description"/>
# <title>조선일보 홈 : 네이버 뉴스	</title>
# <link href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20220818_135641/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20220818_135641/css/news.css" rel="stylesheet" type="text/css"/>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20220818_135641/js/news.jindo.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20220818_135641/js/news.jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
# var _MAIN_NEWS_MENU_ID='sec';
# var _MAIN_NEWS_SECTION_ID='';
# var ccsrv='cc.naver.com';
# var g_ssc='news.press';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Sat Aug 20 10:55:38 KST 2022";
# </script>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20220818_135641/js/news.service.js" type="text/javascript"></script>
# <script>
#
#     var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
# </script>
# </head>
# <body>
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> </a></li>
# <li><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/main/opinion/home.naver"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
# </ul>
# </div>
# </div>
# <div class="lnb_right">
# <div class="lnb_extra">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>08</strong>.<strong>20</strong><span class="day">(토)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <table cellpadding="0" cellspacing="0" class="container">
# <caption class="blind">기사목록</caption>
# <colgroup>
# <col class="col_snb"/>
# <col class="col_content"/>
# <col class="col_aside"/>
# </colgroup>
# <tr>
# <td class="snb">
# <div class="snb" id="snb">
# <h2 class="h2"><a class="nclicks(lmn_prs.home)" href="/main/officeList.naver">언론사 뉴스</a></h2>
# <ul class="nav">
# <li class="on"><a class="nclicks(lmn_prs.tog)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=032">종합 <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(lmn_prs.bro)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=421">방송/통신 </a></li>
# <li><a class="nclicks(lmn_prs.eco)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=009">경제 </a></li>
# <li><a class="nclicks(lmn_prs.int)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=079">인터넷 </a></li>
# <li><a class="nclicks(lmn_prs.sci)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=138">IT </a></li>
# <li><a class="nclicks(lmn_prs.pho)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=348">포토 </a></li>
# <li><a class="nclicks(lmn_prs.mag)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=145">매거진 </a></li>
# <li><a class="nclicks(lmn_prs.pro)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=127">전문지 </a></li>
# <li><a class="nclicks(lmn_prs.reg)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=654">지역 </a></li>
# </ul>
# </div>
# </td>
# <td class="content">
# <div class="content" id="main_content">
# <div class="list_header newsflash_header2">
# <h3>종합</h3>
# <div class="topbox_type4">
# <div>
# <ul class="massmedia">
# <li>
# <a class="nclicks(cnt_press)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=032">경향신문</a>
# <i class="picon">신문</i>
# </li>
# <li>
# <a class="nclicks(cnt_press)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=005">국민일보</a>
# <i class="picon">신문</i>
# </li>
# <li>
# <a class="nclicks(cnt_press)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=020">동아일보</a>
# <i class="picon">신문</i>
# </li>
# <li>
# <a class="nclicks(cnt_press)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=021">문화일보</a>
# <i class="picon">신문</i>
# </li>
# <li>
# <a class="nclicks(cnt_press)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=081">서울신문</a>
# <i class="picon">신문</i>
# </li>
# <li>
# <a class="nclicks(cnt_press)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=022">세계일보</a>
# <i class="picon">신문</i>
# </li>
# <li>
# <a class="visit on nclicks(cnt_press)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=023">조선일보</a>
# <i class="picon">신문</i>
# </li>
# <li>
# <a class="nclicks(cnt_press)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=025">중앙일보</a>
# <i class="picon">신문</i>
# </li>
# <li>
# <a class="nclicks(cnt_press)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=028">한겨레</a>
# <i class="picon">신문</i>
# </li>
# <li>
# <a class="nclicks(cnt_press)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=469">한국일보</a>
# <i class="picon">신문</i>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="list_body newsflash_body">
# <div class="newsflash_header3">
# <h3>조선일보</h3>
# <div class="view_type">
# <a class="newsp nclicks(fls.vtype)" href="list.naver;jsessionid=D097AD05257A864A14AB6DB138738002?mode=LPOD&amp;mid=sec&amp;oid=023&amp;listType=paper&amp;date=20220820" title="신문에 게재된 기사만 보실 수 있습니다.">신문게재기사만</a><span class="bar">|</span>
# <a class="tit_off nclicks(fls.vtype)" href="list.naver;jsessionid=D097AD05257A864A14AB6DB138738002?mode=LPOD&amp;mid=sec&amp;oid=023&amp;listType=title&amp;date=20220820">제목형</a>
# <a class="sum_on nclicks(fls.vtype)" href="list.naver;jsessionid=D097AD05257A864A14AB6DB138738002?mode=LPOD&amp;mid=sec&amp;oid=023&amp;listType=summary&amp;date=20220820">요약형</a>
# <a class="photo_off nclicks(fls.vtype)" href="list.naver;jsessionid=D097AD05257A864A14AB6DB138738002?mode=LPOD&amp;mid=sec&amp;oid=023&amp;listType=photo&amp;type=3&amp;date=20220820">포토만</a>
# </div>
# </div>
# <div class="newspaper_area">
# <h5></h5><p class="data_txt">2022년 08월 20일 신문게재기사  </p>
# <a class="nclicks(cnt_prsall)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=023&amp;listType=paper&amp;date=20220820">전체보기</a>
# <ul class="type13 firstlist">
# <li>
# <dl>
# <dt><a class="nclicks(cnt_papaerart)" href="https://n.news.naver.com/mnews/article/023/0003710999">두 배 비싸게 만든 김원웅식 위인전… 김구 290쪽, 모친은 430쪽</a>
# <i class="icon_photo">포토</i>
# <span class="writing">조선일보</span>
# <span class="newspaper_info" title="신문에 게재되었으며 A1면의 기사입니다."><i class="picon">신문</i>A1면 </span>
# <span class="date">2022.08.20. 오전 3:01</span>
# </dt>
# </dl>
# </li>
# <li>
# <dl>
# <dt><a class="nclicks(cnt_papaerart)" href="https://n.news.naver.com/mnews/article/023/0003711003">[NOW] ‘카톡 손주’ 덕분에 스마트폰·키오스크 혼자서도 잘 써요</a>
# <span class="writing">조선일보</span>
# <span class="newspaper_info" title="신문에 게재되었으며 A1면의 기사입니다."><i class="picon">신문</i>A1면 </span>
# <span class="date">2022.08.20. 오전 3:01</span>
# </dt>
# </dl>
# </li>
# <li>
# <dl>
# <dt><a class="nclicks(cnt_papaerart)" href="https://n.news.naver.com/mnews/article/023/0003710998">월성·북송… 대통령기록관 하루 두번 압수수색</a>
# <i class="icon_photo">포토</i>
# <span class="writing">조선일보</span>
# <span class="newspaper_info" title="신문에 게재되었으며 A1면의 기사입니다."><i class="picon">신문</i>A1면 </span>
# <span class="date">2022.08.20. 오전 3:01</span>
# </dt>
# </dl>
# </li>
# <li>
# <dl>
# <dt><a class="nclicks(cnt_papaerart)" href="https://n.news.naver.com/mnews/article/023/0003710979">저소득층 의료비 최대 5000만원 지원... 적용대상도 6대중증→모든 질환</a>
# <i class="icon_photo">포토</i>
# <span class="writing">조선일보</span>
# <span class="newspaper_info" title="신문에 게재되었으며 A1면의 기사입니다."><i class="picon">신문</i>A1면 </span>
# <span class="date">2022.08.19. 오후 9:14</span>
# </dt>
# </dl>
# </li>
# </ul>
# </div>
# <ul class="type06_headline">
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711100">
# <img alt="펜스 前 부통령 “퇴임 때 기밀정보 가져간 적 없다”" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2022/08/20/3711100.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711100">
# 								 펜스 前 부통령 “퇴임 때 기밀정보 가져간 적 없다”
# 								</a>
# </dt>
# <dd>
# <span class="lede">도널드 트럼프 전 미국 대통령이 퇴임 때 기밀 문서를 플로리다 마러라고 사저로 무단 반출한 혐의로 미 연방수사국(FBI)의 수사 …</span>
# <span class="writing">조선일보</span>
# <span class="date is_new">3분전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711099">
# <img alt="다크웹서 대마 판매, 2심 ‘범죄집단’ 인정... 총책 징역 7년" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2022/08/20/3711099.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711099">
# 								 다크웹서 대마 판매, 2심 ‘범죄집단’ 인정... 총책 징역 7년
# 								</a>
# </dt>
# <dd>
# <span class="lede">특정 프로그램을 사용해야 접속할 수 있는 이른바 ‘다크웹’을 통해 대마를 판매한 일당이 1심에 이어 2심에서도 ‘범죄집단’으로  …</span>
# <span class="writing">조선일보</span>
# <span class="date is_new">20분전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711098">
# <img alt="상품권 싸게 판 뒤 잠적… 중고거래 사기친 20대 징역 4년" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2022/08/20/3711098.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711098">
# 								 상품권 싸게 판 뒤 잠적… 중고거래 사기친 20대 징역 4년
# 								</a>
# </dt>
# <dd>
# <span class="lede">중고나라, 당근마켓과 같은 중고거래 플랫폼에 허위매물을 올려 피해자 140여명으로부터 2억여원을 챙긴 20대 남성이 1심에서 실 …</span>
# <span class="writing">조선일보</span>
# <span class="date is_new">25분전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711097">
# <img alt="김재원 “피해자는 윤석열, 피해호소인은 이준석”" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2022/08/20/3711097.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711097">
# 								 김재원 “피해자는 윤석열, 피해호소인은 이준석”
# 								</a>
# </dt>
# <dd>
# <span class="lede">김건희 여사 논란엔 “과도하게 비난받는다” 김재원 전 국민의힘 최고위원은 20일 이준석 대표를 둘러싼 당내 갈등에 대해 “피해자 …</span>
# <span class="writing">조선일보</span>
# <span class="date is_new">27분전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711096">
# <img alt="할인행사 비용 가맹점주에 떠넘긴 LG생건... 과징금 취소소송 패소" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2022/08/20/3711096.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711096">
# 								 할인행사 비용 가맹점주에 떠넘긴 LG생건... 과징금 취소소송 패소
# 								</a>
# </dt>
# <dd>
# <span class="lede">더페이스샵 화장품 할인행사를 하며 가맹점주에 제품 할인 비용을 떠넘겼다는 이유로 시정명령 및 과징금 납부명령을 받은 LG생활건강 …</span>
# <span class="writing">조선일보</span>
# <span class="date is_new">33분전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711095">
# <img alt="“현수 바다에 빠뜨려야 하나” 이은해, 후배와 나눈 문자 속엔…" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2022/08/20/3711095.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711095">
# 								 “현수 바다에 빠뜨려야 하나” 이은해, 후배와 나눈 문자 속엔…
# 								</a>
# </dt>
# <dd>
# <span class="lede">계곡 살인 사건 피의자 이은해(31)씨가 지인과의 문자 메시지를 통해 공범인 내연남 조현수(30)씨를 언급하며 ‘바다에 빠뜨려야 …</span>
# <span class="writing">조선일보</span>
# <span class="date is_new">50분전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711094">
# <img alt="북한, GDP 대비 군사비 지출 23%로 세계 1위...한국은?" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2022/08/20/3711094.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711094">
# 								 북한, GDP 대비 군사비 지출 23%로 세계 1위...한국은?
# 								</a>
# </dt>
# <dd>
# <span class="lede">전 세계에서 국내총생산(GDP) 대비 군비를 가장 많이 쓰는 나라는 북한인 것으로 드러났다. 미국 국무부가 18일(현지 시각)  …</span>
# <span class="writing">조선일보</span>
# <span class="date is_outdated">1시간전	</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711093">
# <img alt="‘논리의 힘’ 없는 독재 정권이  ‘힘의 논리’로 표현의 자유 탄압" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2022/08/20/3711093.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711093">
# 								 ‘논리의 힘’ 없는 독재 정권이  ‘힘의 논리’로 표현의 자유 탄압
# 								</a>
# </dt>
# <dd>
# <span class="lede">송재윤의 슬픈 중국: 대륙의 자유인들 &lt;45회&gt; 중국 공산당, 왜 헌법에 보장된 ‘표현의 자유’조차 허용 못하나 논리의 힘이 없 …</span>
# <span class="writing">조선일보</span>
# <span class="date is_outdated">1시간전	</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711092">
# <img alt="[Market Watch] 아직 공격적인 연준 따라… 한은 다시 한번 ‘빅스텝’?" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2022/08/20/3711092.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711092">
# 								 [Market Watch] 아직 공격적인 연준 따라… 한은 다시 한번 ‘빅스텝’?
# 								</a>
# </dt>
# <dd>
# <span class="lede">이번주 증시는 인플레이션이 정점을 지났다는 기대감과 공격적 기준금리 인상 기조를 접긴 이르다는 미국 연방준비제도 인사들의 발언이 …</span>
# <span class="writing">조선일보</span>
# <span class="date is_outdated">1시간전	</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711091">
# <img alt="美, 우크라에 1조 규모 무기 추가 지원…정찰 드론 스캔이글 첫 투입" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2022/08/20/3711091.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711091">
# 								 美, 우크라에 1조 규모 무기 추가 지원…정찰 드론 스캔이글 첫 투입
# 								</a>
# </dt>
# <dd>
# <span class="lede">미국 국방부는 19일(현지 시각) 우크라이나에 7억7500만 달러(약 1조354억 원) 규모의 무기 패키지를 추가로 지원한다고  …</span>
# <span class="writing">조선일보</span>
# <span class="date is_outdated">1시간전	</span>
# </dd>
# </dl>
# </li>
# </ul>
# <ul class="type06">
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711090">
# <img alt="“벌금만 10조원”… 휠체어 납치 5년 뒤 나타난 中 억만장자 최후" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2022/08/20/3711090.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711090">
# 								 “벌금만 10조원”… 휠체어 납치 5년 뒤 나타난 中 억만장자 최후
# 								</a>
# </dt>
# <dd>
# <span class="lede">5년간 행방불명 상태였다가 최근 근황이 전해진 중국 재벌 샤오젠화(肖建華·50) 밍톈그룹 회장이 중국 법원으로부터 징역 13년형 …</span>
# <span class="writing">조선일보</span>
# <span class="date is_outdated">1시간전	</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711089">
# <img alt="Conductor Goes Viral with Computer Game Theme Tunes" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2022/08/20/3711089.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711089">
# 								 Conductor Goes Viral with Computer Game Theme Tunes
# 								</a>
# </dt>
# <dd>
# <span class="lede">Jin Sol has gone viral by conducting live orchestral performances of th …</span>
# <span class="writing">조선일보</span>
# <span class="date is_outdated">2시간전	</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711088">
# 								 Rags-to-Riches Stories Outsell Self-Help Books
# 								</a>
# </dt>
# <dd>
# <span class="lede">Get-rich-quick books by successful people have overtaken self-help and  …</span>
# <span class="writing">조선일보</span>
# <span class="date is_outdated">2시간전	</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711087">
# <img alt="MLB 최고령 푸홀스의 ‘라스트 댄스’… 통산 700홈런 가능할까" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2022/08/20/3711087.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711087">
# 								 MLB 최고령 푸홀스의 ‘라스트 댄스’… 통산 700홈런 가능할까
# 								</a>
# </dt>
# <dd>
# <span class="lede">지난 19일(한국 시각) MLB(미 프로야구) 세인트루이스 카디널스와 콜로라도 로키스의 내셔널리그 경기. 홈팀 카디널스가 6대0 …</span>
# <span class="writing">조선일보</span>
# <span class="date is_outdated">2시간전	</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711086">
# <img alt="문 정부  50조  도시재생도 외면한 반지하,  이번엔 저렴주택 임대대란?" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2022/08/20/3711086.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711086">
# 								 문 정부  50조  도시재생도 외면한 반지하,  이번엔 저렴주택 임대대란?
# 								</a>
# </dt>
# <dd>
# <span class="lede">문 정부, 주거지 정비 등 도시재생사업에 50조 투자 반지하에 전시장, 사랑방 만들면서 안전문제는 외면 신통기획 등 재건축 재개 …</span>
# <span class="writing">조선일보</span>
# <span class="date is_outdated">2시간전	</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711085">
# <img alt="[더 한장] 코로나 걱정않는...인도 힌두 축제" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2022/08/20/3711085.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711085">
# 								 [더 한장] 코로나 걱정않는...인도 힌두 축제
# 								</a>
# </dt>
# <dd>
# <span class="lede">8월 19일 인도 뭄바이에서 열린 힌두교 잔마쉬타미 축제에서 인간 피라미드을 쌓기 위해 모인 사람들이 마스크도 없이 빽빽하게 엉 …</span>
# <span class="writing">조선일보</span>
# <span class="date is_outdated">2시간전	</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711084">
# <img alt="‘광란의 파티’ 즐기다 마약까지?… 핀란드 총리, 결국 검사받았다" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2022/08/20/3711084.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711084">
# 								 ‘광란의 파티’ 즐기다 마약까지?… 핀란드 총리, 결국 검사받았다
# 								</a>
# </dt>
# <dd>
# <span class="lede">“우려 덜기 위한 검사, 평생 마약한 적 없다” 정치인·연예인들과 광란의 파티를 즐기는 영상이 유출되며 논란을 빚은 30대 핀란 …</span>
# <span class="writing">조선일보</span>
# <span class="date is_outdated">3시간전	</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711083">
# <img alt="이준석, 윤리위 경고에 “尹 ‘내부총질’ 문자는 어떤 처결할 건가”" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2022/08/20/3711083.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711083">
# 								 이준석, 윤리위 경고에 “尹 ‘내부총질’ 문자는 어떤 처결할 건가”
# 								</a>
# </dt>
# <dd>
# <span class="lede">이준석 국민의힘 전 대표가 19일 ‘엄정 심의’를 언급하며 경고 메시지를 낸 당 윤리위원회를 향해 “당내 가장 큰 분란을 초래했 …</span>
# <span class="writing">조선일보</span>
# <span class="date is_outdated">3시간전	</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711082">
# <img alt="[단독] 독립운동가 신익희가 23세에 쓴 ‘일분몽구’… 1440字에 담긴 비밀" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2022/08/20/3711082.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711082">
# 								 [단독] 독립운동가 신익희가 23세에 쓴 ‘일분몽구’… 1440字에 담긴 비밀
# 								</a>
# </dt>
# <dd>
# <span class="lede">맏형의 장손 첫돌에 쓴 책 후손이 105년 만에 첫 공개 “형님, 귀한 손자의 첫돌을 축하드립니다. 아기 선물로 책 한 권 써서 …</span>
# <span class="writing">조선일보</span>
# <span class="newspaper_info" title="신문에 게재되었으며 B3면의 기사입니다."><i class="picon">신문</i>B3면 </span>
# <span class="date is_outdated">5시간전	</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711081">
# <img alt="“내 별 수백만 목숨과 바꿨다 생각” 주한미군 철수 반대했던 싱글러브 장군 안장식" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2022/08/20/3711081.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003711081">
# 								 “내 별 수백만 목숨과 바꿨다 생각” 주한미군 철수 반대했던 싱글러브 장군 안장식
# 								</a>
# </dt>
# <dd>
# <span class="lede">알링턴국립묘지에서 안장식...尹대통령 조전 통해 “영원히 기억할 것” “전쟁난다” 반대하다 퇴역 생전 “수백만 한국인 목숨 지킨 …</span>
# <span class="writing">조선일보</span>
# <span class="date is_outdated">6시간전	</span>
# </dd>
# </dl>
# </li>
# </ul>
# </div>
# <div class="paging">
# <strong>1</strong>
# <a class="nclicks(fls.page)" href="?mode=LPOD&amp;mid=sec&amp;oid=023&amp;date=20220820&amp;page=2">2</a>
# <a class="nclicks(fls.page)" href="?mode=LPOD&amp;mid=sec&amp;oid=023&amp;date=20220820&amp;page=3">3</a>
# <a class="nclicks(fls.page)" href="?mode=LPOD&amp;mid=sec&amp;oid=023&amp;date=20220820&amp;page=4">4</a>
# <a class="nclicks(fls.page)" href="?mode=LPOD&amp;mid=sec&amp;oid=023&amp;date=20220820&amp;page=5">5</a>
# <a class="nclicks(fls.page)" href="?mode=LPOD&amp;mid=sec&amp;oid=023&amp;date=20220820&amp;page=6">6</a>
# </div>
# <h4 class="blind">뉴스 이전날짜 더보기 링크모음</h4>
# <div class="pagenavi_day">
# <span class="viewday">8월20일(토)</span><span class="devidebar">·</span><a class="nclicks(fls.date)" href="?mode=LPOD&amp;mid=sec&amp;oid=023&amp;date=20220819">8월19일(금)</a><span class="devidebar">·</span><a class="nclicks(fls.date)" href="?mode=LPOD&amp;mid=sec&amp;oid=023&amp;date=20220818">8월18일(목)</a><span class="devidebar">·</span><a class="nclicks(fls.date)" href="?mode=LPOD&amp;mid=sec&amp;oid=023&amp;date=20220817">8월17일(수)</a><span class="devidebar">·</span><a class="nclicks(fls.date)" href="?mode=LPOD&amp;mid=sec&amp;oid=023&amp;date=20220816">8월16일(화)</a></div>
# <script type="text/javascript">
# window.onload = function() {
# 	var selected_item = jindo.$('_');
# 	if (selected_item != null) {
# 		selected_item.className = "highlight";
# 		news.section.ScrollingManager.scroll('');
# 	}
# }
# news.section.MainIssueCollectManager.init({
# 	mediaOneDomain : 'https://n.news.naver.com'
# });
# news.util.CommentListCountManager.view();
# </script>
# </div>
# </td>
# <td class="aside">
# <div class="aside">
# <div class="section _officeTopRanking1087479">
# <h4>언론사별 가장 많이 본 뉴스</h4>
# <button class="section_info_icon nclicks('rig.renws2i') _rankingInfoButton" type="button">안내</button>
# <div class="section_info_layer _rankingInfoLayer" style="display: none">각 언론사의 가장 많이 본 기사 1건을 제공합니다. <button class="section_info_layer_close _rankingInfoCloseButton nclicks('rig.renws2x')" type="button"><span>닫기</span></button></div>
# <p class="section_sub_txt">오전 9시~오전 10시까지 집계한 결과입니다.</p>
# <ul class="section_list_ranking_press _rankingList" id="_rankingList0" style="display: block">
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/018/0005297008?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/018/2022/08/20/5297008.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/018/0005297008?ntype=RANKING&amp;sid=001">하룻새 시총 230兆 사라졌다…비트코인 다시 2만1천달러대 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=018"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/018/2018/07/18/logo_018_56_20180718152418.png" width="16"/></span>이데일리</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/081/0003295735?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/081/2022/08/20/3295735.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/081/0003295735?ntype=RANKING&amp;sid=001">“답답한 일본으로 가느니 한국으로 간다”...전세계 여행객 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=081"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/081/2022/01/05/logo_081_56_20220105195830.png" width="16"/></span>서울신문</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/055/0000994076?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/055/2022/08/20/994076.jpg?type=nf88_60" width="88"/>
# <strong class="r_ico r_vod_small">동영상기사</strong>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/055/0000994076?ntype=RANKING&amp;sid=001">도심 한복판에 잇따라 출몰한 정체…어쩌다가 여기까지?</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=055"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/055/2020/10/07/logo_055_56_20201007141807.jpg" width="16"/></span>SBS</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/469/0000692522?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/469/2022/08/20/692522.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/469/0000692522?ntype=RANKING&amp;sid=001">열흘도 못 간 ‘강남역 슈퍼맨’ 효과... 꽁초받이 된 빗 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=469"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/469/2018/07/20/logo_469_56_20180720194420.png" width="16"/></span>한국일보</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/437/0000310583?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/437/2022/08/19/310583.jpg?type=nf88_60" width="88"/>
# <strong class="r_ico r_vod_small">동영상기사</strong>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/437/0000310583?ntype=RANKING&amp;sid=001">[단독] 워터파크서 8분간 떠 있었는데…끝내 하늘로 간 아 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=437"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/437/2020/08/25/logo_437_56_20200825135552.png" width="16"/></span>JTBC</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <ul class="section_list_ranking_press _rankingList" id="_rankingList5" style="display: none">
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/092/0002265835?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/092/2022/08/20/2265835.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/092/0002265835?ntype=RANKING&amp;sid=001">비트코인, 2만2천달러 붕괴…3주만에 최저치</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=092"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/092/2018/07/18/logo_092_56_20180718153018.png" width="16"/></span>ZDNet Korea</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/009/0005006745?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/009/2022/08/20/5006745.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/009/0005006745?ntype=RANKING&amp;sid=001">이효리도 이건 꼭 한다…잡곡밥에 상추 먹고도 몸 키우는법  …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=009"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/009/2018/07/20/logo_009_56_20180720194820.png" width="16"/></span>매일경제</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/011/0004089572?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/011/2022/08/19/4089572.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/011/0004089572?ntype=RANKING&amp;sid=001">"람보르기니 침수차 100만원"…진짜 주인 등장 '대반전'</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=011"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/011/2022/07/29/logo_011_56_20220729150242.jpg" width="16"/></span>서울경제</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/028/0002603098?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/028/2022/08/19/2603098.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/028/0002603098?ntype=RANKING&amp;sid=001">국민대 교수회, ‘김건희 논문’ 검증 안 한다…“집단지성  …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=028"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/028/2018/08/01/logo_028_56_20180801163801.png" width="16"/></span>한겨레</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/052/0001779074?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/052/2022/08/20/1779074.jpg?type=nf88_60" width="88"/>
# <strong class="r_ico r_vod_small">동영상기사</strong>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/052/0001779074?ntype=RANKING&amp;sid=001">당 대표서 리스크로?...여권 덮친 이준석 3대 변수</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=052"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/052/2021/10/01/logo_052_56_20211001183149.png" width="16"/></span>YTN</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <ul class="section_list_ranking_press _rankingList" id="_rankingList10" style="display: none">
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/001/0013386861?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/001/2022/08/20/13386861.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/001/0013386861?ntype=RANKING&amp;sid=001">[OK!제보] 깻잎 먹는데 이상한 식감…뱉어보니 중국 담배 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=001"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/001/2020/08/11/logo_001_56_20200811154916.png" width="16"/></span>연합뉴스</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/022/0003726765?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/022/2022/08/20/3726765.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/022/0003726765?ntype=RANKING&amp;sid=001">“이은해, 숨진 윤씨를 남편 아니라 ‘애인대행’ 관계로 소 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=022"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/022/2018/07/18/logo_022_56_20180718152618.png" width="16"/></span>세계일보</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/005/0001547598?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/005/2022/08/20/1547598.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/005/0001547598?ntype=RANKING&amp;sid=001">이은해 “딸 성인될 때까지 금전 지원하면 자수”</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=005"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/005/2018/07/18/logo_005_56_20180718152218.png" width="16"/></span>국민일보</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/025/0003217904?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/025/2022/08/20/3217904.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/025/0003217904?ntype=RANKING&amp;sid=001">너덜너덜함에 숨은 반전…김혜수·지수도 홀린 '찢청'의 비밀</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=025"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/025/2021/08/20/logo_025_56_20210820165911.png" width="16"/></span>중앙일보</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/023/0003710745?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/023/2022/08/18/3710745.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/023/0003710745?ntype=RANKING&amp;sid=001">그녀가 골 넣고 상의 던지자 나이키가 웃었다 [WEEKLY …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=023"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/023/2020/04/29/logo_023_56_20200429140429.png" width="16"/></span>조선일보</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <ul class="section_list_ranking_press _rankingList" id="_rankingList15" style="display: none">
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/056/0011324383?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/056/2022/08/20/11324383.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/056/0011324383?ntype=RANKING&amp;sid=001">[여심야심] “대화 녹음하다 감옥 갈 수도?”…與 녹음 금 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=056"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/056/2021/10/28/logo_056_56_20211028103053.png" width="16"/></span>KBS</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/586/0000043540?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/586/2022/08/19/43540.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/586/0000043540?ntype=RANKING&amp;sid=001">안철수 "20%대 대통령 지지율 사상 초유의 일…특단의 대 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=586"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/586/2018/09/20/logo_586_56_20180920154020.png" width="16"/></span>시사저널</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/366/0000835306?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/366/2022/08/19/835306.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/366/0000835306?ntype=RANKING&amp;sid=001">“이렇게 빨리 식을 줄 몰랐다”… 불과 8개월 만에 오피스 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=366"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/366/2020/12/23/logo_366_56_20201223182636.png" width="16"/></span>조선비즈</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# ...
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/655/0000003993?ntype=RANKING&amp;sid=001">단양 중앙고속도로서 산사태... 2명 부상, 부산방향 전면 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=655"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/655/2022/01/20/logo_655_56_20220120164501.png" width="16"/></span>CJB청주방송</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000011733?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/661/2022/08/19/11733.jpg?type=nf88_60" width="88"/>
# <strong class="r_ico r_vod_small">동영상기사</strong>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000011733?ntype=RANKING&amp;sid=001">[자막뉴스] 임금 불만에 정비소 방화.. 한밤 주민 대피  …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=661"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/661/2022/01/19/logo_661_56_20220119142145.png" width="16"/></span>JIBS</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/658/0000017883?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/658/2022/08/20/17883.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/658/0000017883?ntype=RANKING&amp;sid=001">[영상] 발달장애 황성제 작가에게 ‘우영우’란</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=658"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/658/2022/01/20/logo_658_56_20220120164828.png" width="16"/></span>국제신문</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/353/0000043002?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/353/2022/08/20/43002.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/353/0000043002?ntype=RANKING&amp;sid=001">문 정부 청와대 겨냥 하루 두 번 압수수색</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=353"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/353/2018/09/20/logo_353_56_20180920154420.png" width="16"/></span>중앙SUNDAY</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000016856?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/145/2022/08/19/16856.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000016856?ntype=RANKING&amp;sid=001">‘완만한 혈당 곡선’ 만드는 5가지 식재료</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=145"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16"/></span>레이디경향</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <button class="refresh_button nclicks('rig.renws2new') _refreshButton" type="button">더보기</button>
# </div>
# <script type="text/javascript">
#     var OfficeTopRankingManager = jindo.$Class({
#         $static: {
#             RANKING_INFO_BUTTON_SELECTOR: '._rankingInfoButton',
#             RANKING_INFO_LAYER_SELECTOR : '._rankingInfoLayer',
#             RANKING_INFO_BUTTON_CLOSE_SELECTOR : '._rankingInfoCloseButton',
#             REFRESH_BUTTON_SELECTOR : '._refreshButton',
#             RANKING_LIST_SELECTOR : '._rankingList'
#         },
#
#         $init: function(base) {
#             this._welBase = jindo.$Element(base);
#             this._rankingInfoLayer = jindo.$Element(this._welBase.query(this.constructor.RANKING_INFO_LAYER_SELECTOR));
#             this._rankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_CLOSE_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.REFRESH_BUTTON_SELECTOR, jindo.$Fn(this._refreshRankingList, this).bind());
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.hide();
#         },
#
#         _refreshRankingList: function(event) {
#             event.stopDefault();
#
#             for (var i=0 ; i<this._rankingListArray.length() ; i++) {
#                 var rankingList = this._rankingListArray.get(i);
#
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._rankingListArray.length()) {
#                         nextIndex = 0;
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087479");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
# </script>
# <div class="side_ad" id="glad_ad_sidebox"></div>
# <div class="section" id="right_dailyList" style="margin-bottom:20px; white-space:nowrap;">
# <h4>분야별 주요뉴스</h4>
# <div class="classfy sd" style="display:block">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/022/0003726777?sid=100" title="尹 “법 개정 필요한 것 많아”… 국회에 협조 당부">尹 “법 개정 필요한 것 많아”… 국회에 협조 당부</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/025/0003217914?sid=100" title="[단독] 尹정부, 임기내 '1기 신도시 재정비' 첫삽 뜰 계획 없다 [뉴스원샷]">[단독] 尹정부, 임기내 '1기 신도시 재정비' 첫삽 뜰 계획 없다 [뉴스원샷]</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/422/0000556633?sid=100" title="김여정 '담대한 구상' 막말 비난…시작부터 좌초 위기 관측">김여정 '담대한 구상' 막말 비난…시작부터 좌초 위기 관측</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/081/0003295755?sid=104" title="‘광란의 파티’ 즐긴 핀란드 최연소 총리, 결국 마약검사 받았다">‘광란의 파티’ 즐긴 핀란드 최연소 총리, 결국 마약검사 받았다</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/214/0001216913?sid=104" title='"제2의 체르노빌 사태 우려"‥푸틴, 원전 시찰 동의'>"제2의 체르노빌 사태 우려"‥푸틴, 원전 시찰 동의</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/016/0002030743?sid=101" title="“그룹 절반 날아갈 수 있지만 삼성이 모험해야” 이재용이 새긴 이 한마디 [비즈360]">“그룹 절반 날아갈 수 있지만 삼성이 모험해야” 이재용이 새긴 이 한마디 [비즈360]</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/029/0002749840?sid=101" title="금융노조, 파업 결의…`귀족노조 이기주의` 비판 거세">금융노조, 파업 결의…`귀족노조 이기주의` 비판 거세</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/056/0011324401?sid=101" title="변함없는 ‘치킨 사랑’ 파고든 ‘마트 치킨’ 열풍 뒤엔…">변함없는 ‘치킨 사랑’ 파고든 ‘마트 치킨’ 열풍 뒤엔…</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/138/0002131077?sid=105" title="3000억원 규모 '슈퍼컴 6호기' 예타 통과">3000억원 규모 '슈퍼컴 6호기' 예타 통과</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/005/0001547605?sid=105" title="우크라이나에서 갤럭시 Z 폴드4·플립4의 ‘Z’ 빠진 이유">우크라이나에서 갤럭시 Z 폴드4·플립4의 ‘Z’ 빠진 이유</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/001/0013386930?sid=102" title="12만9411명 확진…어제보다 9401명↓…사망 84명, 113일만 최다(종합)">12만9411명 확진…어제보다 9401명↓…사망 84명, 113일만 최다(종합)</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/214/0001216907?sid=102" title="'강제 북송' '원전 폐쇄'‥대통령 기록관 압수수색">'강제 북송' '원전 폐쇄'‥대통령 기록관 압수수색</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003676594?sid=102" title="[단독]국민대 교수회 '김건희 표절 재조사' 투표 중 총장 측 '압박' 메일">[단독]국민대 교수회 '김건희 표절 재조사' 투표 중 총장 측 '압박' 메일</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/052/0001779080?sid=103" title="[날씨] 중부 비 그친 뒤 무더위, 남부 비 오며 더위 주춤">[날씨] 중부 비 그친 뒤 무더위, 남부 비 오며 더위 주춤</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/119/0002631909?sid=103" title="[오늘날씨] 남부지방 아침부터 '비'…서울 최고기온 33도 '더위'">[오늘날씨] 남부지방 아침부터 '비'…서울 최고기온 33도 '더위'</a> </li>
# </ul>
# </ul>
# </ul>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://factcheck.snu.ac.kr/" target="_blank"> <img alt="온라인 허위정보, 팩트체크 어떻게 확인할까요" src="https://imgnews.pstatic.net/image/upload/item/2020/02/05/175955946_%2540banner_300X80_pc.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183022480_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/hotissue/sectionList.naver?mid=hot&amp;sid1=100&amp;cid=909906&amp;decorator=ombudsman&amp;confirm=true"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">서비스 안내</span>더보기</a>
# </div>
# <script>
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
# </script>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <hr/>
# <div class="index">
# <div class="index_inner">
# <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>
# <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>
# </div>
# </div>
# <hr/>
# <div id="footer">
# <ul>
# <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
# <li><a class="nclicks(fot.guide)" href="/main/ombudsman/index.naver">서비스 안내</a></li>
# <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.naver?mid=omb">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
# <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
# <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">뉴스 고객센터</a></li>
# </ul>
# <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address class="address_nhn">
# <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ©</em>
# <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# <!-- -->
# </div>
# <script type="text/javascript">
#
#
#
#
#
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.naver'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.naver'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#     (function() {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
# new news.flash.SubsectionLayerManager('n.f.subsection.layer');
#
#
# new MyFeed()
#     .init({
#         sMyFeedUrl: 'https://me.naver.com/tab/feed/news.nhn',
#         apiUrlMap: {
#             'check': 'https://apis.naver.com/newsweb/media/subscribedChannels?hasFollowerCount=true',
#             'follow': 'https://apis.naver.com/newsweb/media/doSubscribe',
#             'unfollow': 'https://apis.naver.com/newsweb/media/cancelSubscribe'
#         }
#     });
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </body>
# </html>

# %%
bs.select('div.paging a')[-1]
# Out:
# <a class="nclicks(fls.page)" href="?mode=LPOD&amp;mid=sec&amp;oid=023&amp;date=20220820&amp;page=6">6</a>

# %%
response = requests.get('https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=023&date=20220820&page=1000', headers = {'User-Agent':'Mozilla 5.0'})
bs = BeautifulSoup(response.text, 'lxml')
last_page_num = bs.select('div.paging > strong')
last_page_num
# Out:
# [<strong>6</strong>]

# %%
last_page_num1 = int(last_page_num[0].text)
last_page_num1
# Out:
# 6

# %%
bs.select('li > dl >dt > a')
# 제목만 다가져오기


[tag.text for tag in bs.select('li > dl >dt > a') if tag.text != '\n\n']
[tag.text.replace('\n',"").replace('\t','').strip() for tag in bs.select('li > dl >dt > a') if tag.text != '\n\n']
# Out:
# ['손잡은 한미 포병',
#  '추석연휴 기차 예매율 9월 9일·12일이 80%대',
#  '철도 역세권 투자법 부동산 절세 전략… 전문가들 비법 공개',
#  '[NOW] ‘카톡 손주’ 덕분에 스마트폰·키오스크 혼자서도 잘 써요',
#  '한국갤럽 尹지지율 조사, 긍정평가 3%p 올라 28%',
#  '“7명 살리고 떠난 아드님 뜻, 저희가 이을게요”',
#  '“엄마가 내 어린시절 노출해 큰 피해 봤어요” 일본서 셰어런팅 역풍',
#  '두 배 비싸게 만든 김원웅식 위인전… 김구 290쪽, 모친은 430쪽',
#  '월성·북송… 대통령기록관 하루 두번 압수수색',
#  '갤Z폴드·Z플립, 이번에도 우크라에선 ‘Z’ 빠졌다',
#  '[백영옥의 말과 글](266) 글 쓰는 일']

# %%
#page 6개의 내용가져오기


title2 = []
for i in range (1, last_page_num1+1):
    url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=023&date=20220820&page={i}'
    response = requests.get(url, headers = {'User-Agent':'Mozilla 5.0'})
    bs= BeautifulSoup(response.text, 'lxml')
    title1 = [tag.text.replace('\n',"").replace('\t','').strip() for tag in bs.select('li > dl >dt > a') if tag.text != '\n\n']
    title2 += title1
title2
# Out:
# ['저소득층 의료비 최대 5000만원 지원... 적용대상도 6대중증→모든 질환',
#  '두 배 비싸게 만든 김원웅식 위인전… 김구 290쪽, 모친은 430쪽',
#  '월성·북송… 대통령기록관 하루 두번 압수수색',
#  '[NOW] ‘카톡 손주’ 덕분에 스마트폰·키오스크 혼자서도 잘 써요',
#  '“尹도 당했다” 박근혜의 고추가루, 반기문의 퇴주 음복... 온라인 이미지 조작[더블클릭]',
#  '아내 둔기로 내리치자 자녀들이 신고… 40대 남성 경찰에 체포',
#  '정신질환 가족력 있는 여성은 조심… ‘이 병’ 위험 2배 높았다',
#  '[박기자 쇄담] 유종의 미 노리는 다닐 메드베데프',
#  '권성동 “김원웅, 광복회장 직함 달고 자기 가족 우상화…역사 팔아먹은 매국행위”',
#  '다뉴브강 말라붙자...2차대전 때 침몰한 독일 군함들 드러났다',
#  '펜스 前 부통령 “퇴임 때 기밀정보 가져간 적 없다”',
#  '다크웹서 대마 판매, 2심 ‘범죄집단’ 인정... 총책 징역 7년',
#  '상품권 싸게 판 뒤 잠적… 중고거래 사기친 20대 징역 4년',
#  '김재원 “피해자는 윤석열, 피해호소인은 이준석”',
#  '할인행사 비용 가맹점주에 떠넘긴 LG생건... 과징금 취소소송 패소',
#  '“현수 바다에 빠뜨려야 하나” 이은해, 후배와 나눈 문자 속엔…',
#  '북한, GDP 대비 군사비 지출 23%로 세계 1위...한국은?',
#  '‘논리의 힘’ 없는 독재 정권이  ‘힘의 논리’로 표현의 자유 탄압',
#  '[Market Watch] 아직 공격적인 연준 따라… 한은 다시 한번 ‘빅스텝’?',
#  '美, 우크라에 1조 규모 무기 추가 지원…정찰 드론 스캔이글 첫 투입',
#  '“벌금만 10조원”… 휠체어 납치 5년 뒤 나타난 中 억만장자 최후',
#  'Conductor Goes Viral with Computer Game Theme Tunes',
#  'Rags-to-Riches Stories Outsell Self-Help Books',
#  'MLB 최고령 푸홀스의 ‘라스트 댄스’… 통산 700홈런 가능할까',
#  '문 정부  50조  도시재생도 외면한 반지하,  이번엔 저렴주택 임대대란?',
#  '[더 한장] 코로나 걱정않는...인도 힌두 축제',
#  '‘광란의 파티’ 즐기다 마약까지?… 핀란드 총리, 결국 검사받았다',
#  '이준석, 윤리위 경고에 “尹 ‘내부총질’ 문자는 어떤 처결할 건가”',
#  '[단독] 독립운동가 신익희가 23세에 쓴 ‘일분몽구’… 1440字에 담긴 비밀',
#  '“내 별 수백만 목숨과 바꿨다 생각” 주한미군 철수 반대했던 싱글러브 장군 안장식',
#  '[사설] 전기차로 번진 미·중 전쟁 파고, 기업 혼자 헤쳐 나갈 수 없다',
#  '[사설] ‘세월호 7시간’ 무죄 확정, 의혹 제기한 文 정권은 사과해야',
#  '[사설] 목욕·가발에 법카, 공금으로 가족 우상화, 김원웅의 파렴치',
#  '[朝鮮칼럼 The Column] 말 많은 사회와 대통령의 소통',
#  '[만물상] 공급 달리는 필수 의료',
#  '중국몽 자신감 이면에는… 시진핑의 조급함이 있다',
#  '시장의 숨은 고수들은 살림의 모든 해답을 안다',
#  '‘골프계 우영우’ 이승민 “또 태어나도 엄마 아들로”… 엄마는 웃다 울었다',
#  '[아무튼, 주말] 소멸 위기 신안군을 살려낸 ‘수선화의 기적’',
#  '아이는 모두 부모 책임? ‘애착 육아’ 강박은 잊어라',
#  '수퍼카 싸다고 덜컥 구입?… ‘도로 위 시한폭탄’ 사는 겁니다',
#  '교수가 된 ‘용접 아이돌’… “그 힘든 걸 왜 하냐고요? 재미있으니까!”',
#  '‘코로나 갈라파고스’에서 탈출하는 방법',
#  '갑옷 같은 껍질 보드라운 속살… 과묵하지만 섬세한 제빵사 닮았네',
#  '야금, 독널, 그리고 백제금동대향로',
#  '치킨 3만원 시대에 6990원… 이번엔 맛과 가격 모두 통했다',
#  '[아무튼, 주말] ‘우리 對 그들’ 적개심 부추기는 이슬람 극단주의… 한국은 예외일까?',
#  '[아무튼, 주말] ‘1일 1망언’이 정치권 新트렌드? “성찰 없는 지도자, 책임 잊은 정치인 입에서 망언 나온다”',
#  '[아무튼, 주말] ‘위대한 개츠비’의 그들도 얼음 가득 찬 이 술을 마셨다',
#  '[아무튼, 주말] “웰컴 투 터키, 아차차! 튀르키예”',
#  '[TV조선] 남편을 땅에 묻는 아내',
#  '자유인과 호구 사이에서',
#  '[우석훈의 달달하게 책읽기] 청년 남성이 바라보는 페미니즘은…',
#  '[아무튼, 주말] 555미터 서울 하늘에서의 하룻밤',
#  '[특파원 리포트] ‘오샤레 한국’ 명성 지키려면',
#  '[아무튼, 주말] 골방을 나와 세상으로',
#  '[북카페] ‘아편과 조선’ 외',
#  '[아무튼, 주말] 무등산 춘설헌에서 ‘숲멍’ 즐기고, 소쇄원 대숲길 걸으며 안빈낙도 배웠다',
#  '‘빛’에 세금을 부과하자… 사람들은 창문을 없애기 시작했다',
#  'R&D단지에 20兆… 이재용“세상에 없는 기술로 미래 만들자”',
#  '“지금이 내 집 마련 기회될수도””조정 장세 길어질 가능성”',
#  '한기정 공정위장 후보 “기업에 대한 규제 풀고 마음껏 활동하게 해야”',
#  '[당신의 책꽂이] 변호사 조우성의 ‘지혜를 배울 수 있는 고전 5′',
#  '환율 장중 1328원, 글로벌 금융위기 이후 최고',
#  '용인덕영·전주영생·매탄 8강 안착',
#  '원희룡 “겹겹 규제 풀어, 출퇴근 편한 도심 주택 공급 늘릴 것”',
#  '내 죽음을 슬퍼하지 마… 솜사탕같이 달콤한 꿈만 꾸기를',
#  '[TV조선] 가수 서지오의 인생 이야기',
#  '[플라자] 유럽한인총연합회 ‘유럽한인 100년의 발자취’ 출판 기념회 개최',
#  '[요즘 서점가] ‘불편한 편의점 2′ 종합 베스트 2위에',
#  '[한줄읽기] ‘사이먼 샤마의 영국사 1′ 외',
#  '김연경 빠진 흥국생명, 결승 진출 좌절',
#  '실패하고싶지 않다면 ‘초발심’을 기억하세요',
#  '[황석희의 영화 같은 하루] [84] It’s much easier to kill',
#  '세상에 모기가 사라지면 초콜릿을 못 먹는다고?',
#  '[주식 매매 상위 종목 및 환율] 2022년 8월 19일자',
#  'KIA ‘눈에는 눈’',
#  '[부음] 강난예 별세 외',
#  '[오늘의 경기] 2022년 8월 20일',
#  '[그림이 있는 도서관] 으스스한 숲길·깊은 땅굴도 친구와 함께면 무섭지 않아요',
#  '코로나 이후의 동남아 ‘아시아의 EU’ 될까',
#  '[터치! 코리아] 반지하는 죄가 없다',
#  '[인사] 교육부 외',
#  '[편집자 레터] 여름과 헤어질 무렵',
#  '[내일의 경기] 2022년 8월 21일',
#  '“건강하면 봉사를… 더 건강해집니다”',
#  '‘인종·여성 차별의 벽’ 하늘에는 없었다',
#  '[스포츠 브리핑] 황인범, 올림피아코스 데뷔전 동점골 외',
#  '조선 3사, 상반기 수주 호황에도 1조5000억 적자',
#  '北 “핵은 국체, 흥정못해”… 대통령실 “유감”',
#  '[오늘의 날씨] 2022년 8월 20일',
#  '그림처럼 다가오는 가을',
#  '윤이나, 3년간 한국여자오픈서 못본다',
#  '尹 “경찰권한 크게 확대돼, 책임에 맞는 체계를”',
#  '프리미어리그 손흥민·황희찬, 오늘 맞대결',
#  '[핫 코너] ‘강남 비키니 커플’ 과다노출罪 입건 시끌',
#  '서울 기습 폭우… 우산 대신 가방으로 방어',
#  '서울 하수관 배수문제 생기면 ‘경보’ 울리게',
#  '뇌·심장수술 의료수가 올리고 필수인력 키운다',
#  '대법 “김기춘, 세월호 보고조작 안했다”',
#  '반려견 수영장·운동장·호텔까지 갖춘 ‘휴견소’',
#  '‘李 방탄 꼼수’野 당헌 개정안 의결',
#  '[바로잡습니다] 16일 자 A22면 ‘초속 2~3m의 빠른 해류… 해안에서 먼바다로 흘러요’ 기사에서 외',
#  '대통령실 “1기 신도시 재정비, 최대한 빠르게 추진”',
#  '손잡은 한미 포병',
#  '추석연휴 기차 예매율 9월 9일·12일이 80%대',
#  '철도 역세권 투자법 부동산 절세 전략… 전문가들 비법 공개',
#  '[NOW] ‘카톡 손주’ 덕분에 스마트폰·키오스크 혼자서도 잘 써요',
#  '한국갤럽 尹지지율 조사, 긍정평가 3%p 올라 28%',
#  '“7명 살리고 떠난 아드님 뜻, 저희가 이을게요”',
#  '“엄마가 내 어린시절 노출해 큰 피해 봤어요” 일본서 셰어런팅 역풍',
#  '두 배 비싸게 만든 김원웅식 위인전… 김구 290쪽, 모친은 430쪽',
#  '월성·북송… 대통령기록관 하루 두번 압수수색',
#  '갤Z폴드·Z플립, 이번에도 우크라에선 ‘Z’ 빠졌다',
#  '[백영옥의 말과 글](266) 글 쓰는 일']

# %%
#해당내역을 함수화해보기
def get_bs_data_from_naver_news(oid, date, page):
    for page in range (1, last_page_num1+1):
        url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid={oid}&date={date}&page={page}'
        response = requests.get(url, headers = {'User-Agent':'Mozilla 5.0'})
        bs= BeautifulSoup(response.text, 'lxml')

    return bs

# %%
# 함수 만들기
def get_titiles_from_tags(bs: BeautifulSoup):
    return [tag.text.replace('\n',"").replace('\t','').strip() for tag in bs.select('li > dl >dt > a') if tag.text != '\n\n']

# %%
bs = get_bs_data_from_naver_news('023', '20220820',1000)
_last_page_num = bs.select('div.paging>strong')
last_page_num = int(_last_page_num[0].text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\user\Documents\github_jd\Start_Big_Data_MegaIT\day05.ipynb 셀 45 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/github_jd/Start_Big_Data_MegaIT/day05.ipynb#Y101sZmlsZQ%3D%3D?line=0'>1</a> bs = get_bs_data_from_naver_news('023', '20220820',1000)
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/github_jd/Start_Big_Data_MegaIT/day05.ipynb#Y101sZmlsZQ%3D%3D?line=1'>2</a> _last_page_num = bs.select('div.paging>strong')
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/github_jd/Start_Big_Data_MegaIT/day05.ipynb#Y101sZmlsZQ%3D%3D?line=2'>3</a> last_page_num = int(_last_page_num[0].text)
#
# c:\Users\user\Documents\github_jd\Start_Big_Data_MegaIT\day05.ipynb 셀 45 in get_bs_data_from_naver_news(oid, date, page)
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/github_jd/Start_Big_Data_MegaIT/day05.ipynb#Y101sZmlsZQ%3D%3D?line=1'>2</a> def get_bs_data_from_naver_news(oid, date, page):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/github_jd/Start_Big_Data_MegaIT/day05.ipynb#Y101sZmlsZQ%3D%3D?line=2'>3</a>     for page in range (1, last_page_num1+1):
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/github_jd/Start_Big_Data_MegaIT/day05.ipynb#Y101sZmlsZQ%3D%3D?line=3'>4</a>         url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid={oid}&date={date}&page={page}'
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/github_jd/Start_Big_Data_MegaIT/day05.ipynb#Y101sZmlsZQ%3D%3D?line=4'>5</a>         response = requests.get(url, headers = {'User-Agent':'Mozilla 5.0'})
#
# NameError: name 'last_page_num1' is not defined

# %%
title2 = []
for i in range (1, last_page_num1+1):
    response = get_bs_data_from_naver_news('023', '20220820',1000)
    title1 = get_titiles_from_tags(response)
    title2 += title1
title2
# Out:
# ['손잡은 한미 포병',
#  '추석연휴 기차 예매율 9월 9일·12일이 80%대',
#  '철도 역세권 투자법 부동산 절세 전략… 전문가들 비법 공개',
#  '[NOW] ‘카톡 손주’ 덕분에 스마트폰·키오스크 혼자서도 잘 써요',
#  '한국갤럽 尹지지율 조사, 긍정평가 3%p 올라 28%',
#  '“7명 살리고 떠난 아드님 뜻, 저희가 이을게요”',
#  '“엄마가 내 어린시절 노출해 큰 피해 봤어요” 일본서 셰어런팅 역풍',
#  '두 배 비싸게 만든 김원웅식 위인전… 김구 290쪽, 모친은 430쪽',
#  '월성·북송… 대통령기록관 하루 두번 압수수색',
#  '갤Z폴드·Z플립, 이번에도 우크라에선 ‘Z’ 빠졌다',
#  '[백영옥의 말과 글](266) 글 쓰는 일',
#  '손잡은 한미 포병',
#  '추석연휴 기차 예매율 9월 9일·12일이 80%대',
#  '철도 역세권 투자법 부동산 절세 전략… 전문가들 비법 공개',
#  '[NOW] ‘카톡 손주’ 덕분에 스마트폰·키오스크 혼자서도 잘 써요',
#  '한국갤럽 尹지지율 조사, 긍정평가 3%p 올라 28%',
#  '“7명 살리고 떠난 아드님 뜻, 저희가 이을게요”',
#  '“엄마가 내 어린시절 노출해 큰 피해 봤어요” 일본서 셰어런팅 역풍',
#  '두 배 비싸게 만든 김원웅식 위인전… 김구 290쪽, 모친은 430쪽',
#  '월성·북송… 대통령기록관 하루 두번 압수수색',
#  '갤Z폴드·Z플립, 이번에도 우크라에선 ‘Z’ 빠졌다',
#  '[백영옥의 말과 글](266) 글 쓰는 일',
#  '손잡은 한미 포병',
#  '추석연휴 기차 예매율 9월 9일·12일이 80%대',
#  '철도 역세권 투자법 부동산 절세 전략… 전문가들 비법 공개',
#  '[NOW] ‘카톡 손주’ 덕분에 스마트폰·키오스크 혼자서도 잘 써요',
#  '한국갤럽 尹지지율 조사, 긍정평가 3%p 올라 28%',
#  '“7명 살리고 떠난 아드님 뜻, 저희가 이을게요”',
#  '“엄마가 내 어린시절 노출해 큰 피해 봤어요” 일본서 셰어런팅 역풍',
#  '두 배 비싸게 만든 김원웅식 위인전… 김구 290쪽, 모친은 430쪽',
#  '월성·북송… 대통령기록관 하루 두번 압수수색',
#  '갤Z폴드·Z플립, 이번에도 우크라에선 ‘Z’ 빠졌다',
#  '[백영옥의 말과 글](266) 글 쓰는 일',
#  '손잡은 한미 포병',
#  '추석연휴 기차 예매율 9월 9일·12일이 80%대',
#  '철도 역세권 투자법 부동산 절세 전략… 전문가들 비법 공개',
#  '[NOW] ‘카톡 손주’ 덕분에 스마트폰·키오스크 혼자서도 잘 써요',
#  '한국갤럽 尹지지율 조사, 긍정평가 3%p 올라 28%',
#  '“7명 살리고 떠난 아드님 뜻, 저희가 이을게요”',
#  '“엄마가 내 어린시절 노출해 큰 피해 봤어요” 일본서 셰어런팅 역풍',
#  '두 배 비싸게 만든 김원웅식 위인전… 김구 290쪽, 모친은 430쪽',
#  '월성·북송… 대통령기록관 하루 두번 압수수색',
#  '갤Z폴드·Z플립, 이번에도 우크라에선 ‘Z’ 빠졌다',
#  '[백영옥의 말과 글](266) 글 쓰는 일',
#  '손잡은 한미 포병',
#  '추석연휴 기차 예매율 9월 9일·12일이 80%대',
#  '철도 역세권 투자법 부동산 절세 전략… 전문가들 비법 공개',
#  '[NOW] ‘카톡 손주’ 덕분에 스마트폰·키오스크 혼자서도 잘 써요',
#  '한국갤럽 尹지지율 조사, 긍정평가 3%p 올라 28%',
#  '“7명 살리고 떠난 아드님 뜻, 저희가 이을게요”',
#  '“엄마가 내 어린시절 노출해 큰 피해 봤어요” 일본서 셰어런팅 역풍',
#  '두 배 비싸게 만든 김원웅식 위인전… 김구 290쪽, 모친은 430쪽',
#  '월성·북송… 대통령기록관 하루 두번 압수수색',
#  '갤Z폴드·Z플립, 이번에도 우크라에선 ‘Z’ 빠졌다',
#  '[백영옥의 말과 글](266) 글 쓰는 일',
#  '손잡은 한미 포병',
#  '추석연휴 기차 예매율 9월 9일·12일이 80%대',
#  '철도 역세권 투자법 부동산 절세 전략… 전문가들 비법 공개',
#  '[NOW] ‘카톡 손주’ 덕분에 스마트폰·키오스크 혼자서도 잘 써요',
#  '한국갤럽 尹지지율 조사, 긍정평가 3%p 올라 28%',
#  '“7명 살리고 떠난 아드님 뜻, 저희가 이을게요”',
#  '“엄마가 내 어린시절 노출해 큰 피해 봤어요” 일본서 셰어런팅 역풍',
#  '두 배 비싸게 만든 김원웅식 위인전… 김구 290쪽, 모친은 430쪽',
#  '월성·북송… 대통령기록관 하루 두번 압수수색',
#  '갤Z폴드·Z플립, 이번에도 우크라에선 ‘Z’ 빠졌다',
#  '[백영옥의 말과 글](266) 글 쓰는 일']

# %% [markdown]
# #### 본문추출

# %%
bs.select('li > dl >dt > a')[0].attrs.get('href') #get은 키의 값을 기준으로 내용을 가져온다
# Out:
# 'https://n.news.naver.com/mnews/article/023/0003711006'

# %%
def get_body_urls_from_tags(bs: BeautifulSoup):
    return [tag.attrs.get('href') for tag in bs.select('li > dl >dt > a') if tag.text != '\n\n']

# %%
get_body_urls_from_tags(bs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\user\Documents\github_jd\Start_Big_Data_MegaIT\day05.ipynb 셀 50 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/github_jd/Start_Big_Data_MegaIT/day05.ipynb#Y113sZmlsZQ%3D%3D?line=0'>1</a> get_body_urls_from_tags(bs)
#
# NameError: name 'bs' is not defined

# %%
response = requests.get('https://n.news.naver.com/mnews/article/023/0003711001', headers = {'User-Agent':'Mozilla 5.0'})
bs = BeautifulSoup(response.text,'lxml')

# %%
bs.select('div#dic_area')[0].text
# Out:
# '\n19세때 장기기증 이태경군 아버지… 장기기증 서약한 고교생들 만났다\n\n\n\n지난 6일 오후 서울 서대문구 사랑의장기기증운동본부에서 2010년 뇌사 판정을 받은 후 7명에게 장기를 나눠주고 세상을 떠난 이태경군의 아버지 이대호(가운데)씨가 최근 장기기증 희망 등록을 한 고등학생 4명으로부터 꽃다발을 받고 있다. 이씨는“남을 돕는 것을 무척 좋아하던 태경이도 하늘나라에서 기뻐하고 있을 것”이라고 말했다./사랑의장기기증운동본부\t\t\t\t\t\t\t\t\t\t“장기를 기증한 아들에게 ‘대견하다’는 말을 직접 해주지 못했어요. 대신 여러분에게 오늘 그 말을 전해주고 싶습니다.”지난 6일 오후 3시쯤 서울 서대문구 사랑의장기기증운동본부 회의실. 이 말을 하는 이대호(60)씨의 눈시울이 붉어졌다. 이씨의 아들 이태경군은 열아홉이던 지난 2010년 8월 뇌와 척수에 종양이 생겨 뇌사 판정을 받았다. 결국 이군은 세상을 떠났지만 장기를 기증해 7명의 생명을 살렸다. 그 후로 12년이 지났다. 아버지 이씨는 사랑의장기기증운동본부 제안으로 지난 6일 당시 아들 또래인 고교생 4명을 만나 당시를 떠올리는 시간을 가졌다. 모두 만일의 사태가 생기면 ‘장기 기증을 하겠다’고 서약한 학생들이다.지난 2010년 당시 서울 송파구 가락시장에서 홀로 작은 채소 가게를 하던 이씨에게 아들은 든든한 지원군이자 둘도 없는 친구였다. 하지만 2010년 7월 어느 날, 학교에서 돌아온 아들이 “요즘 한쪽 눈이 잘 보이지 않아 학교에서 칠판 보기 불편하다”고 했다. 얼마 후 한 대학 병원에서 들은 검사 결과는 충격적이었다. ‘신경 교종증’이란 들어보지도 못한 병이었다. 뇌와 척수 내부에 있는 신경교세포에 종양이 생겼고, 이 종양이 시신경을 누르고 있어 한쪽 눈이 잘 보이지 않는 증상이 나타난 것이라고 했다. 이씨는 곧바로 병원에 입원시켜 치료를 시작했지만 태경군은 다음 날 의식을 잃고 쓰러졌다. 일주일 뒤 태경군은 의사에게 뇌사 판정을 받았다.\n\n\n\n故 이태경군\t\t\t\t\t\t\t\t\t\t그 후 이씨는 아들이 깨어날까 실낱 같은 기대를 하며 온종일 병원을 떠나지 못했다고 한다. 그러다 우연히 병원 안 장기 이식 센터 앞에서 한 아이를 마주쳤다. 대여섯 살 정도로 보인 그 아이는 주삿바늘을 꽂은 채 터덜터덜 걸어가고 있었다고 한다. 그때 몇 년 전 아들이 한 말이 떠올랐다. 장기 이식을 기다리는 환자들이 나온 TV 다큐멘터리를 보던 태경이는 “아버지 저도 나중에 장기 기증을 해서 힘들어하는 환자들에게 도움을 주고 싶어요”라는 말이었다. 그 직후 이씨는 장기 이식 센터를 찾아 장기 기증 절차를 밟았다. 심장, 폐, 간, 신장, 췌장 등을 7명에게 나눠줬다고 한다.이날 이씨 얘기를 묵묵히 들은 열여덟 김연재, 황은빈, 이가연양과 이보다 한 살 많은 송지형양은 “우리도 다른 사람을 위한 실천을 시작하는 의미로 장기 기증을 서약했다”고 답했다.간호사를 꿈꾸는 송지형양은 “대가 없이 남을 위해 뭔가를 나누는 일에 참여하고 싶었다”고 했다. 김연재양은 “장기 기증 서약을 한 것이 앞으로 장기가 필요한 환자들에 대한 작은 응원이 되길 바란다”고 했고, 황은빈양은 친구들에게 장기 기증 결심을 했다는 걸 자랑하고 추천하고 있다고 전했다. 생명과학 연구원을 꿈꾸고 있는 이가연양은 “생명을 다루는 공부를 하기 전에 실천부터 하고 싶었다”고 말했다. 그는 “지금 장기 기증 희망 등록을 한 것과 훗날 내가 하게 될 생명을 살리는 연구가 함께 빛을 발했으면 좋겠다”고 했다.네 사람은 이날 ‘존경’의 꽃말을 담은 분홍 장미와 감사하는 마음을 쓴 편지를 준비해 이씨에게 건넸다. 편지에는 “두 분의 나눔을 깊이 기억하며, 아픈 환자들을 돕는 사람이 되기 위해 더욱 노력하겠다”고 적혀 있었다.\n'

# %%
#함수로 변환해보기
def get_contents_from_url(url:str):
    response = requests.get(url, headers = {'User-Agent':'Mozilla 5.0'})
    bs = BeautifulSoup(response.text, 'lxml')
    return bs.select('div#dic_area')[0].text

# %%
get_contents_from_url('https://n.news.naver.com/mnews/article/023/0003711001')
# Out:
# '\n19세때 장기기증 이태경군 아버지… 장기기증 서약한 고교생들 만났다\n\n\n\n지난 6일 오후 서울 서대문구 사랑의장기기증운동본부에서 2010년 뇌사 판정을 받은 후 7명에게 장기를 나눠주고 세상을 떠난 이태경군의 아버지 이대호(가운데)씨가 최근 장기기증 희망 등록을 한 고등학생 4명으로부터 꽃다발을 받고 있다. 이씨는“남을 돕는 것을 무척 좋아하던 태경이도 하늘나라에서 기뻐하고 있을 것”이라고 말했다./사랑의장기기증운동본부\t\t\t\t\t\t\t\t\t\t“장기를 기증한 아들에게 ‘대견하다’는 말을 직접 해주지 못했어요. 대신 여러분에게 오늘 그 말을 전해주고 싶습니다.”지난 6일 오후 3시쯤 서울 서대문구 사랑의장기기증운동본부 회의실. 이 말을 하는 이대호(60)씨의 눈시울이 붉어졌다. 이씨의 아들 이태경군은 열아홉이던 지난 2010년 8월 뇌와 척수에 종양이 생겨 뇌사 판정을 받았다. 결국 이군은 세상을 떠났지만 장기를 기증해 7명의 생명을 살렸다. 그 후로 12년이 지났다. 아버지 이씨는 사랑의장기기증운동본부 제안으로 지난 6일 당시 아들 또래인 고교생 4명을 만나 당시를 떠올리는 시간을 가졌다. 모두 만일의 사태가 생기면 ‘장기 기증을 하겠다’고 서약한 학생들이다.지난 2010년 당시 서울 송파구 가락시장에서 홀로 작은 채소 가게를 하던 이씨에게 아들은 든든한 지원군이자 둘도 없는 친구였다. 하지만 2010년 7월 어느 날, 학교에서 돌아온 아들이 “요즘 한쪽 눈이 잘 보이지 않아 학교에서 칠판 보기 불편하다”고 했다. 얼마 후 한 대학 병원에서 들은 검사 결과는 충격적이었다. ‘신경 교종증’이란 들어보지도 못한 병이었다. 뇌와 척수 내부에 있는 신경교세포에 종양이 생겼고, 이 종양이 시신경을 누르고 있어 한쪽 눈이 잘 보이지 않는 증상이 나타난 것이라고 했다. 이씨는 곧바로 병원에 입원시켜 치료를 시작했지만 태경군은 다음 날 의식을 잃고 쓰러졌다. 일주일 뒤 태경군은 의사에게 뇌사 판정을 받았다.\n\n\n\n故 이태경군\t\t\t\t\t\t\t\t\t\t그 후 이씨는 아들이 깨어날까 실낱 같은 기대를 하며 온종일 병원을 떠나지 못했다고 한다. 그러다 우연히 병원 안 장기 이식 센터 앞에서 한 아이를 마주쳤다. 대여섯 살 정도로 보인 그 아이는 주삿바늘을 꽂은 채 터덜터덜 걸어가고 있었다고 한다. 그때 몇 년 전 아들이 한 말이 떠올랐다. 장기 이식을 기다리는 환자들이 나온 TV 다큐멘터리를 보던 태경이는 “아버지 저도 나중에 장기 기증을 해서 힘들어하는 환자들에게 도움을 주고 싶어요”라는 말이었다. 그 직후 이씨는 장기 이식 센터를 찾아 장기 기증 절차를 밟았다. 심장, 폐, 간, 신장, 췌장 등을 7명에게 나눠줬다고 한다.이날 이씨 얘기를 묵묵히 들은 열여덟 김연재, 황은빈, 이가연양과 이보다 한 살 많은 송지형양은 “우리도 다른 사람을 위한 실천을 시작하는 의미로 장기 기증을 서약했다”고 답했다.간호사를 꿈꾸는 송지형양은 “대가 없이 남을 위해 뭔가를 나누는 일에 참여하고 싶었다”고 했다. 김연재양은 “장기 기증 서약을 한 것이 앞으로 장기가 필요한 환자들에 대한 작은 응원이 되길 바란다”고 했고, 황은빈양은 친구들에게 장기 기증 결심을 했다는 걸 자랑하고 추천하고 있다고 전했다. 생명과학 연구원을 꿈꾸고 있는 이가연양은 “생명을 다루는 공부를 하기 전에 실천부터 하고 싶었다”고 말했다. 그는 “지금 장기 기증 희망 등록을 한 것과 훗날 내가 하게 될 생명을 살리는 연구가 함께 빛을 발했으면 좋겠다”고 했다.네 사람은 이날 ‘존경’의 꽃말을 담은 분홍 장미와 감사하는 마음을 쓴 편지를 준비해 이씨에게 건넸다. 편지에는 “두 분의 나눔을 깊이 기억하며, 아픈 환자들을 돕는 사람이 되기 위해 더욱 노력하겠다”고 적혀 있었다.\n'

# %%
pd.DataFrame(zip(title2), columns = ['titles'])
pd.DataFrame({'titles': title2})
# Out:
#                                     titles
# 0                                손잡은 한미 포병
# 1              추석연휴 기차 예매율 9월 9일·12일이 80%대
# 2         철도 역세권 투자법 부동산 절세 전략… 전문가들 비법 공개
# 3    [NOW] ‘카톡 손주’ 덕분에 스마트폰·키오스크 혼자서도 잘 써요
# 4            한국갤럽 尹지지율 조사, 긍정평가 3%p 올라 28%
# ..                                     ...
# 61   “엄마가 내 어린시절 노출해 큰 피해 봤어요” 일본서 셰어런팅 역풍
# 62  두 배 비싸게 만든 김원웅식 위인전… 김구 290쪽, 모친은 430쪽
# 63                월성·북송… 대통령기록관 하루 두번 압수수색
# 64            갤Z폴드·Z플립, 이번에도 우크라에선 ‘Z’ 빠졌다
# 65                 [백영옥의 말과 글](266) 글 쓰는 일
#
# [66 rows x 1 columns]

# %%
title2 = []
all_urls = []
for i in tqdm(range(1, last_page_num1+1)):
    response = get_bs_data_from_naver_news('023', '20220820', i)
    title1 = get_titiles_from_tags(response)
    urls = get_body_urls_from_tags(response)

    all_urls += urls
    title2 += title1
# Out:
# 100%|██████████| 6/6 [00:17<00:00,  2.95s/it]

# %%
news = pd.DataFrame({  'date': '20220820',
                'oid':'023',
                'titles': title2,
                'url': all_urls})

# %%
news
# Out:
#         date  oid                                  titles  \
# 0   20220820  023                               손잡은 한미 포병
# 1   20220820  023             추석연휴 기차 예매율 9월 9일·12일이 80%대
# 2   20220820  023        철도 역세권 투자법 부동산 절세 전략… 전문가들 비법 공개
# 3   20220820  023   [NOW] ‘카톡 손주’ 덕분에 스마트폰·키오스크 혼자서도 잘 써요
# 4   20220820  023           한국갤럽 尹지지율 조사, 긍정평가 3%p 올라 28%
# ..       ...  ...                                     ...
# 61  20220820  023   “엄마가 내 어린시절 노출해 큰 피해 봤어요” 일본서 셰어런팅 역풍
# 62  20220820  023  두 배 비싸게 만든 김원웅식 위인전… 김구 290쪽, 모친은 430쪽
# 63  20220820  023                월성·북송… 대통령기록관 하루 두번 압수수색
# 64  20220820  023            갤Z폴드·Z플립, 이번에도 우크라에선 ‘Z’ 빠졌다
# 65  20220820  023                 [백영옥의 말과 글](266) 글 쓰는 일
#
#                                                   url
# 0   https://n.news.naver.com/mnews/article/023/000...
# 1   https://n.news.naver.com/mnews/article/023/000...
# 2   https://n.news.naver.com/mnews/article/023/000...
# 3   https://n.news.naver.com/mnews/article/023/000...
# 4   https://n.news.naver.com/mnews/article/023/000...
# ..                                                ...
# 61  https://n.news.naver.com/mnews/article/023/000...
# 62  https://n.news.naver.com/mnews/article/023/000...
# 63  https://n.news.naver.com/mnews/article/023/000...
# 64  https://n.news.naver.com/mnews/article/023/000...
# 65  https://n.news.naver.com/mnews/article/023/000...
#
# [66 rows x 4 columns]

# %%
for row in tqdm(news.itertuples()):
    try:
        news.loc[row.Index, 'contents'] = get_contents_from_url(row.url)
    except:
        pass
# Out:
# 66it [00:19,  3.38it/s]

# %%
row
# Out:
# Pandas(Index=65, date='20220820', oid='023', titles='[백영옥의 말과 글](266) 글 쓰는 일', url='https://n.news.naver.com/mnews/article/023/0003710996')

# %%
news
# Out:
#         date  oid                                  titles  \
# 0   20220820  023                               손잡은 한미 포병
# 1   20220820  023             추석연휴 기차 예매율 9월 9일·12일이 80%대
# 2   20220820  023        철도 역세권 투자법 부동산 절세 전략… 전문가들 비법 공개
# 3   20220820  023   [NOW] ‘카톡 손주’ 덕분에 스마트폰·키오스크 혼자서도 잘 써요
# 4   20220820  023           한국갤럽 尹지지율 조사, 긍정평가 3%p 올라 28%
# ..       ...  ...                                     ...
# 61  20220820  023   “엄마가 내 어린시절 노출해 큰 피해 봤어요” 일본서 셰어런팅 역풍
# 62  20220820  023  두 배 비싸게 만든 김원웅식 위인전… 김구 290쪽, 모친은 430쪽
# 63  20220820  023                월성·북송… 대통령기록관 하루 두번 압수수색
# 64  20220820  023            갤Z폴드·Z플립, 이번에도 우크라에선 ‘Z’ 빠졌다
# 65  20220820  023                 [백영옥의 말과 글](266) 글 쓰는 일
#
#                                                   url  \
# 0   https://n.news.naver.com/mnews/article/023/000...
# 1   https://n.news.naver.com/mnews/article/023/000...
# 2   https://n.news.naver.com/mnews/article/023/000...
# 3   https://n.news.naver.com/mnews/article/023/000...
# 4   https://n.news.naver.com/mnews/article/023/000...
# ..                                                ...
# 61  https://n.news.naver.com/mnews/article/023/000...
# 62  https://n.news.naver.com/mnews/article/023/000...
# 63  https://n.news.naver.com/mnews/article/023/000...
# 64  https://n.news.naver.com/mnews/article/023/000...
# 65  https://n.news.naver.com/mnews/article/023/000...
#
#                                              contents
# 0   \n\n\n\n\n/연합뉴스\t\t\t\t\t\t\t\t\t\t19일 경기도 포천시...
# 1   \n\t\t\t\t\t\t\t\t\t\t이번 추석 연휴 때 귀성객이 가장 많은 날은...
# 2   \n[2022 부동산 트렌드쇼] 오늘도 다양한 재테크 강연\t\t\t\t\t\t\t...
# 3   \n노인·청년 이어주는 디지털 교육 인기\t\t\t\t\t\t\t경기 남양주에 사는...
# 4   \n\t\t\t\t\t\t\t\t\t\t윤석열 대통령의 지지율이 한국갤럽 조사에서 ...
# ..                                                ...
# 61  \n\n\n\n\n'셰어런팅' 논란으로 역풍을 맞고 있는 일본 사이바라 리에코(58...
# 62  \n보훈처, 前광복회장 두번째 고발\n\n\n\n\t\t\t\t\t\t\t\t\t\...
# 63  \n文정부 청와대 윗선으로 향하는 검찰 수사\t\t\t\t\t\t\t검찰이 19일 ...
# 64  \n\n\n\n\n삼성전자 우크라이나 홈페이지에 게시된 갤럭시Z폴드4와 갤럭시Z플립...
# 65  \n스티븐 킹과 시드니 셸던의 팬이었던 어린 시절, 큰 의문이 있었다. 어떻게 한 ...
#
# [66 rows x 5 columns]

# %% [markdown]
# ## DB 업로드

# %%
conn = psycopg2.connect(
  host='localhost',
  dbname='postgres',
  user='postgres',
  password='postgrespw',
  port= 49153
)

cur = conn.cursor()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\user\Documents\github_jd\Start_Big_Data_MegaIT\day05.ipynb 셀 62 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/github_jd/Start_Big_Data_MegaIT/day05.ipynb#Y130sZmlsZQ%3D%3D?line=0'>1</a> conn = psycopg2.connect(
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/github_jd/Start_Big_Data_MegaIT/day05.ipynb#Y130sZmlsZQ%3D%3D?line=1'>2</a>   host='localhost',
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/github_jd/Start_Big_Data_MegaIT/day05.ipynb#Y130sZmlsZQ%3D%3D?line=2'>3</a>   dbname='postgres',
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/github_jd/Start_Big_Data_MegaIT/day05.ipynb#Y130sZmlsZQ%3D%3D?line=3'>4</a>   user='postgres',
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/github_jd/Start_Big_Data_MegaIT/day05.ipynb#Y130sZmlsZQ%3D%3D?line=4'>5</a>   password='postgrespw',
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/github_jd/Start_Big_Data_MegaIT/day05.ipynb#Y130sZmlsZQ%3D%3D?line=5'>6</a>   port= 49153
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/github_jd/Start_Big_Data_MegaIT/day05.ipynb#Y130sZmlsZQ%3D%3D?line=6'>7</a> )
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/github_jd/Start_Big_Data_MegaIT/day05.ipynb#Y130sZmlsZQ%3D%3D?line=8'>9</a> cur = conn.cursor()
#
# NameError: name 'psycopg2' is not defined

# %%
#DataFrame 상태로 DB로 올린다

news.to_sql(
    'news',
    conn,
    if_exists='replace'
    index = False
)
# Out:
#   Input In [257]
#     index = False
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### 네이버 증권

# %% [markdown]
# #### 다음 증권
